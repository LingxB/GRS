# %%
#%pylab inline
#pylab.rcParams['figure.figsize'] = (10, 6)
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import re
import random
import nltk
from random import randint
from collections import OrderedDict,Counter

# %%
df = pd.read_csv('GenderEven207.csv')

# %%
def preprocess(text,n_tags=None,filt=True,lower=False):
    """
    Input text string, return tokenized, postagged, filted tokens.
    """
    if filt:
        negative_tags = ['$',"''",'(',')','--','.',',',':','DT','CC','IN','TO']
        if n_tags:
            negative_tags.extend(n_tags)
    else:
        negative_tags = []
    
    if lower:
        text = text.lower()
    tokens = nltk.word_tokenize(text)
    tagged_tokens = nltk.pos_tag(tokens)
    filted_tokens = [(tok,pos) for (tok,pos) in tagged_tokens if pos not in negative_tags]
    
    return filted_tokens   
    
    
def freqdist_by_cat(df,topN=10,focus=None,gender=None,ppraw='PP_RAW'):
    """Find out how word usage based on gender and focus difference"""
    c = Counter()
    
    if focus and gender:
        _df = df.loc[df['FOCUS'] == focus & df['GENDER'] == gender, ppraw]
    else:
        if gender:
            _df = df.loc[df['GENDER'] == gender, ppraw]    
        elif focus:
            _df = df.loc[df['FOCUS'] == focus, ppraw]
        else:
            _df = df[ppraw]
            
    for s in _df:
        c.update(s)
    
    return c.most_common(topN)
    
    
def catwelgo_topNs(df,cw,topN=20,ppraw='PP_RAW',pos_filter=False,n_tags=None):
    """Find out word useage based on category and wellgorithms"""
    c = Counter() 
    for x in df[cw]:
        c.update(x.split(','))
        
    cws = sorted(c.keys())
    dcw = {}
    _n_tags = []
    _n_tags.extend(n_tags)
    
    for t in cws:
        t_seq = []
        for idx,row in df.iterrows():
            if t in row[cw].split(','):
                if pos_filter:
                    t_seq.extend([(w,p) for w,p in row[ppraw] if p not in _n_tags])
                else:    
                    t_seq.extend(row[ppraw])
        dcw.update({t:t_seq})
        
    counted = list(map(lambda t: Counter(dcw[t]).most_common(topN), cws))
    
    _df = pd.DataFrame(index=cws,columns=range(1,topN+1),data=counted)
    
    return _df

# %%
df['PP_RAW'] = None

for idx,row in df.iterrows():
    row['PP_RAW'] = preprocess(row['RAW'])

# %%
df
# Out:
#                                                    RAW  \
# 0    Throughout my drinking career, instant gratifi...
# 1    I tried to control every aspect of my life. Wh...
# 2    Thinking about drinking – the taste and feel –...
# 3    I always thought today/this weekend/this week ...
# 4    The people around me only saw what I wanted th...
# 5    Resigned to the fact that being poor or homele...
# 6    Alcohol was great for two things, suppressing ...
# 7    I’ve started more things than I can count and ...
# 8    How great it was to have a friend that I could...
# 9    Diving headlong into whatever had caught my in...
# 10   When I was drinking, I didn’t just distance my...
# 11   I did it; it was all me. Nobody or no thing ha...
# 12   Embrace the suck. Life sucks, get a helmet. Th...
# 13   I was obsessed with everything. I obsessed ove...
# 14   I only dealt in absolutes when I drank. I was ...
# 15   Talk about being ashamed. I’d hurt just about ...
# 16   My world was black and white while I was drink...
# 17   How impulsive I was. I never had time to make ...
# 18   I didn’t plan my day, alcohol did. Everything ...
# 19   When I was drinking, I could only be best desc...
# 20   Like a kid hopped up on sugar, I can’t sit sti...
# 21   I didn’t just avoid the warning signs when I w...
# 22   When I was drinking, I thought I was pretty go...
# 23   I felt worthless. Even more troubling is that ...
# 24   Abstinence... it was a hard thing for me to ap...
# 25   It took a long time for me to sail through sto...
# 26   Accidents happen. I've known that since childh...
# 27   I used to always hurt - anxiety, depression, a...
# 28   Exploring for alternatives was what got me int...
# 29   I always thought myself to be a humble dude. I...
# ..                                                 ...
# 384  Even when I am not in a great mood, I sometime...
# 385  Reaching deep down is scary, but necessary. To...
# 386  I have been dealing with a lot of emotional ch...
# 387  One of the challenges in battling my disease i...
# 388  As I recover, I learn to be grateful for the s...
# 389  Removing myself from a situation sooths my str...
# 390   My emotions tended to be all over the place w...
# 391  I have stopped the use of drugs. I have alread...
# 392  You can find me in the garden early in the mor...
# 393  I pledge my sobriety for a day at a time. I do...
# 394   Now I realize that my bad habits/using cost m...
# 395  If I am not prepared, I will not progress. I d...
# 396  Cravings or something that will always exist. ...
# 397  There are certain people in my life that feed ...
# 398  Exploring the things that motivate my recovery...
# 399  As the saying goes, shit happens. Expect it, p...
# 400  My 4th step inventory worksheet is a problem d...
# 401  Monitoring my moods is important for me. It is...
# 402  There are many rewards of recovery. In OA and ...
# 403  Today I am not afraid to seek help. Others in ...
# 404   While using, irrational beliefs were rational...
# 405  I am capable of disputing irrational beliefs w...
# 406  While using, I had this habit of making excuse...
# 407  I imagine that I am riding an unending wave. T...
# 408  My problems became more manageable in recovery...
# 409  Lazy thinking keeps me in relapse. Everything ...
# 410  It’s been said to call a spade a spade. Bringi...
# 411   Just by being in recovery, I have a new calmn...
# 412  The cravings I experience are not imaginary, b...
# 413  When I used drugs, I was alone and I preferred...
#
#                                                   CATS  \
# 0    PROGRESS / start small,INNER MASTERY / take a ...
# 1    CONTROL,SERENITY,FREEDOM / past & let go,TRUST...
# 2    CRAVINGS / will power & tools,INNER POWER / Se...
# 3    DELUSION,CONFESSION / denial,TRUTH / self honesty
# 4    CONFIDENCE / acceptance & worth,DELUSION,VULNE...
# 5    CONFIDENCE /  hope & future,FREEDOM / past & l...
# 6    WORTHINESS / connections & sharing,VULNERABILI...
# 7    COMMITMENTS,MOTIVATION,RESPONSIBILITY,INNER PO...
# 8    EGO,PRIDE ,INFLUENCES,COMMUNITY / healthy rela...
# 9    COMMITMENTS,PROGRESS / start small,INNER POWER...
# 10   INFLUENCES,LONELINESS,GROWTH / motivation & bo...
# 11   GRATITUDE / for others,CHANGE / self love & tr...
# 12   RESILIENCE / reaction & behavior,AGONY,MINDSET...
# 13   INNER POWER / Self control & willpower,FREEDOM...
# 14   GROWTH / behavior & habits,EGO,PROGRESS / reac...
# 15   SHAME,CONFESSION / damage & hurt,WORTHINESS / ...
# 16   GROWTH / learning & mistakes,RESILIENCE / reac...
# 17   PROGRESS / future & hope,MINDSET,GROWTH / supp...
# 18   FREEDOM / past & let go,WORTHINESS / new life ...
# 19   INNER MASTERY / beliefs & awareness,URGES / to...
# 20   FREEDOM / tools & strategies,URGES / tools & t...
# 21   GROWTH / learning & mistakes,SOBRIETY / behavi...
# 22   HEALING,GROWTH / true self,INNER / SELF / harm...
# 23   WORTHINESS / connections & sharing,VULNERABILI...
# 24   SOBRIETY / costs & benefits,ABSTINENCE,INNER P...
# 25   ABSTINENCE,COMMUNITY / healthy relationships,S...
# 26   VULNERABILITY / learning and mistakes,ACCOUNTA...
# 27   AGONY,INNER MASTERY / strength,TRUTH / Admit a...
# 28   DEAD END,TRUTH / dark past,MINDSET / Future so...
# 29     AMENDS,RECONCILIATON,CONFESSION / damage & hurt
# ..                                                 ...
# 384  JOY,INNER / SELF / patterns,COMMUNITY / connec...
# 385  COURAGE,CONFIDENCE /  hope & future,COMMUNITY ...
# 386  INNER MASTERY / challenge & resilience,INNER P...
# 387  COMMUNITY / Meetings & groups,URGES / tools & ...
# 388  GRATITUDE / progress & growth,PROGRESS / rewar...
# 389                             STRESS,MOODS,REACTIONS
# 390  RESILIENCE / reaction & behavior,CONFLICT,TRIG...
# 391  WORTHINESS / new life & future,CONFIDENCE / ac...
# 392  GRATITUDE / progress & growth,HIGHER POWER / s...
# 393  SOBRIETY / maintaining & will power,PROGRESS /...
# 394         BENEFITS / COSTS,PAST,REGRET,TRUTH / Costs
# 395  PROGRESS / start small,GROWTH / behavior & hab...
# 396  MINDSET / obstacles & challenge,CRAVINGS / vul...
# 397  INFLUENCES,BABY STEPS / Help & support,COMMUNI...
# 398   DAILY WORK,OPTIMISM,GROWTH / motivation & boosts
# 399  CONTROL,SITUATIONS,MINDSET / imperfection & ac...
# 400  INNER MASTERY / tools & processes,CONFIDENCE /...
# 401  MOODS,FREEDOM / tools & strategies,MINDSET / F...
# 402  FREEDOM / tools & strategies,PROGRESS / reward...
# 403  COURAGE,CONFESSION / powerlessness,WORTHINESS ...
# 404  MINDSET,CONFIDENCE /  obstacles & challenge,CH...
# 405  CONFIDENCE / acceptance & worth,INNER POWER / ...
# 406  EXCUSES,RESPONSIBILITY,DEAD END,ACCOUNTABILITY...
# 407  MINDSET / obstacles & challenge,INNER POWER / ...
# 408  OVERWHELM,TRUTH / Admit addiction,VULNERABILIT...
# 409  GROWTH / motivation & boosts,PROGRESS / future...
# 410  DEMONS,THOUGHTS,PROGRESS / reactions & behavio...
# 411  TRIGGERS / confidence & strength,INNER POWER /...
# 412  INNER MASTERY / challenge & resilience,CRAVING...
# 413         HEALING,WORTHINESS / connections & sharing
#
#                                                WELLGOS      FOCUS       N  \
# 0    Baby Step Embracer,Finish Line Forgetter,The M...  DRUGS/ALC    Paul
# 1    Controller Coaster,Should Shover,Serenity Simu...  DRUGS/ALC    Paul
# 2    Pattern Interrupter,New Pattern Painter,Craver...  DRUGS/ALC    Paul
# 3    Delusion Detector,Sabotage SOS’r,Insanity SOS’...  DRUGS/ALC    Paul
# 4    Self Esteem Elixir,Confidence Caffeinator,Inne...  DRUGS/ALC    Paul
# 5    Excuse Exterminator,Rationalization Rinser,Gra...  DRUGS/ALC    Paul
# 6    Emotions Engineer,Feelings Fantasizer,Compassi...  DRUGS/ALC    Paul
# 7    Finish Line Forgetter,The Procrastina-shunner,...  DRUGS/ALC    Paul
# 8    Foul Weather Friender,Arrogance Arrestor,Pride...  DRUGS/ALC    Paul
# 9    Symbolic Stepper,New Pattern Painter / grit & ...  DRUGS/ALC    Paul
# 10   Isolation SOS’r,Bad Influence Butcher,WAIT AND...  DRUGS/ALC    Paul
# 11   Miracle Embracer,Ego Eclipser,Pride Polisher,A...  DRUGS/ALC    Paul
# 12   Misery Minister,Ill Feelings Illuminator,Depre...  DRUGS/ALC    Paul
# 13   Insanity SOS’r,Self awareness / habits & behav...  DRUGS/ALC    Paul
# 14   Pride Puffer,Ego Eclipser,Arrogance Arrestor,N...  DRUGS/ALC    Paul
# 15   Shame X’r,Ever Evolving Flower,Worthiness Whis...  DRUGS/ALC    Paul
# 16   Perspective Detective,Daily Daisy Spotter,Blun...  DRUGS/ALC    Paul
# 17   Values VIP’r,Soul Proprietor,Sobriety 101'r,WA...  DRUGS/ALC    Paul
# 18   Past #2,The Mindfulizer,Regret Refunder,Self C...  DRUGS/ALC    Paul
# 19   Placid Reflux,Urge Auditor,Compulsion KO’r,Sel...  DRUGS/ALC    Paul
# 20   Void Avoider,The Procrastina-shunner,Lazy Zapp...  DRUGS/ALC    Paul
# 21   Sabotage SOS’r,Little Hint Listener,Inner Soul...  DRUGS/ALC    Paul
# 22   Whole Soul Healer,Serenity Soulmater,Inner Sou...  DRUGS/ALC    Paul
# 23   Dead End Deluder,Worthiness Whisperer,Love Swe...  DRUGS/ALC    Paul
# 24   Abstainer Amazer,Demon Dethroner ,COMMITMENT k...  DRUGS/ALC   Nigel
# 25   COMMITMENT knitter / abstinence confidence,REL...  DRUGS/ALC   Nigel
# 26   RAW SOUL REVEALER / past mistakes,ADMIT / acco...  DRUGS/ALC   Nigel
# 27   Pain Abstainer,CLOSET CONFESSOR / Admit addict...  DRUGS/ALC   Nigel
# 28   Dead End Defier ,Addiction AMF’r,Lost Benefit ...  DRUGS/ALC   Nigel
# 29   Relationship Dedamager,The First Amender,CLOSE...  DRUGS/ALC   Nigel
# ..                                                 ...        ...     ...
# 384  WAIT AND SWITCH / Emotions,Soul Tuner,New Patt...    GENERAL    Shar
# 385  Deep Down Diver,Scary Stepper,Fear Flusher,Cou...  DRUGS/ALC     Jen
# 386  Challenge Ninja,Addiction AMF’r,Adversity Aven...       FOOD    Shar
# 387  Urge Auditor,Compulsion KO’r,Ill Feelings Illu...       FOOD  Ilanna
# 388  Sober Milestoner,Baby Step Embracer,WAIT AND S...       FOOD    Shar
# 389  Placid Reflux,Stress Auditor,The Wellifier ,Th...     EITHER     Jen
# 390  Reactions Auditor,Situation Unscrewer,Problem ...  DRUGS/ALC    Alys
# 391  Inner Power Allower,Negativity Nuker,THOUGHTS ...  DRUGS/ALC    Alys
# 392  Gratitude Gardener,God Grounder,Bliss Kisser,N...  DRUGS/ALC    Shar
# 393  Sobriety 101'r,Symbolic Stepper,The Momentumiz...  DRUGS/ALC    Alys
# 394  Lost Benefit Lamenter,Wellectricity Generator,...  DRUGS/ALC     Jen
# 395  WAIT AND SWITCH / Small steps,Progress Pollina...       FOOD    Shar
# 396  Reactions Auditor,Craver Saver / Braver,I-Can-...  DRUGS/ALC     Jen
# 397  Bad Influence Butcher,VULNERABILITY / listen t...       FOOD    Shar
# 398  Confidence Colonizer,The Dynamotivator,Journey...  DRUGS/ALC     Jen
# 399  Excrement Expector,Problem Primer,Self Control...    GENERAL     Jen
# 400  Problem Doctor,The Dynamotivator,COMMITMENT kn...       FOOD    Shar
# 401  Feelings Flipper,SELF HARM / Tools,I-examiner ...  DRUGS/ALC    Shar
# 402  Progress Painter,The Successcalator,Values VIP...       FOOD    Shar
# 403  Pride Puffer,The Benefisher,Sobriety SOS’r,CLO...  DRUGS/ALC     Jen
# 404  Old Belief Butcher,Missi-Un-Impossiblizer ,Can...  DRUGS/ALC    Alys
# 405  Belief Superseder,Illogical Looper,Mentality M...     EITHER     Jen
# 406  Rationalization Rinser,Excuse X’r,Responsibili...  DRUGS/ALC    Alys
# 407  Adversity Adventurer,Blunder Blesser,Troubles ...    GENERAL     Jen
# 408  Qualm Quitter,CLOSET CONFESSOR / Share & suppo...       FOOD    Shar
# 409  Lazy Zapper,The Procrastina-shunner,THOUGHTS /...  DRUGS/ALC  Ilanna
# 410  Demon Doctor,THOUGHTS / aware & examine,VULNER...       FOOD    Shar
# 411  Bad Influence Butcher,Pain Abstainer,Self Cont...  DRUGS/ALC    Alys
# 412  Ill Feelings Illuminator,Soul-ution Finder,Cra...       FOOD  Ilanna
# 413  Sobriety Soulmater,Progress Pollinator,RELATIO...  DRUGS/ALC     Jen
#
#      GENDER                                             PP_RAW
# 0      male  [(my, PRP$), (drinking, NN), (career, NN), (in...
# 1      male  [(I, PRP), (tried, VBD), (control, VB), (aspec...
# 2      male  [(Thinking, VBG), (drinking, NN), (–, VBP), (t...
# 3      male  [(I, PRP), (always, RB), (thought, VBD), (toda...
# 4      male  [(people, NNS), (me, PRP), (only, RB), (saw, V...
# 5      male  [(Resigned, VBN), (fact, NN), (being, VBG), (p...
# 6      male  [(Alcohol, NNP), (was, VBD), (great, JJ), (two...
# 7      male  [(I’ve, NNP), (started, VBD), (more, JJR), (th...
# 8      male  [(How, WRB), (great, JJ), (it, PRP), (was, VBD...
# 9      male  [(Diving, VBG), (headlong, NN), (whatever, WDT...
# 10     male  [(When, WRB), (I, PRP), (was, VBD), (drinking,...
# 11     male  [(I, PRP), (did, VBD), (it, PRP), (it, PRP), (...
# 12     male  [(Embrace, NNP), (suck, NN), (Life, NNP), (suc...
# 13     male  [(I, PRP), (was, VBD), (obsessed, VBN), (every...
# 14     male  [(I, PRP), (only, RB), (dealt, VBD), (absolute...
# 15     male  [(Talk, NN), (being, VBG), (ashamed, VBN), (I’...
# 16     male  [(My, PRP$), (world, NN), (was, VBD), (black, ...
# 17     male  [(How, WRB), (impulsive, JJ), (I, PRP), (was, ...
# 18     male  [(I, PRP), (didn’t, VBP), (plan, JJ), (my, PRP...
# 19     male  [(When, WRB), (I, PRP), (was, VBD), (drinking,...
# 20     male  [(kid, NN), (hopped, VBD), (up, RP), (sugar, N...
# 21     male  [(I, PRP), (didn’t, VBP), (just, RB), (avoid, ...
# 22     male  [(When, WRB), (I, PRP), (was, VBD), (drinking,...
# 23     male  [(I, PRP), (felt, VBD), (worthless, NN), (Even...
# 24     male  [(Abstinence, NN), (it, PRP), (was, VBD), (har...
# 25     male  [(It, PRP), (took, VBD), (long, JJ), (time, NN...
# 26     male  [(Accidents, NNS), (happen, VBP), (I, PRP), ('...
# 27     male  [(I, PRP), (used, VBD), (always, RB), (hurt, V...
# 28     male  [(Exploring, VBG), (alternatives, NNS), (was, ...
# 29     male  [(I, PRP), (always, RB), (thought, VBD), (myse...
# ..      ...                                                ...
# 384  female  [(Even, RB), (when, WRB), (I, PRP), (am, VBP),...
# 385  female  [(Reaching, VBG), (deep, JJ), (down, NN), (is,...
# 386  female  [(I, PRP), (have, VBP), (been, VBN), (dealing,...
# 387  female  [(One, CD), (challenges, NNS), (battling, VBG)...
# 388  female  [(I, PRP), (recover, VBP), (I, PRP), (learn, V...
# 389  female  [(Removing, VBG), (myself, PRP), (situation, N...
# 390  female  [(My, PRP$), (emotions, NNS), (tended, VBD), (...
# 391  female  [(I, PRP), (have, VBP), (stopped, VBD), (use, ...
# 392  female  [(You, PRP), (can, MD), (find, VB), (me, PRP),...
# 393  female  [(I, PRP), (pledge, VBP), (my, PRP$), (sobriet...
# 394  female  [(Now, RB), (I, PRP), (realize, VBP), (my, PRP...
# 395  female  [(I, PRP), (am, VBP), (not, RB), (prepared, JJ...
# 396  female  [(Cravings, NNS), (something, NN), (that, WDT)...
# 397  female  [(There, EX), (are, VBP), (certain, JJ), (peop...
# 398  female  [(Exploring, VBG), (things, NNS), (that, WDT),...
# 399  female  [(saying, NN), (goes, VBZ), (shit, JJ), (happe...
# 400  female  [(My, PRP$), (4th, CD), (step, NN), (inventory...
# 401  female  [(Monitoring, VBG), (my, PRP$), (moods, NNS), ...
# 402  female  [(There, EX), (are, VBP), (many, JJ), (rewards...
# 403  female  [(Today, NN), (I, PRP), (am, VBP), (not, RB), ...
# 404  female  [(using, VBG), (irrational, JJ), (beliefs, NNS...
# 405  female  [(I, PRP), (am, VBP), (capable, JJ), (disputin...
# 406  female  [(using, VBG), (I, PRP), (had, VBD), (habit, N...
# 407  female  [(I, PRP), (imagine, VBP), (I, PRP), (am, VBP)...
# 408  female  [(My, PRP$), (problems, NNS), (became, VBD), (...
# 409  female  [(Lazy, NNP), (thinking, VBG), (keeps, NNS), (...
# 410  female  [(It’s, NNP), (been, VBN), (said, VBD), (call,...
# 411  female  [(Just, RB), (being, VBG), (recovery, NN), (I,...
# 412  female  [(cravings, NNS), (I, PRP), (experience, VBP),...
# 413  female  [(When, WRB), (I, PRP), (used, VBD), (drugs, N...
#
# [414 rows x 7 columns]

# %%
afag = freqdist_by_cat(df,30) #all focus, all gender
afom = freqdist_by_cat(df,30,gender='male') #all focus / male
afof = freqdist_by_cat(df,30,gender='female') #all focus / female

df_g_w = pd.DataFrame(columns=['ALL','MALE','FEMALE'])
df_g_w['ALL'] = afag
df_g_w['MALE'] = afom
df_g_w['FEMALE'] = afof

print('Male average words: %4.2f' %(sum([len(s) for s in df.loc[df['GENDER'] == 'male', 'PP_RAW']])/207)) # Male average words
print('Female average words: %4.2f' %(sum([len(s) for s in df.loc[df['GENDER'] == 'female', 'PP_RAW']])/207)) #Female average words
print('Total words Male: ', sum([len(s) for s in df.loc[df['GENDER'] == 'male', 'PP_RAW']])) # Male total words
print('Total words Female: ', sum([len(s) for s in df.loc[df['GENDER'] == 'female', 'PP_RAW']])) # Female total words
# Out:
# Male average words: 114.51
# Female average words: 85.41
# Total words Male:  23703
# Total words Female:  17679

# %%
df_g_w.to_csv('Raw/W-fdist_Top30-gender.csv',index=False)

# %%
df_g_w
# Out:
#                        ALL                    MALE                 FEMALE
# 0         ((I, PRP), 3829)        ((I, PRP), 2281)       ((I, PRP), 1548)
# 1       ((my, PRP$), 1529)       ((my, PRP$), 789)      ((my, PRP$), 740)
# 2         ((me, PRP), 772)       ((was, VBD), 607)       ((is, VBZ), 373)
# 3        ((was, VBD), 735)        ((it, PRP), 427)       ((me, PRP), 360)
# 4         ((it, PRP), 617)        ((me, PRP), 412)       ((am, VBP), 309)
# 5         ((is, VBZ), 596)        ((n't, RB), 246)       ((not, RB), 221)
# 6         ((am, VBP), 356)       ((had, VBD), 227)     ((have, VBP), 211)
# 7         ((not, RB), 317)        ((is, VBZ), 223)       ((it, PRP), 190)
# 8       ((have, VBP), 312)         (('d, MD), 187)  ((recovery, NN), 175)
# 9     ((myself, PRP), 311)    ((myself, PRP), 186)       ((can, MD), 150)
# 10       ((life, NN), 300)       ((life, NN), 182)      ((are, VBP), 149)
# 11        ((can, MD), 264)         ((be, VB), 145)      ((was, VBD), 128)
# 12       ((had, VBD), 261)      ((could, MD), 144)   ((myself, PRP), 125)
# 13         ((be, VB), 258)       ((did, VBD), 137)      ((life, NN), 118)
# 14        ((n't, RB), 246)  ((addiction, NN), 132)     ((that, WDT), 118)
# 15      ((that, WDT), 235)     ((drugs, NNS), 126)        ((be, VB), 113)
# 16       ((are, VBP), 215)      ((that, WDT), 117)      ((will, MD), 112)
# 17      ((when, WRB), 204)        ((can, MD), 114)     ((when, WRB), 101)
# 18  ((addiction, NN), 195)      ((were, VBD), 113)      ((them, PRP), 99)
# 19      ((them, PRP), 192)        ((It, PRP), 108)      ((they, PRP), 73)
# 20         (('d, MD), 187)      ((would, MD), 107)      ((When, WRB), 72)
# 21   ((recovery, NN), 179)      ((they, PRP), 104)    ((people, NNS), 70)
# 22      ((they, PRP), 177)      ((when, WRB), 103)    ((things, NNS), 69)
# 23        ((It, PRP), 173)      ((have, VBP), 101)       ((what, WP), 68)
# 24      ((could, MD), 171)        ((just, RB), 98)        ((It, PRP), 65)
# 25      ((would, MD), 154)         ((not, RB), 96)  ((addiction, NN), 63)
# 26     ((drugs, NNS), 153)    ((friends, NNS), 94)        ((do, VBP), 63)
# 27       ((did, VBD), 152)       ((them, PRP), 93)     ((don’t, VBP), 61)
# 28       ((what, WP), 152)         (('m, VBP), 85)        ((get, VB), 61)
# 29    ((things, NNS), 152)        ((what, WP), 84)        ((one, CD), 58)

# %%
# %%time
countwelgo = catwelgo_topNs(df,'WELLGOS')
countcats = catwelgo_topNs(df,'CATS')
# Out:
# Wall time: 39.1 s

# %%
countwelgo.to_csv('Raw/Cats_W-most_common-Top20.csv')
countcats.to_csv('Raw/Welgs_W-most_common-Top20.csv')

# %%
countwelgo_flt = catwelgo_topNs(df,'WELLGOS',pos_filter=True,n_tags=['PRP','PRP$','VBD','RB','VBZ','VBP','VB','MD','VB'])
countcats_flt = catwelgo_topNs(df,'CATS',pos_filter=True,n_tags=['PRP','PRP$','VBD','RB','VBZ','VBP','VB','MD','VB'])

# %%
countwelgo_flt.to_csv('Raw/Cats_W-most_common-Top20_filted.csv')
countcats_flt.to_csv('Raw/Welgs_W-most_common-Top20_filted.csv')

# %%
countcats_flt
# Out:
#                                                              1   \
# "WILL POWER\n"                                  ((I’m, NNP), 3)
# ABSTINENCE                                   ((things, NNS), 8)
# ACCOUNTABILITY / Amends                      ((amends, NNS), 8)
# ACCOUNTABILITY / De-blame                     ((using, VBG), 3)
# ACCOUNTABILITY / Own up                     ((actions, NNS), 7)
# ACCOUNTABILITY / damage confess               ((been, VBN), 16)
# AGONY                                     ((depression, NN), 6)
# AMENDS                                      ((amends, NNS), 15)
# ANGER                                         ((anger, NN), 14)
# ANXIETY                                      ((anxiety, NN), 9)
# APOLOGY                                     ((friends, NNS), 1)
# BABY STEPS / Accomplishments                     ((one, CD), 6)
# BABY STEPS / Help & support                     ((who, WP), 10)
# BABY STEPS / first steps                     ((coaster, NN), 7)
# BABY STEPS / focus on today                  ((going, VBG), 12)
# BABY STEPS / slow changes                      ((time, NN), 11)
# BELIEFS                                     ((beliefs, NNS), 6)
# BENEFITS / COSTS                          ((decisions, NNS), 3)
# BINGE                                           ((life, NN), 4)
# BITTERNESS                                     ((truth, NN), 3)
# BLAME                                          ((blame, NN), 7)
# CHANGE / action & behavior                      ((life, NN), 6)
# CHANGE / beliefs                           ((beliefs, NNS), 13)
# CHANGE / courage                                ((God, NNP), 9)
# CHANGE / mental confidence                   ((drugs, NNS), 15)
# CHANGE / motivations                           ((life, NN), 16)
# CHANGE / self love & true self                ((that, WDT), 10)
# CHANGE / thoughts                         ((thoughts, NNS), 10)
# COMMITMENTS                                   ((drugs, NNS), 7)
# COMMUNITY / Meetings & groups               ((recovery, NN), 9)
# ...                                                         ...
# SOBRIETY / maintaining & will power             ((time, NN), 5)
# STRESS                                        ((stress, NN), 9)
# THOUGHTS                                  ((thoughts, NNS), 18)
# TRIGGERS / awareness                            ((what, WP), 8)
# TRIGGERS / confidence & strength          ((addiction, NN), 10)
# TRIGGERS / tools & techniques             ((triggers, NNS), 24)
# TRUST                                        ((things, NNS), 4)
# TRUTH / Admit addiction                    ((excuses, NNS), 11)
# TRUTH / Costs                                ((miracle, NN), 6)
# TRUTH / Inventory                          ((inventory, NN), 7)
# TRUTH / dark past                              ((life, NN), 17)
# TRUTH / self honesty                           ((life, NN), 14)
# URGES / moods & emotions                         ((pot, NN), 7)
# URGES / support & help                        ((afraid, JJ), 5)
# URGES / tools & techniques                    ((that, WDT), 13)
# VALUES                                    ((foundation, NN), 4)
# VULNERABILITY / Connection                 ((friends, NNS), 13)
# VULNERABILITY / Show true self              ((things, NNS), 10)
# VULNERABILITY / learning and mistakes      ((something, NN), 8)
# VULNERABILITY / others who’ve been there       ((when, WRB), 4)
# VULNERABILITY / to support my sobriety        ((when, WRB), 10)
# VULNERABILITY / worthy                          ((life, NN), 3)
# WARNINGS / Avoid triggers                    ((going, VBG), 14)
# WARNINGS / Relapse & tools                      ((drug, NN), 3)
# WARNINGS / self aware & listen                 ((when, WRB), 9)
# WORTHINESS / connections & sharing          ((people, NNS), 15)
# WORTHINESS / deserve & rewards                ((addict, NN), 5)
# WORTHINESS / help                           ((recovery, NN), 6)
# WORTHINESS / new life & future                 ((life, NN), 19)
# WORTHINESS / self love & acceptance        ((addiction, NN), 8)
#
#                                                                 2   \
# "WILL POWER\n"                                  ((better, JJR), 2)
# ABSTINENCE                                   ((abstinence, NN), 7)
# ACCOUNTABILITY / Amends                          ((going, VBG), 8)
# ACCOUNTABILITY / De-blame                         ((blame, NN), 3)
# ACCOUNTABILITY / Own up                       ((mistakes, NNS), 7)
# ACCOUNTABILITY / damage confess                 ((damage, NN), 15)
# AGONY                                            ((misery, NN), 6)
# AMENDS                                          ((making, VBG), 6)
# ANGER                                             ((angry, JJ), 5)
# ANXIETY                                       ((situation, NN), 6)
# APOLOGY                                           ((been, VBN), 1)
# BABY STEPS / Accomplishments                       ((step, NN), 5)
# BABY STEPS / Help & support                        ((life, NN), 9)
# BABY STEPS / first steps                          ((happy, JJ), 4)
# BABY STEPS / focus on today                       ((today, NN), 5)
# BABY STEPS / slow changes                          ((life, NN), 6)
# BELIEFS                                           ((right, JJ), 3)
# BENEFITS / COSTS                               ((recovery, NN), 3)
# BINGE                                             ((more, JJR), 4)
# BITTERNESS                                    ((beautiful, JJ), 2)
# BLAME                                              ((life, NN), 6)
# CHANGE / action & behavior                        ((When, WRB), 4)
# CHANGE / beliefs                             ((addiction, NN), 12)
# CHANGE / courage                                  ((that, WDT), 8)
# CHANGE / mental confidence                        ((life, NN), 12)
# CHANGE / motivations                            ((drugs, NNS), 13)
# CHANGE / self love & true self                   ((being, VBG), 8)
# CHANGE / thoughts                              ((negative, JJ), 7)
# COMMITMENTS                               ((gratification, NN), 6)
# COMMUNITY / Meetings & groups                 ((meetings, NNS), 7)
# ...                                                            ...
# SOBRIETY / maintaining & will power                ((life, NN), 4)
# STRESS                                            ((when, WRB), 6)
# THOUGHTS                                         ((that, WDT), 10)
# TRIGGERS / awareness                              ((when, WRB), 8)
# TRIGGERS / confidence & strength              ((triggers, NNS), 8)
# TRIGGERS / tools & techniques                    ((that, WDT), 13)
# TRUST                                              ((mood, NN), 4)
# TRUTH / Admit addiction                       ((recovery, NN), 10)
# TRUTH / Costs                                 ((feelings, NNS), 5)
# TRUTH / Inventory                                ((drugs, NNS), 6)
# TRUTH / dark past                                ((that, WDT), 14)
# TRUTH / self honesty                            ((person, NN), 10)
# URGES / moods & emotions                           ((what, WP), 4)
# URGES / support & help                           ((person, NN), 3)
# URGES / tools & techniques                      ((urges, NNS), 12)
# VALUES                                              ((new, JJ), 3)
# VULNERABILITY / Connection                    ((bridges, NNS), 11)
# VULNERABILITY / Show true self                     ((what, WP), 8)
# VULNERABILITY / learning and mistakes         ((mistakes, NNS), 8)
# VULNERABILITY / others who’ve been there        ((sponsor, NN), 4)
# VULNERABILITY / to support my sobriety              ((pot, NN), 7)
# VULNERABILITY / worthy                       ((hardships, NNS), 2)
# WARNINGS / Avoid triggers                        ((that, WDT), 12)
# WARNINGS / Relapse & tools                         ((much, JJ), 2)
# WARNINGS / self aware & listen                     ((what, WP), 7)
# WORTHINESS / connections & sharing            ((friends, NNS), 12)
# WORTHINESS / deserve & rewards                ((thoughts, NNS), 3)
# WORTHINESS / help                                  ((help, NN), 6)
# WORTHINESS / new life & future                     ((time, NN), 9)
# WORTHINESS / self love & acceptance               ((peace, NN), 7)
#
#                                                              3   \
# "WILL POWER\n"                                ((matter, NN), 1)
# ABSTINENCE                                    ((doing, VBG), 6)
# ACCOUNTABILITY / Amends                      ((people, NNS), 6)
# ACCOUNTABILITY / De-blame                       ((life, NN), 2)
# ACCOUNTABILITY / Own up                      ((things, NNS), 6)
# ACCOUNTABILITY / damage confess                ((life, NN), 14)
# AGONY                                          ((that, WDT), 5)
# AMENDS                                        ((going, VBG), 6)
# ANGER                                            ((way, NN), 5)
# ANXIETY                                      ((problem, NN), 5)
# APOLOGY                                       ((“amen”, NN), 1)
# BABY STEPS / Accomplishments                    ((life, NN), 3)
# BABY STEPS / Help & support                    ((when, WRB), 8)
# BABY STEPS / first steps                    ((recovery, NN), 4)
# BABY STEPS / focus on today                    ((that, WDT), 5)
# BABY STEPS / slow changes                       ((what, WP), 5)
# BELIEFS                                      ((beliefs, NN), 2)
# BENEFITS / COSTS                                ((life, NN), 2)
# BINGE                                             ((up, RP), 3)
# BITTERNESS                                     ((more, RBR), 2)
# BLAME                                          ((fault, NN), 4)
# CHANGE / action & behavior                   ((healthy, JJ), 4)
# CHANGE / beliefs                               ((life, NN), 12)
# CHANGE / courage                               ((when, WRB), 7)
# CHANGE / mental confidence                ((addiction, NN), 11)
# CHANGE / motivations                      ((addiction, NN), 13)
# CHANGE / self love & true self                 ((been, VBN), 6)
# CHANGE / thoughts                               ((life, NN), 6)
# COMMITMENTS                                     ((time, NN), 6)
# COMMUNITY / Meetings & groups                ((meeting, NN), 7)
# ...                                                         ...
# SOBRIETY / maintaining & will power           ((foods, NNS), 4)
# STRESS                                       ((things, NNS), 5)
# THOUGHTS                                        ((food, NN), 8)
# TRIGGERS / awareness                       ((addiction, NN), 8)
# TRIGGERS / confidence & strength             ((things, NNS), 7)
# TRIGGERS / tools & techniques                   ((life, NN), 9)
# TRUST                                           ((life, NN), 3)
# TRUTH / Admit addiction                        ((life, NN), 10)
# TRUTH / Costs                                   ((able, JJ), 5)
# TRUTH / Inventory                          ((addiction, NN), 5)
# TRUTH / dark past                         ((addiction, NN), 11)
# TRUTH / self honesty                           ((when, WRB), 9)
# URGES / moods & emotions                       ((that, WDT), 4)
# URGES / support & help                          ((urge, NN), 2)
# URGES / tools & techniques                ((something, NN), 10)
# VALUES                                          ((life, NN), 3)
# VULNERABILITY / Connection                      ((life, NN), 9)
# VULNERABILITY / Show true self                ((addict, NN), 8)
# VULNERABILITY / learning and mistakes       ((recovery, NN), 7)
# VULNERABILITY / others who’ve been there     ((program, NN), 3)
# VULNERABILITY / to support my sobriety       ((meeting, NN), 7)
# VULNERABILITY / worthy                          ((hard, JJ), 2)
# WARNINGS / Avoid triggers                 ((addiction, NN), 11)
# WARNINGS / Relapse & tools                    ((using, VBG), 2)
# WARNINGS / self aware & listen                   ((way, NN), 7)
# WORTHINESS / connections & sharing         ((recovery, NN), 11)
# WORTHINESS / deserve & rewards                   ((own, JJ), 3)
# WORTHINESS / help                              ((when, WRB), 5)
# WORTHINESS / new life & future                 ((clean, JJ), 7)
# WORTHINESS / self love & acceptance            ((inner, JJ), 7)
#
#                                                              4   \
# "WILL POWER\n"                                   ((way, NN), 1)
# ABSTINENCE                                      ((life, NN), 6)
# ACCOUNTABILITY / Amends                        ((detox, NN), 4)
# ACCOUNTABILITY / De-blame                   ((recovery, NN), 2)
# ACCOUNTABILITY / Own up                      ((someone, NN), 6)
# ACCOUNTABILITY / damage confess           ((addiction, NN), 12)
# AGONY                                           ((life, NN), 4)
# AMENDS                                       ((people, NNS), 6)
# ANGER                                       ((positive, JJ), 4)
# ANXIETY                                        ((more, JJR), 4)
# APOLOGY                                   ((apologies, NNS), 1)
# BABY STEPS / Accomplishments                   ((ways, NNS), 3)
# BABY STEPS / Help & support                 ((recovery, NN), 8)
# BABY STEPS / first steps                     ((bipolar, JJ), 4)
# BABY STEPS / focus on today                      ((pot, NN), 4)
# BABY STEPS / slow changes                      ((that, WDT), 5)
# BELIEFS                                       ((using, VBG), 2)
# BENEFITS / COSTS                                ((cost, NN), 2)
# BINGE                                         ((system, NN), 3)
# BITTERNESS                                    ((addict, NN), 2)
# BLAME                                       ((recovery, NN), 4)
# CHANGE / action & behavior                   ((stores, NNS), 3)
# CHANGE / beliefs                              ((when, WRB), 10)
# CHANGE / courage                            ((recovery, NN), 7)
# CHANGE / mental confidence                       ((up, RP), 10)
# CHANGE / motivations                       ((motives, NNS), 12)
# CHANGE / self love & true self                ((drugs, NNS), 6)
# CHANGE / thoughts                         ((negativity, NN), 3)
# COMMITMENTS                                     ((what, WP), 5)
# COMMUNITY / Meetings & groups                  ((when, WRB), 5)
# ...                                                         ...
# SOBRIETY / maintaining & will power             ((home, NN), 4)
# STRESS                                          ((time, NN), 5)
# THOUGHTS                                    ((recovery, NN), 7)
# TRIGGERS / awareness                           ((that, WDT), 7)
# TRIGGERS / confidence & strength             ((trigger, NN), 7)
# TRIGGERS / tools & techniques                  ((when, WRB), 6)
# TRUST                                          ((right, JJ), 3)
# TRUTH / Admit addiction                      ((problem, NN), 9)
# TRUTH / Costs                              ((addiction, NN), 5)
# TRUTH / Inventory                               ((What, WP), 4)
# TRUTH / dark past                          ((friends, NNS), 10)
# TRUTH / self honesty                         ((people, NNS), 8)
# URGES / moods & emotions                        ((plan, NN), 4)
# URGES / support & help                          ((fear, NN), 2)
# URGES / tools & techniques                      ((urge, NN), 9)
# VALUES                                        ((drugs, NNS), 2)
# VULNERABILITY / Connection                      ((what, WP), 9)
# VULNERABILITY / Show true self                ((years, NNS), 8)
# VULNERABILITY / learning and mistakes        ((amends, NNS), 6)
# VULNERABILITY / others who’ve been there       ((share, NN), 3)
# VULNERABILITY / to support my sobriety        ((going, VBG), 6)
# VULNERABILITY / worthy                          ((I’m, NNP), 2)
# WARNINGS / Avoid triggers                       ((pot, NN), 10)
# WARNINGS / Relapse & tools                      ((last, JJ), 2)
# WARNINGS / self aware & listen                 ((that, WDT), 7)
# WORTHINESS / connections & sharing             ((life, NN), 11)
# WORTHINESS / deserve & rewards              ((positive, JJ), 3)
# WORTHINESS / help                           ((friends, NNS), 4)
# WORTHINESS / new life & future                ((being, VBG), 6)
# WORTHINESS / self love & acceptance              ((who, WP), 6)
#
#                                                                  5   \
# "WILL POWER\n"                                      ((how, WRB), 1)
# ABSTINENCE                                      ((friends, NNS), 6)
# ACCOUNTABILITY / Amends                              ((who, WP), 4)
# ACCOUNTABILITY / De-blame                 ((responsibility, NN), 2)
# ACCOUNTABILITY / Own up                            ((When, WRB), 6)
# ACCOUNTABILITY / damage confess                ((friends, NNS), 10)
# AGONY                                                ((way, NN), 4)
# AMENDS                                              ((what, WP), 5)
# ANGER                                              ((more, RBR), 4)
# ANXIETY                                            ((When, WRB), 4)
# APOLOGY                                            ((first, JJ), 1)
# BABY STEPS / Accomplishments                       ((wins, NNS), 3)
# BABY STEPS / Help & support                        ((been, VBN), 7)
# BABY STEPS / first steps                           ((small, JJ), 4)
# BABY STEPS / focus on today                         ((life, NN), 3)
# BABY STEPS / slow changes                            ((one, CD), 5)
# BELIEFS                                         ((negative, JJ), 2)
# BENEFITS / COSTS                                   ((when, WRB), 2)
# BINGE                                              ((when, WRB), 3)
# BITTERNESS                                        ((bitter, JJ), 2)
# BLAME                                             ((nobody, NN), 3)
# CHANGE / action & behavior                     ((emotional, JJ), 3)
# CHANGE / beliefs                                 ((things, NNS), 9)
# CHANGE / courage                                    ((life, NN), 6)
# CHANGE / mental confidence                        ((when, WRB), 10)
# CHANGE / motivations                                 ((up, RP), 11)
# CHANGE / self love & true self                      ((life, NN), 5)
# CHANGE / thoughts                                   ((free, JJ), 3)
# COMMITMENTS                                       ((doing, VBG), 4)
# COMMUNITY / Meetings & groups                      ((anger, NN), 5)
# ...                                                             ...
# SOBRIETY / maintaining & will power                  ((way, NN), 4)
# STRESS                                              ((work, NN), 4)
# THOUGHTS                                        ((negative, JJ), 6)
# TRIGGERS / awareness                           ((thoughts, NNS), 7)
# TRIGGERS / confidence & strength                    ((life, NN), 5)
# TRIGGERS / tools & techniques                   ((recovery, NN), 6)
# TRUST                                          ((potential, JJ), 2)
# TRUTH / Admit addiction                           ((drugs, NNS), 9)
# TRUTH / Costs                                       ((life, NN), 4)
# TRUTH / Inventory                                ((nothing, NN), 4)
# TRUTH / dark past                                 ((been, VBN), 10)
# TRUTH / self honesty                             ((others, NNS), 8)
# URGES / moods & emotions                          ((urges, NNS), 4)
# URGES / support & help                              ((help, NN), 2)
# URGES / tools & techniques                            ((up, RP), 8)
# VALUES                                               ((one, CD), 2)
# VULNERABILITY / Connection                         ((that, WDT), 7)
# VULNERABILITY / Show true self                  ((friends, NNS), 7)
# VULNERABILITY / learning and mistakes            ((someone, NN), 6)
# VULNERABILITY / others who’ve been there       ((thoughts, NNS), 3)
# VULNERABILITY / to support my sobriety         ((addiction, NN), 6)
# VULNERABILITY / worthy                            ((worthy, JJ), 2)
# WARNINGS / Avoid triggers                     ((triggers, NNS), 10)
# WARNINGS / Relapse & tools                        ((drugs, NNS), 2)
# WARNINGS / self aware & listen                 ((addiction, NN), 7)
# WORTHINESS / connections & sharing              ((others, NNS), 11)
# WORTHINESS / deserve & rewards                 ((conducive, JJ), 2)
# WORTHINESS / help                                   ((hand, NN), 3)
# WORTHINESS / new life & future                      ((how, WRB), 6)
# WORTHINESS / self love & acceptance            ((feelings, NNS), 5)
#
#                                                                  6   \
# "WILL POWER\n"                                      ((deaf, NN), 1)
# ABSTINENCE                                        ((drugs, NNS), 6)
# ACCOUNTABILITY / Amends                             ((what, WP), 4)
# ACCOUNTABILITY / De-blame                           ((part, NN), 2)
# ACCOUNTABILITY / Own up                   ((responsibility, NN), 6)
# ACCOUNTABILITY / damage confess                  ((drugs, NNS), 10)
# AGONY                                              ((when, WRB), 4)
# AMENDS                                             ((that, WDT), 5)
# ANGER                                            ((feeling, NN), 4)
# ANXIETY                                          ((exiled, VBN), 3)
# APOLOGY                                            ((rehab, NN), 1)
# BABY STEPS / Accomplishments                      ((little, JJ), 3)
# BABY STEPS / Help & support                      ((people, NNS), 7)
# BABY STEPS / first steps                             ((new, JJ), 3)
# BABY STEPS / focus on today                     ((tomorrow, NN), 3)
# BABY STEPS / slow changes                          ((when, WRB), 4)
# BELIEFS                                              ((old, JJ), 2)
# BENEFITS / COSTS                                  ((matter, NN), 1)
# BINGE                                              ((binge, NN), 3)
# BITTERNESS                                          ((gold, NN), 1)
# BLAME                                            ((problem, NN), 3)
# CHANGE / action & behavior                          ((how, WRB), 3)
# CHANGE / beliefs                                ((recovery, NN), 8)
# CHANGE / courage                                      ((up, RP), 5)
# CHANGE / mental confidence                          ((what, WP), 9)
# CHANGE / motivations                               ((time, NN), 11)
# CHANGE / self love & true self                   ((layers, NNS), 5)
# CHANGE / thoughts                                  ((when, WRB), 3)
# COMMITMENTS                                       ((years, NNS), 4)
# COMMUNITY / Meetings & groups                       ((I’m, NNP), 4)
# ...                                                             ...
# SOBRIETY / maintaining & will power                ((anger, NN), 4)
# STRESS                                               ((day, NN), 4)
# THOUGHTS                                         ((thought, NN), 6)
# TRIGGERS / awareness                                ((food, NN), 7)
# TRIGGERS / confidence & strength                   ((when, WRB), 5)
# TRIGGERS / tools & techniques                    ((problem, NN), 6)
# TRUST                                               ((time, NN), 2)
# TRUTH / Admit addiction                           ((addict, NN), 8)
# TRUTH / Costs                                       ((what, WP), 4)
# TRUTH / Inventory                                   ((how, WRB), 3)
# TRUTH / dark past                                    ((out, RP), 9)
# TRUTH / self honesty                             ((honesty, NN), 7)
# URGES / moods & emotions                             ((out, RP), 3)
# URGES / support & help                             ((tough, JJ), 2)
# URGES / tools & techniques                          ((life, NN), 7)
# VALUES                                            ((ideas, NNS), 2)
# VULNERABILITY / Connection                       ((people, NNS), 7)
# VULNERABILITY / Show true self                     ((when, WRB), 7)
# VULNERABILITY / learning and mistakes     ((responsibility, NN), 6)
# VULNERABILITY / others who’ve been there         ((relapse, NN), 3)
# VULNERABILITY / to support my sobriety              ((life, NN), 6)
# VULNERABILITY / worthy                              ((hand, NN), 2)
# WARNINGS / Avoid triggers                           ((one, CD), 10)
# WARNINGS / Relapse & tools                        ((doing, VBG), 2)
# WARNINGS / self aware & listen                     ((When, WRB), 6)
# WORTHINESS / connections & sharing             ((addiction, NN), 9)
# WORTHINESS / deserve & rewards                  ((thinking, NN), 2)
# WORTHINESS / help                                   ((life, NN), 3)
# WORTHINESS / new life & future                   ((things, NNS), 5)
# WORTHINESS / self love & acceptance                 ((life, NN), 4)
#
#                                                                  7   \
# "WILL POWER\n"                                 ((listening, NN), 1)
# ABSTINENCE                                           ((way, NN), 6)
# ACCOUNTABILITY / Amends                           ((damage, NN), 4)
# ACCOUNTABILITY / De-blame                           ((game, NN), 2)
# ACCOUNTABILITY / Own up                              ((own, JJ), 6)
# ACCOUNTABILITY / damage confess                   ((years, NNS), 8)
# AGONY                                              ((more, RBR), 4)
# AMENDS                                         ((mistakes, NNS), 5)
# ANGER                                             ((Anger, NNP), 4)
# ANXIETY                                            ((that, WDT), 3)
# APOLOGY                                            ((when, WRB), 1)
# BABY STEPS / Accomplishments                      ((steps, NNS), 3)
# BABY STEPS / Help & support                        ((that, WDT), 6)
# BABY STEPS / first steps                        ((bridges, NNS), 3)
# BABY STEPS / focus on today                         ((room, NN), 3)
# BABY STEPS / slow changes                       ((recovery, NN), 4)
# BELIEFS                                         ((working, VBG), 2)
# BENEFITS / COSTS                                ((sobriety, NN), 1)
# BINGE                                              ((sugar, NN), 3)
# BITTERNESS                                         ((told, VBN), 1)
# BLAME                                            ((things, NNS), 3)
# CHANGE / action & behavior                        ((mental, JJ), 3)
# CHANGE / beliefs                                   ((that, WDT), 8)
# CHANGE / courage                                    ((what, WP), 5)
# CHANGE / mental confidence                          ((how, WRB), 9)
# CHANGE / motivations                         ((motivation, NN), 10)
# CHANGE / self love & true self                     ((there, EX), 5)
# CHANGE / thoughts                                   ((how, WRB), 3)
# COMMITMENTS                                      ((things, NNS), 4)
# COMMUNITY / Meetings & groups                        ((who, WP), 4)
# ...                                                             ...
# SOBRIETY / maintaining & will power                ((detox, NN), 3)
# STRESS                                         ((triggers, NNS), 4)
# THOUGHTS                                             ((new, JJ), 6)
# TRIGGERS / awareness                           ((triggers, NNS), 6)
# TRIGGERS / confidence & strength                   ((that, WDT), 5)
# TRIGGERS / tools & techniques                       ((how, WRB), 6)
# TRUST                                               ((able, JJ), 2)
# TRUTH / Admit addiction                             ((news, NN), 7)
# TRUTH / Costs                                         ((up, RP), 3)
# TRUTH / Inventory                                   ((life, NN), 3)
# TRUTH / dark past                                 ((drugs, NNS), 8)
# TRUTH / self honesty                            ((friends, NNS), 7)
# URGES / moods & emotions                            ((food, NN), 3)
# URGES / support & help                    ((relationships, NNS), 2)
# URGES / tools & techniques                           ((pot, NN), 7)
# VALUES                                               ((way, NN), 1)
# VULNERABILITY / Connection                          ((able, JJ), 6)
# VULNERABILITY / Show true self                     ((there, EX), 7)
# VULNERABILITY / learning and mistakes            ((people, NNS), 6)
# VULNERABILITY / others who’ve been there        ((recovery, NN), 3)
# VULNERABILITY / to support my sobriety           ((someone, NN), 5)
# VULNERABILITY / worthy                         ((drinking, VBG), 1)
# WARNINGS / Avoid triggers                             ((up, RP), 9)
# WARNINGS / Relapse & tools                          ((side, NN), 2)
# WARNINGS / self aware & listen                      ((life, NN), 6)
# WORTHINESS / connections & sharing                  ((what, WP), 8)
# WORTHINESS / deserve & rewards                       ((new, JJ), 2)
# WORTHINESS / help                                ((people, NNS), 3)
# WORTHINESS / new life & future                  ((recovery, NN), 5)
# WORTHINESS / self love & acceptance              ((things, NNS), 4)
#
#                                                                  8   \
# "WILL POWER\n"                                     ((tough, JJ), 1)
# ABSTINENCE                                         ((that, WDT), 5)
# ACCOUNTABILITY / Amends                         ((behavior, NN), 4)
# ACCOUNTABILITY / De-blame                      ((Ditching, VBG), 2)
# ACCOUNTABILITY / Own up                             ((time, NN), 6)
# ACCOUNTABILITY / damage confess               ((hardships, NNS), 6)
# AGONY                                          ((cravings, NNS), 4)
# AMENDS                                           ((others, NNS), 5)
# ANGER                                               ((life, NN), 3)
# ANXIETY                                             ((pain, NN), 3)
# APOLOGY                                        ((integrity, NN), 1)
# BABY STEPS / Accomplishments                    ((anything, NN), 2)
# BABY STEPS / Help & support                       ((drugs, NNS), 6)
# BABY STEPS / first steps                       ((addiction, NN), 3)
# BABY STEPS / focus on today                    ((thoughts, NNS), 2)
# BABY STEPS / slow changes                            ((day, NN), 4)
# BELIEFS                                              ((one, CD), 2)
# BENEFITS / COSTS                               ((changing, VBG), 1)
# BINGE                                           ((recovery, NN), 3)
# BITTERNESS                                      ((telltale, JJ), 1)
# BLAME                                             ((using, VBG), 3)
# CHANGE / action & behavior                        ((liquor, NN), 3)
# CHANGE / beliefs                                 ((people, NNS), 8)
# CHANGE / courage                                    ((I’m, NNP), 5)
# CHANGE / mental confidence                     ((feelings, NNS), 9)
# CHANGE / motivations                               ((that, WDT), 9)
# CHANGE / self love & true self                 ((addiction, NN), 5)
# CHANGE / thoughts                                    ((way, NN), 3)
# COMMITMENTS                                        ((when, WRB), 4)
# COMMUNITY / Meetings & groups                      ((more, RBR), 4)
# ...                                                             ...
# SOBRIETY / maintaining & will power                 ((last, JJ), 3)
# STRESS                                              ((what, WP), 3)
# THOUGHTS                                            ((life, NN), 6)
# TRIGGERS / awareness                                ((life, NN), 4)
# TRIGGERS / confidence & strength                     ((pot, NN), 5)
# TRIGGERS / tools & techniques                      ((more, JJR), 5)
# TRUST                                                ((way, NN), 2)
# TRUTH / Admit addiction                             ((food, NN), 6)
# TRUTH / Costs                                    ((things, NNS), 3)
# TRUTH / Inventory                                 ((reason, NN), 3)
# TRUTH / dark past                                ((people, NNS), 8)
# TRUTH / self honesty                                ((time, NN), 7)
# URGES / moods & emotions                          ((doing, VBG), 3)
# URGES / support & help                          ((contrary, JJ), 1)
# URGES / tools & techniques                       ((control, NN), 6)
# VALUES                                            ((going, VBG), 1)
# VULNERABILITY / Connection                ((relationships, NNS), 6)
# VULNERABILITY / Show true self                     ((been, VBN), 6)
# VULNERABILITY / learning and mistakes          ((addiction, NN), 6)
# VULNERABILITY / others who’ve been there         ((thought, NN), 3)
# VULNERABILITY / to support my sobriety           ((support, NN), 5)
# VULNERABILITY / worthy                         ((another’s, JJ), 1)
# WARNINGS / Avoid triggers                          ((when, WRB), 8)
# WARNINGS / Relapse & tools                        ((years, NNS), 2)
# WARNINGS / self aware & listen                        ((up, RP), 5)
# WORTHINESS / connections & sharing               ((things, NNS), 8)
# WORTHINESS / deserve & rewards              ((reinforcing, VBG), 2)
# WORTHINESS / help                                ((sponsor, NN), 3)
# WORTHINESS / new life & future                     ((When, WRB), 5)
# WORTHINESS / self love & acceptance                 ((self, NN), 4)
#
#                                                                   9   \
# "WILL POWER\n"                                   ((listener, NN), 1)
# ABSTINENCE                                      ((addiction, NN), 5)
# ACCOUNTABILITY / Amends                              ((how, WRB), 4)
# ACCOUNTABILITY / De-blame                       ((something, NN), 2)
# ACCOUNTABILITY / Own up                       ((accountable, JJ), 5)
# ACCOUNTABILITY / damage confess                     ((that, WDT), 6)
# AGONY                                           ((addiction, NN), 4)
# AMENDS                                               ((past, JJ), 4)
# ANGER                                                ((God, NNP), 3)
# ANXIETY                                            ((being, VBG), 2)
# APOLOGY                                            ((honest, JJ), 1)
# BABY STEPS / Accomplishments                       ((drugs, NNS), 2)
# BABY STEPS / Help & support                       ((support, NN), 6)
# BABY STEPS / first steps                             ((time, NN), 3)
# BABY STEPS / focus on today                            ((up, RP), 2)
# BABY STEPS / slow changes                            ((food, NN), 4)
# BELIEFS                                            ((matter, NN), 1)
# BENEFITS / COSTS                                    ((Today, NN), 1)
# BINGE                                                ((lazy, JJ), 3)
# BITTERNESS                                     ((experience, NN), 1)
# BLAME                                            ((anything, NN), 2)
# CHANGE / action & behavior                       ((physical, JJ), 3)
# CHANGE / beliefs                                   ((belief, NN), 7)
# CHANGE / courage                                 ((changes, NNS), 5)
# CHANGE / mental confidence                         ((addict, NN), 7)
# CHANGE / motivations                                 ((what, WP), 8)
# CHANGE / self love & true self                      ((thing, NN), 5)
# CHANGE / thoughts                                   ((there, EX), 3)
# COMMITMENTS                                           ((try, NN), 4)
# COMMUNITY / Meetings & groups                    ((building, NN), 4)
# ...                                                              ...
# SOBRIETY / maintaining & will power                    ((up, RP), 3)
# STRESS                                          ((feelings, NNS), 3)
# THOUGHTS                                             ((what, WP), 5)
# TRIGGERS / awareness                              ((things, NNS), 4)
# TRIGGERS / confidence & strength                      ((one, CD), 5)
# TRIGGERS / tools & techniques                     ((things, NNS), 5)
# TRUST                                            ((negative, JJ), 2)
# TRUTH / Admit addiction                              ((what, WP), 5)
# TRUTH / Costs                                         ((who, WP), 3)
# TRUTH / Inventory                                   ((When, WRB), 3)
# TRUTH / dark past                                 ((miracle, NN), 6)
# TRUTH / self honesty                            ((addiction, NN), 7)
# URGES / moods & emotions                            ((days, NNS), 3)
# URGES / support & help                            ((losing, VBG), 1)
# URGES / tools & techniques                      ((addiction, NN), 6)
# VALUES                                               ((only, JJ), 1)
# VULNERABILITY / Connection                      ((feelings, NNS), 5)
# VULNERABILITY / Show true self                       ((food, NN), 6)
# VULNERABILITY / learning and mistakes            ((actions, NNS), 5)
# VULNERABILITY / others who’ve been there             ((same, JJ), 2)
# VULNERABILITY / to support my sobriety              ((more, RBR), 5)
# VULNERABILITY / worthy                              ((Earth, NN), 1)
# WARNINGS / Avoid triggers                         ((things, NNS), 8)
# WARNINGS / Relapse & tools                            ((six, CD), 2)
# WARNINGS / self aware & listen                       ((hard, JJ), 5)
# WORTHINESS / connections & sharing                    ((who, WP), 8)
# WORTHINESS / deserve & rewards            ((self-confidence, NN), 2)
# WORTHINESS / help                                  ((strong, JJ), 3)
# WORTHINESS / new life & future                      ((today, NN), 4)
# WORTHINESS / self love & acceptance                 ((that, WDT), 4)
#
#                                                                  10  \
# "WILL POWER\n"                                      ((what, WP), 1)
# ABSTINENCE                                           ((who, WP), 5)
# ACCOUNTABILITY / Amends                          ((others, NNS), 4)
# ACCOUNTABILITY / De-blame                 ((back-and-forth, JJ), 1)
# ACCOUNTABILITY / Own up                             ((how, WRB), 5)
# ACCOUNTABILITY / damage confess                       ((up, RP), 5)
# AGONY                                                ((one, CD), 4)
# AMENDS                                             ((when, WRB), 4)
# ANGER                                              ((When, WRB), 3)
# ANXIETY                                          ((program, NN), 2)
# APOLOGY                                          ((crying, VBG), 1)
# BABY STEPS / Accomplishments                        ((size, NN), 2)
# BABY STEPS / Help & support                          ((lot, NN), 6)
# BABY STEPS / first steps                        ((towards, NNS), 3)
# BABY STEPS / focus on today                      ((things, NNS), 2)
# BABY STEPS / slow changes                         ((doing, VBG), 3)
# BELIEFS                                         ((sobriety, NN), 1)
# BENEFITS / COSTS                               ((potential, JJ), 1)
# BINGE                                               ((head, NN), 2)
# BITTERNESS                                        ((choice, NN), 1)
# BLAME                                               ((part, NN), 2)
# CHANGE / action & behavior                       ((seeing, VBG), 2)
# CHANGE / beliefs                                     ((new, JJ), 6)
# CHANGE / courage                                   ((more, JJR), 4)
# CHANGE / mental confidence                          ((time, NN), 6)
# CHANGE / motivations                           ((something, NN), 8)
# CHANGE / self love & true self                    ((years, NNS), 4)
# CHANGE / thoughts                               ((actions, NNS), 2)
# COMMITMENTS                                        ((more, JJR), 4)
# COMMUNITY / Meetings & groups                    ((support, NN), 4)
# ...                                                             ...
# SOBRIETY / maintaining & will power            ((fighting, VBG), 3)
# STRESS                                             ((that, WDT), 3)
# THOUGHTS                                           ((when, WRB), 5)
# TRIGGERS / awareness                           ((feelings, NNS), 4)
# TRIGGERS / confidence & strength                   ((ways, NNS), 4)
# TRIGGERS / tools & techniques                     ((stress, NN), 5)
# TRUST                                           ((recovery, NN), 2)
# TRUTH / Admit addiction                          ((better, JJR), 5)
# TRUTH / Costs                                        ((pot, NN), 3)
# TRUTH / Inventory                                  ((lost, VBN), 3)
# TRUTH / dark past                                   ((what, WP), 6)
# TRUTH / self honesty                               ((that, WDT), 7)
# URGES / moods & emotions                       ((feelings, NNS), 3)
# URGES / support & help                          ((anything, NN), 1)
# URGES / tools & techniques                          ((easy, JJ), 6)
# VALUES                                            ((career, NN), 1)
# VULNERABILITY / Connection                     ((cravings, NNS), 4)
# VULNERABILITY / Show true self                      ((life, NN), 6)
# VULNERABILITY / learning and mistakes               ((life, NN), 5)
# VULNERABILITY / others who’ve been there         ((better, RBR), 2)
# VULNERABILITY / to support my sobriety               (('s, POS), 5)
# VULNERABILITY / worthy                            ((least, JJS), 1)
# WARNINGS / Avoid triggers                        ((disease, NN), 7)
# WARNINGS / Relapse & tools                         ((days, NNS), 2)
# WARNINGS / self aware & listen                  ((recovery, NN), 5)
# WORTHINESS / connections & sharing                 ((that, WDT), 7)
# WORTHINESS / deserve & rewards                   ((labels, NNS), 2)
# WORTHINESS / help                         ((relationships, NNS), 3)
# WORTHINESS / new life & future                 ((thoughts, NNS), 4)
# WORTHINESS / self love & acceptance               ((drugs, NNS), 4)
#
#                                                              11  \
# "WILL POWER\n"                                   ((gut, NN), 1)
# ABSTINENCE                                        ((up, RP), 4)
# ACCOUNTABILITY / Amends                     ((friends, NNS), 4)
# ACCOUNTABILITY / De-blame                       ((kept, FW), 1)
# ACCOUNTABILITY / Own up                      ((making, VBG), 5)
# ACCOUNTABILITY / damage confess                 ((how, WRB), 5)
# AGONY                                            ((day, NN), 4)
# AMENDS                                       ((someone, NN), 4)
# ANGER                                        ((emotion, NN), 3)
# ANXIETY                                         ((life, NN), 2)
# APOLOGY                                                    None
# BABY STEPS / Accomplishments              ((confidence, NN), 2)
# BABY STEPS / Help & support                ((addiction, NN), 5)
# BABY STEPS / first steps                         ((way, NN), 3)
# BABY STEPS / focus on today                      ((way, NN), 2)
# BABY STEPS / slow changes                   ((Getting, VBG), 3)
# BELIEFS                                    ((changing, VBG), 1)
# BENEFITS / COSTS                               ((money, NN), 1)
# BINGE                                         ((being, VBG), 2)
# BITTERNESS                                      ((head, NN), 1)
# BLAME                                          ((other, JJ), 2)
# CHANGE / action & behavior                     ((other, JJ), 2)
# CHANGE / beliefs                                ((free, JJ), 6)
# CHANGE / courage                                 ((one, CD), 4)
# CHANGE / mental confidence                   ((things, NNS), 6)
# CHANGE / motivations                             ((who, WP), 8)
# CHANGE / self love & true self               ((things, NNS), 4)
# CHANGE / thoughts                               ((able, JJ), 2)
# COMMITMENTS                                ((something, NN), 4)
# COMMUNITY / Meetings & groups                ((others, NNS), 4)
# ...                                                         ...
# SOBRIETY / maintaining & will power         ((fighting, JJ), 2)
# STRESS                                          ((much, JJ), 3)
# THOUGHTS                                     ((things, NNS), 5)
# TRIGGERS / awareness                         ((people, NNS), 4)
# TRIGGERS / confidence & strength                ((how, WRB), 4)
# TRIGGERS / tools & techniques                 ((being, VBG), 4)
# TRUST                                           ((etc., FW), 2)
# TRUTH / Admit addiction                        ((more, JJR), 5)
# TRUTH / Costs                                 ((going, VBG), 3)
# TRUTH / Inventory                              ((lies, NNS), 2)
# TRUTH / dark past                             ((damage, NN), 6)
# TRUTH / self honesty                          ((addict, NN), 6)
# URGES / moods & emotions                      ((little, JJ), 3)
# URGES / support & help                          ((huge, JJ), 1)
# URGES / tools & techniques                      ((what, WP), 5)
# VALUES                                    ((fragments, NNS), 1)
# VULNERABILITY / Connection                      ((dope, NN), 4)
# VULNERABILITY / Show true self             ((something, NN), 5)
# VULNERABILITY / learning and mistakes         ((afraid, JJ), 5)
# VULNERABILITY / others who’ve been there    ((working, VBG), 2)
# VULNERABILITY / to support my sobriety         ((that, WDT), 5)
# VULNERABILITY / worthy                      ((strength, NN), 1)
# WARNINGS / Avoid triggers                     ((foods, NNS), 7)
# WARNINGS / Relapse & tools                     ((binge, NN), 2)
# WARNINGS / self aware & listen                ((little, JJ), 5)
# WORTHINESS / connections & sharing             ((when, WRB), 6)
# WORTHINESS / deserve & rewards               ((helpful, JJ), 2)
# WORTHINESS / help                            ((Asking, VBG), 2)
# WORTHINESS / new life & future                  ((I’m, NNP), 4)
# WORTHINESS / self love & acceptance                ((–, NN), 4)
#
#                                                             12  \
# "WILL POWER\n"                                 ((part, NN), 1)
# ABSTINENCE                                   ((reward, NN), 4)
# ACCOUNTABILITY / Amends                   ((addiction, NN), 4)
# ACCOUNTABILITY / De-blame                    ((victim, NN), 1)
# ACCOUNTABILITY / Own up                    ((recovery, NN), 5)
# ACCOUNTABILITY / damage confess             ((problem, NN), 5)
# AGONY                                     ((unhealthy, JJ), 3)
# ...
# BABY STEPS / slow changes                            ((–, JJ), 3)
# BELIEFS                                            ((new, JJ), 1)
# BENEFITS / COSTS                               ((account, NN), 1)
# BINGE                                              ((who, WP), 2)
# BITTERNESS                                      ((middle, JJ), 1)
# BLAME                                            ((when, WRB), 2)
# CHANGE / action & behavior                     ((things, NNS), 2)
# CHANGE / beliefs                               ((mindset, NN), 5)
# CHANGE / courage                                    ((–, NNP), 3)
# CHANGE / mental confidence                       ((been, VBN), 5)
# CHANGE / motivations                            ((using, VBG), 6)
# CHANGE / self love & true self                     ((day, NN), 4)
# CHANGE / thoughts                              ((things, NNS), 2)
# COMMITMENTS                                       ((dope, NN), 3)
# COMMUNITY / Meetings & groups                     ((life, NN), 3)
# ...                                                           ...
# SOBRIETY / maintaining & will power           ((sobriety, NN), 2)
# STRESS                                            ((life, NN), 2)
# THOUGHTS                                         ((been, VBN), 4)
# TRIGGERS / awareness                           ((comfort, NN), 3)
# TRIGGERS / confidence & strength               ((easier, JJR), 3)
# TRIGGERS / tools & techniques                  ((trigger, NN), 4)
# TRUST                                             ((much, JJ), 1)
# TRUTH / Admit addiction                            ((one, CD), 5)
# TRUTH / Costs                                    ((great, JJ), 2)
# TRUTH / Inventory                              ((better, JJR), 2)
# TRUTH / dark past                                ((money, NN), 5)
# TRUTH / self honesty                              ((help, NN), 5)
# URGES / moods & emotions                            ((up, RP), 2)
# URGES / support & help                         ((serious, JJ), 1)
# URGES / tools & techniques                        ((good, JJ), 5)
# VALUES                                        ((musician, NN), 1)
# VULNERABILITY / Connection                   ((addiction, NN), 4)
# VULNERABILITY / Show true self                ((conflict, NN), 5)
# VULNERABILITY / learning and mistakes             ((past, JJ), 4)
# VULNERABILITY / others who’ve been there         ((When, WRB), 2)
# VULNERABILITY / to support my sobriety             ((own, JJ), 4)
# VULNERABILITY / worthy                          ((gotten, NN), 1)
# WARNINGS / Avoid triggers                       ((doing, VBG), 5)
# WARNINGS / Relapse & tools                       ((that, WDT), 2)
# WARNINGS / self aware & listen                    ((part, NN), 5)
# WORTHINESS / connections & sharing                 ((new, JJ), 5)
# WORTHINESS / deserve & rewards            ((encouraging, VBG), 2)
# WORTHINESS / help                            ((important, JJ), 2)
# WORTHINESS / new life & future                   ((ways, NNS), 3)
# WORTHINESS / self love & acceptance              ((Today, NN), 3)
#
#                                                                18  \
# "WILL POWER\n"                                   ((more, RBR), 1)
# ABSTINENCE                                        ((time, NN), 4)
# ACCOUNTABILITY / Amends                          ((that, WDT), 3)
# ACCOUNTABILITY / De-blame                      ((better, RBR), 1)
# ACCOUNTABILITY / Own up                      ((hostility, NN), 4)
# ACCOUNTABILITY / damage confess                ((others, NNS), 5)
# AGONY                                             ((food, NN), 3)
# AMENDS                                         ((Making, VBG), 3)
# ANGER                                            ((order, NN), 2)
# ANXIETY                                       ((solution, NN), 2)
# APOLOGY                                                      None
# BABY STEPS / Accomplishments                     ((point, NN), 2)
# BABY STEPS / Help & support                       ((I’m, NNP), 4)
# BABY STEPS / first steps                    ((girlfriend, NN), 2)
# BABY STEPS / focus on today                        ((day, NN), 2)
# BABY STEPS / slow changes                    ((addiction, NN), 3)
# BELIEFS                                         ((drugs, NNS), 1)
# BENEFITS / COSTS                                  ((how, WRB), 1)
# BINGE                                          ((husband, NN), 2)
# BITTERNESS                                        ((life, NN), 1)
# BLAME                                          ((someone, NN), 2)
# CHANGE / action & behavior                      ((action, NN), 2)
# CHANGE / beliefs                                   (('s, POS), 5)
# CHANGE / courage                                 ((clean, JJ), 3)
# CHANGE / mental confidence                       ((brain, NN), 5)
# CHANGE / motivations                               (('s, POS), 6)
# CHANGE / self love & true self                    ((past, NN), 4)
# CHANGE / thoughts                                 ((step, NN), 2)
# COMMITMENTS                                       ((drug, NN), 3)
# COMMUNITY / Meetings & groups                ((important, JJ), 3)
# ...                                                           ...
# SOBRIETY / maintaining & will power              ((more, RBR), 2)
# STRESS                                            ((God, NNP), 2)
# THOUGHTS                                           ((way, NN), 4)
# TRIGGERS / awareness                          ((negative, JJ), 2)
# TRIGGERS / confidence & strength              ((recovery, NN), 3)
# TRIGGERS / tools & techniques                  ((people, NNS), 4)
# TRUST                                        ((confident, JJ), 1)
# TRUTH / Admit addiction                         ((doing, VBG), 4)
# TRUTH / Costs                             ((suppressing, VBG), 2)
# TRUTH / Inventory                             ((secrets, NNS), 2)
# TRUTH / dark past                                ((left, VBN), 5)
# TRUTH / self honesty                               ((who, WP), 5)
# URGES / moods & emotions                     ((emotions, NNS), 2)
# URGES / support & help                            ((half, JJ), 1)
# URGES / tools & techniques                         ((bad, JJ), 5)
# VALUES                                             ((old, JJ), 1)
# VULNERABILITY / Connection                       ((today, NN), 3)
# VULNERABILITY / Show true self               ((problems, NNS), 5)
# VULNERABILITY / learning and mistakes              ((pot, NN), 4)
# VULNERABILITY / others who’ve been there         ((that, WDT), 2)
# VULNERABILITY / to support my sobriety            ((help, NN), 4)
# VULNERABILITY / worthy                         ((head-on, JJ), 1)
# WARNINGS / Avoid triggers                        ((more, JJR), 5)
# WARNINGS / Relapse & tools                        ((food, NN), 2)
# WARNINGS / self aware & listen                    ((time, NN), 4)
# WORTHINESS / connections & sharing                   ((–, NN), 5)
# WORTHINESS / deserve & rewards                    ((role, NN), 2)
# WORTHINESS / help                                  ((who, WP), 2)
# WORTHINESS / new life & future                    ((fate, NN), 3)
# WORTHINESS / self love & acceptance              ((first, JJ), 3)
#
#                                                                19  \
# "WILL POWER\n"                                  ((little, JJ), 1)
# ABSTINENCE                                      ((charge, NN), 4)
# ACCOUNTABILITY / Amends                            ((way, NN), 3)
# ACCOUNTABILITY / De-blame                       ((given, VBN), 1)
# ACCOUNTABILITY / Own up                            ((who, WP), 4)
# ACCOUNTABILITY / damage confess                  ((detox, NN), 4)
# AGONY                                        ((beautiful, JJ), 2)
# AMENDS                                            ((list, NN), 3)
# ANGER                                           ((person, NN), 2)
# ANXIETY                                         ((exiler, NN), 2)
# APOLOGY                                                      None
# BABY STEPS / Accomplishments                  ((recovery, NN), 2)
# BABY STEPS / Help & support                   ((building, NN), 4)
# BABY STEPS / first steps                       ((journey, NN), 2)
# BABY STEPS / focus on today                      ((there, EX), 2)
# BABY STEPS / slow changes                         ((baby, JJ), 3)
# BELIEFS                                           ((what, WP), 1)
# BENEFITS / COSTS                          ((habits/using, NN), 1)
# BINGE                                           ((excess, JJ), 2)
# BITTERNESS                                       ((MIS-, NNP), 1)
# BLAME                                        ((Ditching, VBG), 2)
# CHANGE / action & behavior                        ((mind, NN), 2)
# CHANGE / beliefs                               ((others, NNS), 5)
# CHANGE / courage                                ((turkey, NN), 3)
# CHANGE / mental confidence                      ((being, VBG), 4)
# CHANGE / motivations                           ((people, NNS), 6)
# CHANGE / self love & true self                ((positive, JJ), 4)
# CHANGE / thoughts                                 ((time, NN), 2)
# COMMITMENTS                                       ((lazy, JJ), 3)
# COMMUNITY / Meetings & groups              ((recovering, VBG), 3)
# ...                                                           ...
# SOBRIETY / maintaining & will power              ((been, VBN), 2)
# STRESS                                        ((getting, VBG), 2)
# THOUGHTS                                     ((conducive, JJ), 3)
# TRIGGERS / awareness                              ((why, WRB), 2)
# TRIGGERS / confidence & strength                  ((good, JJ), 3)
# TRIGGERS / tools & techniques                     ((down, RP), 4)
# TRUST                                         ((serenity, NN), 1)
# TRUTH / Admit addiction                          ((when, WRB), 4)
# TRUTH / Costs                                      ((My, NNP), 2)
# TRUTH / Inventory                                ((when, WRB), 2)
# TRUTH / dark past                                ((done, VBN), 5)
# TRUTH / self honesty                                 ((–, NN), 5)
# URGES / moods & emotions                         ((when, WRB), 2)
# URGES / support & help                            ((high, JJ), 1)
# URGES / tools & techniques                  ((withdrawal, NN), 4)
# VALUES                                            ((long, JJ), 1)
# VULNERABILITY / Connection                          ((up, RP), 3)
# VULNERABILITY / Show true self               ((feelings, NNS), 4)
# VULNERABILITY / learning and mistakes               ((up, RP), 4)
# VULNERABILITY / others who’ve been there       ((having, VBG), 2)
# VULNERABILITY / to support my sobriety           ((curve, NN), 4)
# VULNERABILITY / worthy                            ((it’s, JJ), 1)
# WARNINGS / Avoid triggers                    ((cravings, NNS), 5)
# WARNINGS / Relapse & tools                    ((darkest, JJS), 1)
# WARNINGS / self aware & listen                   ((more, JJR), 4)
# WORTHINESS / connections & sharing               ((more, JJR), 5)
# WORTHINESS / deserve & rewards                ((recovery, NN), 2)
# WORTHINESS / help                           ((hardships, NNS), 2)
# WORTHINESS / new life & future               ((children, NNS), 3)
# WORTHINESS / self love & acceptance               ((time, NN), 3)
#
#                                                                20
# "WILL POWER\n"                                     ((guy, NN), 1)
# ABSTINENCE                                         ((one, CD), 4)
# ACCOUNTABILITY / Amends                        ((Making, VBG), 2)
# ACCOUNTABILITY / De-blame                       ((change, NN), 1)
# ACCOUNTABILITY / Own up                          ((when, WRB), 4)
# ACCOUNTABILITY / damage confess                  ((wrong, JJ), 4)
# AGONY                                           ((years, NNS), 2)
# AMENDS                                         ((things, NNS), 3)
# ANGER                                        ((feelings, NNS), 2)
# ANXIETY                                            ((one, CD), 2)
# APOLOGY                                                      None
# BABY STEPS / Accomplishments                 ((triggers, NNS), 2)
# BABY STEPS / Help & support                  ((triggers, NNS), 4)
# BABY STEPS / first steps                      ((moments, NNS), 2)
# BABY STEPS / focus on today                    ((places, NNS), 1)
# BABY STEPS / slow changes                       ((which, WDT), 3)
# BELIEFS                                         ((doing, VBG), 1)
# BENEFITS / COSTS                                ((health, NN), 1)
# BINGE                                     ((relationship, NN), 2)
# BITTERNESS                                       ((happy, JJ), 1)
# BLAME                                        ((criticism, NN), 2)
# CHANGE / action & behavior                        ((what, WP), 2)
# CHANGE / beliefs                               ((beliefs, NN), 4)
# CHANGE / courage                                  ((time, NN), 3)
# CHANGE / mental confidence                      ((doing, VBG), 4)
# CHANGE / motivations                            ((where, WRB), 6)
# CHANGE / self love & true self                    ((love, NN), 3)
# CHANGE / thoughts                              ((better, JJR), 2)
# COMMITMENTS                                    ((people, NNS), 3)
# COMMUNITY / Meetings & groups                     ((how, WRB), 3)
# ...                                                           ...
# SOBRIETY / maintaining & will power             ((doing, VBG), 2)
# STRESS                                    ((relationship, NN), 2)
# THOUGHTS                                      ((beliefs, NNS), 3)
# TRIGGERS / awareness                                ((up, RP), 2)
# TRIGGERS / confidence & strength             ((something, NN), 3)
# TRIGGERS / tools & techniques                ((addiction, NN), 4)
# TRUST                                          ((liberal, JJ), 1)
# TRUTH / Admit addiction                            ((bad, JJ), 4)
# TRUTH / Costs                                 ((thought, VBN), 2)
# TRUTH / Inventory                                  ((own, JJ), 2)
# TRUTH / dark past                                 ((how, WRB), 5)
# TRUTH / self honesty                           ((better, JJR), 5)
# URGES / moods & emotions                     ((direction, NN), 2)
# URGES / support & help                          ((urges, NNS), 1)
# URGES / tools & techniques                    ((physical, JJ), 4)
# VALUES                                         ((having, VBG), 1)
# VULNERABILITY / Connection                     ((problem, NN), 3)
# VULNERABILITY / Show true self                ((recovery, NN), 4)
# VULNERABILITY / learning and mistakes              ((one, CD), 4)
# VULNERABILITY / others who’ve been there         ((It’s, NNP), 2)
# VULNERABILITY / to support my sobriety        ((building, NN), 4)
# VULNERABILITY / worthy                           ((Worth, JJ), 1)
# WARNINGS / Avoid triggers                      ((nothing, NN), 4)
# WARNINGS / Relapse & tools                       ((detox, NN), 1)
# WARNINGS / self aware & listen               ((something, NN), 4)
# WORTHINESS / connections & sharing           ((something, NN), 5)
# WORTHINESS / deserve & rewards                     ((day, NN), 2)
# WORTHINESS / help                               ((person, NN), 2)
# WORTHINESS / new life & future                   ((It’s, NNP), 3)
# WORTHINESS / self love & acceptance               ((down, RP), 3)
#
# [200 rows x 20 columns]

# %%
nltk.help.upenn_tagset()
# Out:
# $: dollar
#     $ -$ --$ A$ C$ HK$ M$ NZ$ S$ U.S.$ US$
# '': closing quotation mark
#     ' ''
# (: opening parenthesis
#     ( [ {
# ): closing parenthesis
#     ) ] }
# ,: comma
#     ,
# --: dash
#     --
# .: sentence terminator
#     . ! ?
# :: colon or ellipsis
#     : ; ...
# CC: conjunction, coordinating
#     & 'n and both but either et for less minus neither nor or plus so
#     therefore times v. versus vs. whether yet
# CD: numeral, cardinal
#     mid-1890 nine-thirty forty-two one-tenth ten million 0.5 one forty-
#     seven 1987 twenty '79 zero two 78-degrees eighty-four IX '60s .025
#     fifteen 271,124 dozen quintillion DM2,000 ...
# DT: determiner
#     all an another any both del each either every half la many much nary
#     neither no some such that the them these this those
# EX: existential there
#     there
# FW: foreign word
#     gemeinschaft hund ich jeux habeas Haementeria Herr K'ang-si vous
#     lutihaw alai je jour objets salutaris fille quibusdam pas trop Monte
#     terram fiche oui corporis ...
# IN: preposition or conjunction, subordinating
#     astride among uppon whether out inside pro despite on by throughout
#     below within for towards near behind atop around if like until below
#     next into if beside ...
# JJ: adjective or numeral, ordinal
#     third ill-mannered pre-war regrettable oiled calamitous first separable
#     ectoplasmic battery-powered participatory fourth still-to-be-named
#     multilingual multi-disciplinary ...
# JJR: adjective, comparative
#     bleaker braver breezier briefer brighter brisker broader bumper busier
#     calmer cheaper choosier cleaner clearer closer colder commoner costlier
#     cozier creamier crunchier cuter ...
# JJS: adjective, superlative
#     calmest cheapest choicest classiest cleanest clearest closest commonest
#     corniest costliest crassest creepiest crudest cutest darkest deadliest
#     dearest deepest densest dinkiest ...
# LS: list item marker
#     A A. B B. C C. D E F First G H I J K One SP-44001 SP-44002 SP-44005
#     SP-44007 Second Third Three Two * a b c d first five four one six three
#     two
# MD: modal auxiliary
#     can cannot could couldn't dare may might must need ought shall should
#     shouldn't will would
# NN: noun, common, singular or mass
#     common-carrier cabbage knuckle-duster Casino afghan shed thermostat
#     investment slide humour falloff slick wind hyena override subhumanity
#     machinist ...
# NNP: noun, proper, singular
#     Motown Venneboerger Czestochwa Ranzer Conchita Trumplane Christos
#     Oceanside Escobar Kreisler Sawyer Cougar Yvette Ervin ODI Darryl CTCA
#     Shannon A.K.C. Meltex Liverpool ...
# NNPS: noun, proper, plural
#     Americans Americas Amharas Amityvilles Amusements Anarcho-Syndicalists
#     Andalusians Andes Andruses Angels Animals Anthony Antilles Antiques
#     Apache Apaches Apocrypha ...
# NNS: noun, common, plural
#     undergraduates scotches bric-a-brac products bodyguards facets coasts
#     divestitures storehouses designs clubs fragrances averages
#     subjectivists apprehensions muses factory-jobs ...
# PDT: pre-determiner
#     all both half many quite such sure this
# POS: genitive marker
#     ' 's
# PRP: pronoun, personal
#     hers herself him himself hisself it itself me myself one oneself ours
#     ourselves ownself self she thee theirs them themselves they thou thy us
# PRP$: pronoun, possessive
#     her his mine my our ours their thy your
# RB: adverb
#     occasionally unabatingly maddeningly adventurously professedly
#     stirringly prominently technologically magisterially predominately
#     swiftly fiscally pitilessly ...
# RBR: adverb, comparative
#     further gloomier grander graver greater grimmer harder harsher
#     healthier heavier higher however larger later leaner lengthier less-
#     perfectly lesser lonelier longer louder lower more ...
# RBS: adverb, superlative
#     best biggest bluntest earliest farthest first furthest hardest
#     heartiest highest largest least less most nearest second tightest worst
# RP: particle
#     aboard about across along apart around aside at away back before behind
#     by crop down ever fast for forth from go high i.e. in into just later
#     low more off on open out over per pie raising start teeth that through
#     under unto up up-pp upon whole with you
# SYM: symbol
#     % & ' '' ''. ) ). * + ,. < = > @ A[fj] U.S U.S.S.R * ** ***
# TO: "to" as preposition or infinitive marker
#     to
# UH: interjection
#     Goodbye Goody Gosh Wow Jeepers Jee-sus Hubba Hey Kee-reist Oops amen
#     huh howdy uh dammit whammo shucks heck anyways whodunnit honey golly
#     man baby diddle hush sonuvabitch ...
# VB: verb, base form
#     ask assemble assess assign assume atone attention avoid bake balkanize
#     bank begin behold believe bend benefit bevel beware bless boil bomb
#     boost brace break bring broil brush build ...
# VBD: verb, past tense
#     dipped pleaded swiped regummed soaked tidied convened halted registered
#     cushioned exacted snubbed strode aimed adopted belied figgered
#     speculated wore appreciated contemplated ...
# VBG: verb, present participle or gerund
#     telegraphing stirring focusing angering judging stalling lactating
#     hankerin' alleging veering capping approaching traveling besieging
#     encrypting interrupting erasing wincing ...
# VBN: verb, past participle
#     multihulled dilapidated aerosolized chaired languished panelized used
#     experimented flourished imitated reunifed factored condensed sheared
#     unsettled primed dubbed desired ...
# VBP: verb, present tense, not 3rd person singular
#     predominate wrap resort sue twist spill cure lengthen brush terminate
#     appear tend stray glisten obtain comprise detest tease attract
#     emphasize mold postpone sever return wag ...
# VBZ: verb, present tense, 3rd person singular
#     bases reconstructs marks mixes displeases seals carps weaves snatches
#     slumps stretches authorizes smolders pictures emerges stockpiles
#     seduces fizzes uses bolsters slaps speaks pleads ...
# WDT: WH-determiner
#     that what whatever which whichever
# WP: WH-pronoun
#     that what whatever whatsoever which who whom whosoever
# WP$: WH-pronoun, possessive
#     whose
# WRB: Wh-adverb
#     how however whence whenever where whereby whereever wherein whereof why
# ``: opening quotation mark
#     ` ``

# %%
l
# Out:
# [1, 2, 3, 4, 5]
