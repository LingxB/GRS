# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import numpy as np
import nltk
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
# %matplotlib inline

# %%
def preprocess(text,pos=True,n_tags=None,filt=True,lower=False):
    """
    Input text string, return tokenized, postagged, filted tokens.
    """
    if filt:
        negative_tags = ['$',"''",'(',')','--','.',',',':','DT','CC','IN','TO']
        if n_tags:
            negative_tags.extend(n_tags)
    else:
        negative_tags = []
    
    if lower:
        text = text.lower()
        
    tokens = nltk.word_tokenize(text)
    tagged_tokens = nltk.pos_tag(tokens)
    filted_tokens = [(tok,pos) for (tok,pos) in tagged_tokens if pos not in negative_tags]
    
    if pos:
        return filted_tokens 
    else:
        return tokens
    
def mapidx(df,cat):
    
    c = Counter()
    
    for idx,row in df.iterrows():
        label = row[cat].split(',')
        c.update(label)
        
    keys = sorted(c.keys())
    mapidx = {key:idx for idx,key in enumerate(keys)}
    
    return mapidx

def data2feats(df,col=['CATS','WELLGOS']):
    
    d_idx = {colname:mapidx(df,colname) for colname in col}

    feats_col_n = sum([len(v) for k,v in d_idx.items()])
    
    feats = np.zeros([df.shape[0],feats_col_n])
    
    # Extend idx to fit feature col size
    for idx,colname in enumerate(col):
        if idx == 1:
            for k,v in d_idx[colname].items():
                d_idx[colname][k] += len(d_idx[col[idx-1]])
        if idx > 1:
            for k,v in d_idx[colname].items():
                d_idx[colname][k] += sum([len(d_idx[col[idx-(i+1)]]) for i in range(idx)])
    
    for idx,row in df.iterrows():
        for i,colname in enumerate(col):
            elements = row[colname].split(',')
            element_idxs = [d_idx[colname][e] for e in elements]
            for e_idx in element_idxs:
                feats[idx,e_idx] = 1
                
    return d_idx,feats
    
    
def getlabels(df,colname):
    
    c = Counter()
    for idx,row in df.iterrows():
        c.update(row[colname].split(','))
        
    keys = sorted(c.keys())
    d_idx = {k:i for i,k in enumerate(keys)}
    
    labels = np.zeros([df.shape[0]],dtype=int)
    
    for idx,row in df.iterrows():
        labels[idx] = d_idx[row[colname]]
        
    return d_idx,labels
    

def plotclusters(feats_2d,km_labels,df,legloc='lower left'):
    
    l_focus = df['FOCUS']
    l_names = df['N']
    l_gender = df['GENDER']
    
    fig,axes =plt.subplots(2,2, sharey=True,figsize=(16,16))
    ax1 = axes[0,0]
    ax2 = axes[0,1]
    ax3 = axes[1,0]
    ax4 = axes[1,1]
    
    # KMeans Plot
    #ax1.set_title('K Means')
    #ax1.scatter(feats_2d[:,0],feats_2d[:,1],c=km_labels,s=50,linewidth=0.1,cmap='rainbow')
    
    # Other
    def plotrest(ax,name,lst):
        ax.set_title(name)
        label_added = []
        cmap = {l:c for l,c in zip(sorted(set(lst)),cm.rainbow(np.linspace(0,0.9,len(set(lst)))))}
        colors = [cmap[l] for l in lst]
        for i,c in enumerate(colors):
            x = feats_2d[i,0]
            y = feats_2d[i,1]
            l = lst[i]
            if l not in label_added:
                ax.scatter(x, y, label=l, s=50, linewidth=0.1, c=c)
                label_added.append(l)
            else:
                ax.scatter(x, y, s=50, linewidth=0.1, c=c)
        ax.legend(loc=legloc)
        
    plotrest(ax1,'KMeans',km_labels)    
    plotrest(ax2,'FOCUS',l_focus)
    plotrest(ax3,'NAME',l_names)
    plotrest(ax4,'GENDER',l_gender)
    

def getlabel(km_labels,clusters):
    
    examples = []
    
    for c in clusters:
        l = [idx for idx,label in enumerate(km_labels) if label == c]
        examples.append(l)
        print('Cluster %i: %i examples' %(c, len(l))) 
        print('%s\n%s\n%s\n' %(Counter(df.ix[l]['GENDER']), Counter(df.ix[l]['FOCUS']), Counter(df.ix[l]['N'])))                                         
    if len(clusters) == 1:
        return examples[0]
    else:
        return examples

def count(df,colname,l,cname,topN=10):
    
    c = Counter()
    for line in df.ix[l][colname]:
        c.update(line.split(','))
        
    print('Total %s in Cluster %i: %i\n' %(colname, cname, len(c.keys())))
    
    print('Most Common: ')
    
    for x in c.most_common(topN):
        print(x)
    print('\n')

def overlap2d(df,catname,welgname):
    
    c_cats = Counter()
    c_welg = Counter()

    for x in df[catname]:
        c_cats.update(x.split(','))

    for x in df[welgname]:
        c_welg.update(x.split(','))

    cats = sorted(c_cats.keys())
    welgs = sorted(c_welg.keys())

    c_matrix = np.zeros([len(cats),len(welgs)],dtype=int)

    for idx,row in df.iterrows():
        cat = row[catname].split(',')
        welg = row[welgname].split(',')
        for c in cat:
            for w in welg:
                c_matrix[cats.index(c),welgs.index(w)] += 1
    
    return cats,welgs,c_matrix

def matrix2df_(cols,rows,matrix):
    df = pd.DataFrame(index=cols,columns=rows,data=matrix)
    return df

def topNoverlap_(df,n=10):
    
    rows = df.index
    cols = df.columns
    tops = []
    
    for idx,row in df.iterrows():
        sortedlst = sorted([(count,idx) for idx,count in enumerate(row)],reverse=True)
        topN = [(cols[idx],count) for count,idx in sortedlst[:n]]
        tops.append(topN)
        
    new_df = pd.DataFrame(index=rows,columns=range(1,n+1),data=tops)
    return new_df

# %%
df = pd.read_csv('GenderEven207.csv')
df['TOKENS'] = None

for idx,row in df.iterrows():
    row['TOKENS'] = preprocess(row['RAW'],pos=False)

# %%
df
# Out:
#                                                    RAW  \
# 0    Throughout my drinking career, instant gratifi...
# 1    I tried to control every aspect of my life. Wh...
# 2    Thinking about drinking – the taste and feel –...
# 3    I always thought today/this weekend/this week ...
# 4    The people around me only saw what I wanted th...
# 5    Resigned to the fact that being poor or homele...
# 6    Alcohol was great for two things, suppressing ...
# 7    I’ve started more things than I can count and ...
# 8    How great it was to have a friend that I could...
# 9    Diving headlong into whatever had caught my in...
# 10   When I was drinking, I didn’t just distance my...
# 11   I did it; it was all me. Nobody or no thing ha...
# 12   Embrace the suck. Life sucks, get a helmet. Th...
# 13   I was obsessed with everything. I obsessed ove...
# 14   I only dealt in absolutes when I drank. I was ...
# 15   Talk about being ashamed. I’d hurt just about ...
# 16   My world was black and white while I was drink...
# 17   How impulsive I was. I never had time to make ...
# 18   I didn’t plan my day, alcohol did. Everything ...
# 19   When I was drinking, I could only be best desc...
# 20   Like a kid hopped up on sugar, I can’t sit sti...
# 21   I didn’t just avoid the warning signs when I w...
# 22   When I was drinking, I thought I was pretty go...
# 23   I felt worthless. Even more troubling is that ...
# 24   Abstinence... it was a hard thing for me to ap...
# 25   It took a long time for me to sail through sto...
# 26   Accidents happen. I've known that since childh...
# 27   I used to always hurt - anxiety, depression, a...
# 28   Exploring for alternatives was what got me int...
# 29   I always thought myself to be a humble dude. I...
# ..                                                 ...
# 384  Even when I am not in a great mood, I sometime...
# 385  Reaching deep down is scary, but necessary. To...
# 386  I have been dealing with a lot of emotional ch...
# 387  One of the challenges in battling my disease i...
# 388  As I recover, I learn to be grateful for the s...
# 389  Removing myself from a situation sooths my str...
# 390   My emotions tended to be all over the place w...
# 391  I have stopped the use of drugs. I have alread...
# 392  You can find me in the garden early in the mor...
# 393  I pledge my sobriety for a day at a time. I do...
# 394   Now I realize that my bad habits/using cost m...
# 395  If I am not prepared, I will not progress. I d...
# 396  Cravings or something that will always exist. ...
# 397  There are certain people in my life that feed ...
# 398  Exploring the things that motivate my recovery...
# 399  As the saying goes, shit happens. Expect it, p...
# 400  My 4th step inventory worksheet is a problem d...
# 401  Monitoring my moods is important for me. It is...
# 402  There are many rewards of recovery. In OA and ...
# 403  Today I am not afraid to seek help. Others in ...
# 404   While using, irrational beliefs were rational...
# 405  I am capable of disputing irrational beliefs w...
# 406  While using, I had this habit of making excuse...
# 407  I imagine that I am riding an unending wave. T...
# 408  My problems became more manageable in recovery...
# 409  Lazy thinking keeps me in relapse. Everything ...
# 410  It’s been said to call a spade a spade. Bringi...
# 411   Just by being in recovery, I have a new calmn...
# 412  The cravings I experience are not imaginary, b...
# 413  When I used drugs, I was alone and I preferred...
#
#                                                   CATS  \
# 0    PROGRESS / start small,INNER MASTERY / take a ...
# 1    CONTROL,SERENITY,FREEDOM / past & let go,TRUST...
# 2    CRAVINGS / will power & tools,INNER POWER / Se...
# 3    DELUSION,CONFESSION / denial,TRUTH / self honesty
# 4    CONFIDENCE / acceptance & worth,DELUSION,VULNE...
# 5    CONFIDENCE /  hope & future,FREEDOM / past & l...
# 6    WORTHINESS / connections & sharing,VULNERABILI...
# 7    COMMITMENTS,MOTIVATION,RESPONSIBILITY,INNER PO...
# 8    EGO,PRIDE ,INFLUENCES,COMMUNITY / healthy rela...
# 9    COMMITMENTS,PROGRESS / start small,INNER POWER...
# 10   INFLUENCES,LONELINESS,GROWTH / motivation & bo...
# 11   GRATITUDE / for others,CHANGE / self love & tr...
# 12   RESILIENCE / reaction & behavior,AGONY,MINDSET...
# 13   INNER POWER / Self control & willpower,FREEDOM...
# 14   GROWTH / behavior & habits,EGO,PROGRESS / reac...
# 15   SHAME,CONFESSION / damage & hurt,WORTHINESS / ...
# 16   GROWTH / learning & mistakes,RESILIENCE / reac...
# 17   PROGRESS / future & hope,MINDSET,GROWTH / supp...
# 18   FREEDOM / past & let go,WORTHINESS / new life ...
# 19   INNER MASTERY / beliefs & awareness,URGES / to...
# 20   FREEDOM / tools & strategies,URGES / tools & t...
# 21   GROWTH / learning & mistakes,SOBRIETY / behavi...
# 22   HEALING,GROWTH / true self,INNER / SELF / harm...
# 23   WORTHINESS / connections & sharing,VULNERABILI...
# 24   SOBRIETY / costs & benefits,ABSTINENCE,INNER P...
# 25   ABSTINENCE,COMMUNITY / healthy relationships,S...
# 26   VULNERABILITY / learning and mistakes,ACCOUNTA...
# 27   AGONY,INNER MASTERY / strength,TRUTH / Admit a...
# 28   DEAD END,TRUTH / dark past,MINDSET / Future so...
# 29     AMENDS,RECONCILIATON,CONFESSION / damage & hurt
# ..                                                 ...
# 384  JOY,INNER / SELF / patterns,COMMUNITY / connec...
# 385  COURAGE,CONFIDENCE /  hope & future,COMMUNITY ...
# 386  INNER MASTERY / challenge & resilience,INNER P...
# 387  COMMUNITY / Meetings & groups,URGES / tools & ...
# 388  GRATITUDE / progress & growth,PROGRESS / rewar...
# 389                             STRESS,MOODS,REACTIONS
# 390  RESILIENCE / reaction & behavior,CONFLICT,TRIG...
# 391  WORTHINESS / new life & future,CONFIDENCE / ac...
# 392  GRATITUDE / progress & growth,HIGHER POWER / s...
# 393  SOBRIETY / maintaining & will power,PROGRESS /...
# 394         BENEFITS / COSTS,PAST,REGRET,TRUTH / Costs
# 395  PROGRESS / start small,GROWTH / behavior & hab...
# 396  MINDSET / obstacles & challenge,CRAVINGS / vul...
# 397  INFLUENCES,BABY STEPS / Help & support,COMMUNI...
# 398   DAILY WORK,OPTIMISM,GROWTH / motivation & boosts
# 399  CONTROL,SITUATIONS,MINDSET / imperfection & ac...
# 400  INNER MASTERY / tools & processes,CONFIDENCE /...
# 401  MOODS,FREEDOM / tools & strategies,MINDSET / F...
# 402  FREEDOM / tools & strategies,PROGRESS / reward...
# 403  COURAGE,CONFESSION / powerlessness,WORTHINESS ...
# 404  MINDSET,CONFIDENCE /  obstacles & challenge,CH...
# 405  CONFIDENCE / acceptance & worth,INNER POWER / ...
# 406  EXCUSES,RESPONSIBILITY,DEAD END,ACCOUNTABILITY...
# 407  MINDSET / obstacles & challenge,INNER POWER / ...
# 408  OVERWHELM,TRUTH / Admit addiction,VULNERABILIT...
# 409  GROWTH / motivation & boosts,PROGRESS / future...
# 410  DEMONS,THOUGHTS,PROGRESS / reactions & behavio...
# 411  TRIGGERS / confidence & strength,INNER POWER /...
# 412  INNER MASTERY / challenge & resilience,CRAVING...
# 413         HEALING,WORTHINESS / connections & sharing
#
#                                                WELLGOS      FOCUS       N  \
# 0    Baby Step Embracer,Finish Line Forgetter,The M...  DRUGS/ALC    Paul
# 1    Controller Coaster,Should Shover,Serenity Simu...  DRUGS/ALC    Paul
# 2    Pattern Interrupter,New Pattern Painter,Craver...  DRUGS/ALC    Paul
# 3    Delusion Detector,Sabotage SOS’r,Insanity SOS’...  DRUGS/ALC    Paul
# 4    Self Esteem Elixir,Confidence Caffeinator,Inne...  DRUGS/ALC    Paul

kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='lower left')
# Out:
# Feats Shape:  (414, 205)
# Included:  dict_keys(['FOCUS', 'CATS'])

# %% [markdown]
# 1. Categories are strongly related to focus.
# 2. Categories for FOOD(mostly female) are similar.
# 3. Categories for POT(mostly male) are similar.

# %% [markdown]
# # CATS vs N

# %%
d_idx,feats = data2feats(df,col=['CATS','N'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='lower left')
# Out:
# Feats Shape:  (414, 207)
# Included:  dict_keys(['CATS', 'N'])

# %% [markdown]
# Cluster 2 & 3 in KMeans: Paul,Alys,Ilanna,Jack share similar categories? Deeper look required.
#
# After running multiple times with different number of cluster, with larger n_cluster (i.e. 7), KMeans tend to fit NAME classes, smaller n_cluster group examples together. n_cluster=5 fits gender difference.
#
# As shown below, Cluster 2 are all Alys, see most common categories below. Cluster 3 says Jack, Paul, Ilanna share common categories such as: ('INNER / SELF / patterns', 7), ('CONFESSION / damage & hurt', 7) and ('WARNINGS / Avoid triggers', 7)

# %%
l2 = [idx for idx,label in enumerate(kmeans.labels_) if label == 2] # Cluster 2
l3 = [idx for idx,label in enumerate(kmeans.labels_) if label == 3] # Cluster 3
l_all = l2 + l3 # Cluster 2+3

print('Cluster 2: %i examples, %s, %s' %(len(l2), Counter(df.ix[l2]['GENDER']), Counter(df.ix[l2]['N'])))
print('Cluster 3: %i examples, %s, %s' %(len(l3), Counter(df.ix[l3]['GENDER']), Counter(df.ix[l3]['N'])))
# Out:
# Cluster 2: 45 examples, Counter({'female': 45}), Counter({'Alys': 45})
# Cluster 3: 90 examples, Counter({'male': 73, 'female': 17}), Counter({'Jack': 38, 'Paul': 35, 'Ilanna': 17})

# %%
c = Counter()

for line in df.ix[l2]['CATS']:
    c.update(line.split(','))

print('Total cats in Cluster2: %i \n' %len(c.keys()))

print('Most common cats in Cluster2:\n')
c.most_common(10)
# Out:
# Total cats in Cluster2: 96
#
# Most common cats in Cluster2:
# [('COMMUNITY / listen to guidance', 5),
#  ('ACCOUNTABILITY / Own up', 4),
#  ('INNER POWER / Vulnerability', 3),
#  ('WORTHINESS / new life & future', 3),
#  ('INNER MASTERY / beliefs & awareness', 3),
#  ('TRIGGERS / tools & techniques', 3),
#  ('MINDSET / obstacles & challenge', 3),
#  ('CONFIDENCE /  hope & future', 3),
#  ('FREEDOM / past & let go', 3),
#  ('EXCUSES', 3)]

# %%
c = Counter()

for line in df.ix[l3]['CATS']:
    c.update([(c,n) for c in line.split(',')])

print('Total cats in Cluster3: %i \n' %len(c.keys()))
print('Most common cats in Cluster3:\n')
c.most_common(10)
# Out:
# Total cats in Cluster3: 127
#
# Most common cats in Cluster3:
# [('INNER / SELF / patterns', 7),
#  ('CONFESSION / damage & hurt', 7),
#  ('WARNINGS / Avoid triggers', 7),
#  ('WORTHINESS / new life & future', 6),
#  ('URGES / tools & techniques', 6),
#  ('WORTHINESS / connections & sharing', 5),
#  ('PROGRESS / start small', 5),
#  ('RESILIENCE / reaction & behavior', 5),
#  ('CONFESSION / denial', 5),
#  ('INNER / SELF / balance', 5)]

# %%
c = Counter()

for line in df.ix[l_all]['CATS']:
    c.update(line.split(','))
    
print('Total cats in Cluster2+3: %i \n' %len(c.keys()))
print('Cluster 2+3 most common:')
c.most_common(20)
# Out:
# Total cats in Cluster2+3: 148
#
# Cluster 2+3 most common:
# [('WORTHINESS / new life & future', 9),
#  ('CONFESSION / damage & hurt', 8),
#  ('FREEDOM / past & let go', 8),
#  ('WORTHINESS / connections & sharing', 7),
#  ('TRIGGERS / tools & techniques', 7),
#  ('MINDSET / obstacles & challenge', 7),
#  ('CONFIDENCE /  hope & future', 7),
#  ('URGES / tools & techniques', 7),
#  ('INNER / SELF / patterns', 7),
#  ('PROGRESS / start small', 7),
#  ('WARNINGS / Avoid triggers', 7),
#  ('INNER POWER / Self control & willpower', 7),
#  ('RESILIENCE / reaction & behavior', 6),
#  ('INNER / SELF / balance', 6),
#  ('TRIGGERS / confidence & strength', 6),
#  ('CHANGE / mental confidence', 6),
#  ('GROWTH / motivation & boosts', 6),
#  ('ACCOUNTABILITY / Own up', 5),
#  ('INNER MASTERY / self control', 5),
#  ('INNER POWER / Vulnerability', 5)]

# %% [markdown]
# # CAT vs GENDER

# %%
d_idx,feats = data2feats(df,col=['CATS','GENDER'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=8)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='lower left')
# Out:
# Feats Shape:  (414, 202)
# Included:  dict_keys(['CATS', 'GENDER'])

# %% [markdown]
# Some similar categories in each gender: 1 & 3 cluster in KMeans. Chek what are those categories.
#
# As shown below, most examples from each set share the same focus of DRUSG/ALC. Same as observed in other comparation analysis, male and female have unique problems such as POT and FOOD. It's interesting to find out that most categories choosen are universal in terms of gender, however, ('CONFESSION / admit', 7) and ('INNER MASTERY / challenge & resilience', 7) works better for male while ('CHANGE / motivations', 8) and ('SOBRIETY / celebrate & progress', 8) are more useful for female.

# %%
l1,l3 = getlabel(kmeans.labels_,clusters=[1,3])
count(df,'CATS',l1,1)
count(df,'CATS',l2,3)
# Out:
# Cluster 1: 180 examples
# Counter({'female': 180})
# Counter({'DRUGS/ALC': 114, 'FOOD': 45, 'EITHER': 14, 'GENERAL': 7})
# Counter({'Shar': 65, 'Jen': 60, 'Alys': 41, 'Ilanna': 14})
#
# Cluster 3: 133 examples
# Counter({'male': 133})
# Counter({'DRUGS/ALC': 100, 'POT': 25, 'GENERAL': 6, 'EITHER': 2})
# Counter({'Nigel': 84, 'Jack': 25, 'Paul': 24})
#
# Total CATS in Cluster 1: 170
#
# Most Common:
# ('CONFIDENCE /  hope & future', 10)
# ('COMMUNITY / Meetings & groups', 9)
# ('GROWTH / motivation & boosts', 9)
# ('FREEDOM / future & growth', 9)
# ('ACCOUNTABILITY / Own up', 9)
# ('THOUGHTS', 8)
# ('CHANGE / motivations', 8)
# ('FREEDOM / tools & strategies', 8)
# ('SOBRIETY / celebrate & progress', 8)
# ('MINDSET / obstacles & challenge', 8)
#
#
# Total CATS in Cluster 3: 169
#
# Most Common:
# ('CONFIDENCE /  hope & future', 9)
# ('COMMUNITY / Meetings & groups', 9)
# ('ACCOUNTABILITY / Own up', 9)
# ('MINDSET / obstacles & challenge', 9)
# ('THOUGHTS', 8)
# ('FREEDOM / tools & strategies', 8)
# ('COMMUNITY / listen to guidance', 8)
# ('CONFESSION / admit', 7)
# ('INNER MASTERY / challenge & resilience', 7)
# ('GROWTH / motivation & boosts', 7)

# %% [markdown]
# # ONLY WELLGOS

# %%
d_idx,feats = data2feats(df,col=['WELLGOS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=2)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df)
# Out:
# Feats Shape:  (414, 402)
# Included:  dict_keys(['WELLGOS'])

# %% [markdown]
# No clear pattern if only looking at wellgorithms.

# %% [markdown]
# # WELLGOS vs CATS

# %%
d_idx,feats = data2feats(df,col=['CATS','WELLGOS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df)
# Out:
# Feats Shape:  (414, 602)
# Included:  dict_keys(['CATS', 'WELLGOS'])

# %% [markdown]
# Some overlapping in terms of categories and wellgorithms choosen, perhaps commonly combined categories and wellgorithms or most choosen ones. Deeper investigation required.
#
# As shown below, can't help notice that in Cluster 1, INNER and FREEDOM appear frequently in both CATS and WELLGOS. When looking at overlappings between CATS and WELLGOS in Cluster 1, the concept of 'Inner', 'Freedom' and 'Soul' appear frequently.

# %%
l1 = getlabel(kmeans.labels_,clusters=[1])
count(df,'CATS',l1,1)
count(df,'WELLGOS',l1,1)
# Out:
# Cluster 1: 247 examples
# Counter({'female': 128, 'male': 119})
# Counter({'DRUGS/ALC': 160, 'FOOD': 31, 'POT': 26, 'GENERAL': 16, 'EITHER': 14})
# Counter({'Nigel': 65, 'Jen': 49, 'Shar': 43, 'Paul': 28, 'Alys': 28, 'Jack': 26, 'Ilanna': 8})
#
# Total CATS in Cluster 1: 175
#
# Most Common:
# ('INNER / SELF / harmony & inner peace', 14)
# ('EMOTIONS', 13)
# ('MINDSET / Future sobriety', 12)
# ('INNER POWER / Self control & willpower', 12)
# ('FREEDOM / past & let go', 12)
# ('URGES / tools & techniques', 11)
# ('WARNINGS / self aware & listen', 11)
# ('FREEDOM / tools & strategies', 11)
# ('MINDSET / obstacles & challenge', 11)
# ('FREEDOM / peace & harmony', 10)
#
#
# Total WELLGOS in Cluster 1: 340
#
# Most Common:
# ('Reactions Auditor', 13)
# ('Inner Power Allower', 12)
# ('Ill Feelings Illuminator', 12)
# ('Placid Reflux', 12)
# ('I-examiner - reactions & behavior', 12)
# ('Inner Freedom Forager', 12)
# ('Inner Motor Motivator', 11)
# ("Self Control 101'r", 11)
# ('SELF HARM ALARMER / avoid triggers', 10)
# ('THOUGHTS / positivity', 10)

# %%
cats,welgs,C_mat = overlap2d(df.ix[l1],'CATS','WELLGOS')
df_C_mat = matrix2df_(cats,welgs,C_mat)
top_cw = topNoverlap_(df_C_mat)
top_cw['CATS'] = top_cw.index # In Cluster 1, Top10 overlaped wellgorithms for each category

# %%
#df[df['A'].str.contains("hello")]
top_cw[top_cw['CATS'].str.contains('INNER POWER / Self control & willpower')]
# Out:
#                                                               1  \
# INNER POWER / Self control & willpower  (Self Control 101'r, 3)
#
#                                                            2  \
# INNER POWER / Self control & willpower  (Soul Controller, 2)
#
#                                                                                         3  \
# INNER POWER / Self control & willpower  (New Pattern Painter / confidence & awareness, 2)
#
#                                                      4                  5  \
# INNER POWER / Self control & willpower  (Craverade, 2)  (Worry Washer, 1)
#
#                                                         6  \
# INNER POWER / Self control & willpower  (Void Avoider, 1)
#
#                                                                               7  \
# INNER POWER / Self control & willpower  (VULNERABILITY / reach out for help, 1)
#
#                                                     8                  9  \
# INNER POWER / Self control & willpower  (Urge X’r, 1)  (Urge Auditor, 1)
#
#                                                                   10  \
# INNER POWER / Self control & willpower  (The Procrastina-shunner, 1)
#
#                                                                           CATS
# INNER POWER / Self control & willpower  INNER POWER / Self control & willpower

# %%
top_cw[top_cw['CATS'].str.contains('INNER / SELF / harmony & inner peace')]
# Out:
#                                                            1  \
# INNER / SELF / harmony & inner peace  (Whole Soul Healer, 3)
#
#                                                            2  \
# INNER / SELF / harmony & inner peace  (Soul Synchronizer, 2)
#
#                                                       3  \
# INNER / SELF / harmony & inner peace  (Soul Surgeon, 2)
#
#                                                             4  \
# INNER / SELF / harmony & inner peace  (Serenity Soulmater, 2)
#
#                                                             5  \
# INNER / SELF / harmony & inner peace  (Serenity Simulator, 2)
#
#                                                                6  \
# INNER / SELF / harmony & inner peace  (Inner Wealth Welcomer, 2)
#
#                                                             7  \
# INNER / SELF / harmony & inner peace  (Inner Soul X-Rayer, 2)
#
#                                                                  8  \
# INNER / SELF / harmony & inner peace  (Inner Light Illuminator, 2)
#
#                                                       9  \
# INNER / SELF / harmony & inner peace  (Bliss Kisser, 2)
#
#                                                              10  \
# INNER / SELF / harmony & inner peace  (Worthiness Whisperer, 1)
#
#                                                                       CATS
# INNER / SELF / harmony & inner peace  INNER / SELF / harmony & inner peace

# %%
top_cw[top_cw['CATS'].str.contains('FREEDOM')]
# Out:
#                                                                               1  \
# FREEDOM                                                    (The Mindfulizer, 2)
# FREEDOM / future & growth                             (Ever Evolving Flower, 3)
# FREEDOM / past & let go                              (Inner Freedom Forager, 4)
# FREEDOM / peace & harmony                         (Ill Feelings Illuminator, 3)
# FREEDOM / tools & strategies  (New Pattern Painter / confidence & awareness, 3)
#
#                                                                     2  \
# FREEDOM                                       (Black Hole Blesser, 2)
# FREEDOM / future & growth                      (Self Worth Surfer, 2)
# FREEDOM / past & let go                 (NEW LIFE / POSSIBILITIES, 3)
# FREEDOM / peace & harmony                        (Emotions Elixir, 3)
# FREEDOM / tools & strategies  (Self awareness / habits & behavior, 2)
#
#                                                                    3  \
# FREEDOM                                                (Urge X’r, 1)
# FREEDOM / future & growth                      (Miracle Embracer, 2)
# FREEDOM / past & let go                         (The Mindfulizer, 2)
# FREEDOM / peace & harmony                 (Inner Freedom Forager, 2)
# FREEDOM / tools & strategies  (I-examiner - reactions & behavior, 2)
#
#                                                     4  \
# FREEDOM                           (The Blessifier, 1)
# FREEDOM / future & growth       (Mentality Mender, 2)
# FREEDOM / past & let go       (Serenity Soulmater, 2)
# FREEDOM / peace & harmony          (Beloved BFF’r, 2)
# FREEDOM / tools & strategies        (Void Avoider, 1)
#
#                                                             5  \
# FREEDOM                            (THOUGHTS / positivity, 1)
# FREEDOM / future & growth          (Inner Freedom Forager, 2)
# FREEDOM / past & let go               (Self Control 101'r, 2)
# FREEDOM / peace & harmony     (WAIT AND SWITCH / Progress, 1)
# FREEDOM / tools & strategies         (Trigger Transformer, 1)
#
#                                                             6  \
# FREEDOM                                       (Soul Tuner, 1)
# FREEDOM / future & growth                (Divine Designer, 2)
# FREEDOM / past & let go                          (Past #2, 2)
# FREEDOM / peace & harmony     (WAIT AND SWITCH / Emotions, 1)
# FREEDOM / tools & strategies           (The Wellectrifier, 1)
#
#                                                          7  \
# FREEDOM                                 (Soul Survivor, 1)
# FREEDOM / future & growth         (Almighty Alchemizer, 2)
# FREEDOM / past & let go             (The Dynamotivator, 1)
# FREEDOM / peace & harmony                (Void Avoider, 1)
# FREEDOM / tools & strategies  (The Procrastina-shunner, 1)
#
#                                                    8                     9  \
# FREEDOM                          (Sobriety SOS’r, 1)   (Rainbow Hunter, 1)
# FREEDOM / future & growth         (Worthy Soul’r, 1)     (Void Avoider, 1)
# FREEDOM / past & let go        (Symbolic Stepper, 1)       (Soul Tuner, 1)
# FREEDOM / peace & harmony       (Venom Vaporizer, 1)     (Urge Auditor, 1)
# FREEDOM / tools & strategies  (The Momentumizer , 1)  (The Mindfulizer, 1)
#
#                                                                10  \
# FREEDOM                       (RAW SOUL REVEALER / worthiness, 1)
# FREEDOM / future & growth                  (Thy Will Be Doner, 1)
# FREEDOM / past & let go                    (Soul Synchronizer, 1)
# FREEDOM / peace & harmony                    (The Mindfulizer, 1)
# FREEDOM / tools & strategies               (The Dynamotivator, 1)
#
#                                                       CATS
# FREEDOM                                            FREEDOM
# FREEDOM / future & growth        FREEDOM / future & growth
# FREEDOM / past & let go            FREEDOM / past & let go
# FREEDOM / peace & harmony        FREEDOM / peace & harmony
# FREEDOM / tools & strategies  FREEDOM / tools & strategies

# %% [markdown]
# # WELLGOS vs FOCUS

# %%
d_idx,feats = data2feats(df,col=['WELLGOS','FOCUS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 407)
# Included:  dict_keys(['FOCUS', 'WELLGOS'])

# %% [markdown]
# Wellgorithms are strongly related to focuses as well

# %% [markdown]
# # WELLGOS vs N

# %%
d_idx,feats = data2feats(df,col=['WELLGOS','N'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 409)
# Included:  dict_keys(['N', 'WELLGOS'])

# %% [markdown]
# Wellgorithms are strongly related to NAMEs.

# %% [markdown]
# # WELLGOS vs GENDER

# %%
d_idx,feats = data2feats(df,col=['WELLGOS','GENDER'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=8)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='lower center')
# Out:
# Feats Shape:  (414, 404)
# Included:  dict_keys(['GENDER', 'WELLGOS'])

# %% [markdown]
# Some similar wellgorithms in each gender: 0 & 2 cluster in KMeans.
#
# Similar to CATS, male and female share similarity on higher level wellgorithms but quite different in terms of lower level ones. For instance, ('VULNERABILITY / support from others', 8), ('VULNERABILITY / reach out for help', 7)

# %%
l0,l2 = getlabel(kmeans.labels_,clusters=[0,2])
count(df,'WELLGOS',l0,0)
count(df,'WELLGOS',l2,2)
# Out:
# Cluster 0: 150 examples
# Counter({'male': 150})
# Counter({'DRUGS/ALC': 114, 'POT': 30, 'GENERAL': 5, 'EITHER': 1})
# Counter({'Nigel': 95, 'Jack': 30, 'Paul': 25})
#
# Cluster 2: 170 examples
# Counter({'female': 170})
# Counter({'DRUGS/ALC': 103, 'FOOD': 47, 'EITHER': 11, 'GENERAL': 9})
# Counter({'Shar': 66, 'Jen': 57, 'Alys': 33, 'Ilanna': 14})
#
# Total WELLGOS in Cluster 0: 280
#
# Most Common:
# ('VULNERABILITY / support from others', 8)
# ('Inner Freedom Forager', 8)
# ('Relationship Redeemer', 8)
# ('WAIT AND SWITCH / Small steps', 7)
# ('Inner Winner', 7)
# ('RELATIONSHIPS / Healthy & supportive', 7)
# ('Inner Light Illuminator', 6)
# ('New Pattern Painter / grit & progress', 6)
# ('Delusion Detector', 6)
# ('Inner Motor Motivator', 6)
#
#
# Total WELLGOS in Cluster 2: 299
#
# Most Common:
# ('RELATIONSHIPS / Build connections & community', 11)
# ('NEW LIFE / POSSIBILITIES', 9)
# ('Inner Power Allower', 8)
# ('Addiction AMF’r', 8)
# ('Reactions Auditor', 8)
# ('Killer Kickstarter', 8)
# ("Self Control 101'r", 7)
# ('VULNERABILITY / reach out for help', 7)
# ('The Dynamotivator', 7)
# ('Progress Pollinator', 7)

# %% [markdown]
# # CATS + WELLGOS + FOCUS

# %%
d_idx,feats = data2feats(df,col=['CATS','WELLGOS','FOCUS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 607)
# Included:  dict_keys(['FOCUS', 'WELLGOS', 'CATS'])

# %% [markdown]
# 1. FOOD are almost all females
# 2. POT are almost all males
# 3. Jack likes POT
# 4. Shar likes FOOD and DRUGS/ALC

# %% [markdown]
# # CATS + WELLGOS + FOCUS + NAME

# %%
d_idx,feats = data2feats(df,col=['CATS','WELLGOS','FOCUS','N'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=8)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 614)
# Included:  dict_keys(['N', 'FOCUS', 'WELLGOS', 'CATS'])

# %% [markdown]
# 1. Name fits gender, obviously
# 2. Nigel likes DRUGS/ALC
# 3. Jen likes DRUGS/ALC
# 4. Allys likes DRUGS/ALC
# 5. Paul is complex, between DRUGS/ALC, GENERAL, EITHER

# %% [markdown]
# # CATS + WELLGOS + FOCUS + GENDER

# %%
d_idx,feats = data2feats(df,col=['CATS','WELLGOS','FOCUS','GENDER'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=6)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='lower center')
# Out:
# Feats Shape:  (414, 609)
# Included:  dict_keys(['GENDER', 'CATS', 'WELLGOS', 'FOCUS'])

# %% [markdown]
# male/female+POT/FOOD close to male/female+EITHER+GENERAL, common categories or wellgorithms perhaps, further look required.

# %%
l1,l2 = getlabel(kmeans.labels_,clusters=[1,2])
count(df,'CATS',l1,1)
count(df,'WELLGOS',l1,1)
count(df,'CATS',l2,2)
count(df,'WELLGOS',l2,2)
# Out:
# Cluster 1: 47 examples
# Counter({'male': 47})
# Counter({'POT': 38, 'GENERAL': 6, 'EITHER': 3})
# Counter({'Jack': 38, 'Paul': 9})
#
# Cluster 2: 78 examples
# Counter({'female': 78})
# Counter({'FOOD': 53, 'EITHER': 15, 'GENERAL': 10})
# Counter({'Shar': 55, 'Jen': 16, 'Ilanna': 4, 'Alys': 3})
#
# Total CATS in Cluster 1: 92
#
# Most Common:
# ('WARNINGS / Avoid triggers', 7)
# ('INNER / SELF / patterns', 5)
# ('INNER MASTERY / self control', 4)
# ('WARNINGS / self aware & listen', 4)
# ('TRIGGERS / confidence & strength', 4)
# ('MINDSET / obstacles & challenge', 4)
# ('CONFESSION / damage & hurt', 4)
# ('URGES / tools & techniques', 3)
# ('VULNERABILITY / to support my sobriety', 3)
# ('URGES / moods & emotions', 3)
#
#
# Total WELLGOS in Cluster 1: 130
#
# Most Common:
# ('SELF HARM ALARMER / avoid triggers', 7)
# ('VULNERABILITY / support from others', 5)
# ('Craver Saver / Braver', 5)
# ('Trigger Trespasser', 4)
# ('Temperance Tester', 4)
# ('RAW SOUL REVEALER / past mistakes', 3)
# ("Self Control 101'r", 3)
# ('Trigger Auditor', 3)
# ('NEW PATTERN PAINTER / share & learn', 3)
# ('Compulsion KO’r', 3)
#
#
# Total CATS in Cluster 2: 133
#
# Most Common:
# ('OVERWHELM', 6)
# ('CONFESSION / admit', 6)
# ('STRESS', 5)
# ('VULNERABILITY / Show true self', 5)
# ('INNER MASTERY / challenge & resilience', 5)
# ('NEGATIVITY', 5)
# ('THOUGHTS', 5)
# ('TRIGGERS / awareness', 4)
# ('SOBRIETY / celebrate & progress', 4)
# ('TRUTH / Admit addiction', 4)
#
#
# Total WELLGOS in Cluster 2: 208
#
# Most Common:
# ('Ill Feelings Illuminator', 6)
# ('VULNERABILITY / reach out for help', 5)
# ('SELF HARM ALARMER / avoid triggers', 5)
# ('SELF HARM / Tools', 5)
# ('THOUGHTS / positivity', 5)
# ('New Pattern Painter / confidence & awareness', 5)
# ('Deep Down Diver', 5)
# ('Self awareness / habits & behavior', 5)
# ('Addiction AMF’r', 4)
# ('I-examiner - reactions & behavior', 4)

# %% [markdown]
# # CATS + WELLGOS + FOCUS + NAME + GENDER

# %%
d_idx,feats = data2feats(df,col=['CATS','WELLGOS','FOCUS','N','GENDER'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=8)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df)
# Out:
# Feats Shape:  (414, 616)
# Included:  dict_keys(['N', 'FOCUS', 'WELLGOS', 'GENDER', 'CATS'])
