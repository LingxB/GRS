# %%
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd
import numpy as np
import nltk
from nltk.corpus import stopwords 
from nltk.stem.wordnet import WordNetLemmatizer
import string
from collections import Counter
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import gensim, logging
from gensim import corpora
logging.basicConfig(format='%(asctime)s : %(levelname)s : %(message)s', level=logging.INFO)
# %matplotlib inline

# %%
def preprocess(text,pos=True,n_tags=None,filt=True,lower=False,BOW=False):
    """
    Input text string, return tokenized, postagged, filted tokens.
    """
    if filt:
        negative_tags = ['$',"''",'(',')','--','.',',',':','DT','CC','IN','TO']
        if n_tags:
            negative_tags.extend(n_tags)
    else:
        negative_tags = []
    
    if lower:
        text = text.lower()
        
    tokens = nltk.word_tokenize(text)
    tagged_tokens = nltk.pos_tag(tokens)
    filted_tokens = [(tok,pos) for (tok,pos) in tagged_tokens if pos not in negative_tags]
    
    if pos:
        if BOW:
            return list(set(filted_tokens))
        else:
            return filted_tokens
    else:
        if BOW:
            return list(set(tokens))
        else:
            return tokens
    
def mapidx(dataframe,colname):
    
    c = Counter()
    
    for idx,row in dataframe.iterrows():
        label = str(row[colname]).split(',')
        c.update(label)
        
    keys = sorted(c.keys())
    mapidx = {key:idx for idx,key in enumerate(keys)}
    
    return mapidx

def data2feats(df_,col=['CATS','WELLGOS'],we_size=200):
    
    concatfeats = False
    
    if 'TOPICS' in col:
        col = [c for c in col if c != 'TOPICS']
        w2vfeats = np.zeros([df_.shape[0],we_size*len(df.ix[0]['TOPICS'].split(','))])
        #print(w2vfeats.shape)
        for idx,row in df_.iterrows():
            vec = []
            for t in row['TOPICS'].split(','):
                try:
                    vec.append(word2vec[t])
                except KeyError:
                    print('KeyError: ', t, idx)
                    pass
            #embeddings = np.array([word2vec[t] for t in row['TOPICS'].split(',')])
            embeddings = np.array(vec)
            try:
                w2vfeats[idx,:] = embeddings.ravel()
            except ValueError:
                print('ValueError ', idx)
                pass
        concatfeats = True
    
    d_idx = {colname:mapidx(df_,colname) for colname in col}
    
    feats_col_n = sum([len(v) for k,v in d_idx.items()])
    
    feats = np.zeros([df_.shape[0],feats_col_n])
    #print(feats.shape)
    
    # Extend idx to fit feature col size
    for idx,colname in enumerate(col):
        if idx == 1:
            for k,v in d_idx[colname].items():
                d_idx[colname][k] += len(d_idx[col[idx-1]])
        if idx > 1:
            for k,v in d_idx[colname].items():
                d_idx[colname][k] += sum([len(d_idx[col[idx-(i+1)]]) for i in range(idx)])
    
    for idx,row in df_.iterrows():
        for i,colname in enumerate(col):
            elements = str(row[colname]).split(',')
            element_idxs = [d_idx[colname][e] for e in elements]
            for e_idx in element_idxs:
                feats[idx,e_idx] = 1
     
    if concatfeats:
        new_feats = np.concatenate((feats,w2vfeats),axis=1)
        #print(new_feats.shape)
        return d_idx,new_feats
    else:
        return d_idx,feats
    
    
def getlabels(df_,colname):
    
    c = Counter()
    for idx,row in df_.iterrows():
        c.update(row[colname].split(','))
        
    keys = sorted(c.keys())
    d_idx = {k:i for i,k in enumerate(keys)}
    
    labels = np.zeros([df_.shape[0]],dtype=int)
    
    for idx,row in df_.iterrows():
        labels[idx] = d_idx[row[colname]]
        
    return d_idx,labels
    

def plotclusters(feats_2d,km_labels,df_,legloc='lower left'):
    
    l_focus = df_['FOCUS'].values
    l_names = df_['N']
    l_gender = df_['GENDER']
    
    fig,axes =plt.subplots(2,2, sharey=True,figsize=(16,16))
    ax1 = axes[0,0]
    ax2 = axes[0,1]
    ax3 = axes[1,0]
    ax4 = axes[1,1]
    
    # KMeans Plot
    #ax1.set_title('K Means')
    #ax1.scatter(feats_2d[:,0],feats_2d[:,1],c=km_labels,s=50,linewidth=0.1,cmap='rainbow')
    
    # Other
    def plotrest(ax,name,lst):
        ax.set_title(name)
        label_added = []
        cmap = {l:c for l,c in zip(sorted(set(lst)),cm.rainbow(np.linspace(0,0.9,len(set(lst)))))}
        colors = [cmap[l] for l in lst]
        for i,c in enumerate(colors):
            x = feats_2d[i,0]
            y = feats_2d[i,1]
            l = lst[i]
            if l not in label_added:
                ax.scatter(x, y, label=l, s=50, linewidth=0.1, c=c)
                label_added.append(l)
            else:
                ax.scatter(x, y, s=50, linewidth=0.1, c=c)
        ax.legend(loc=legloc)
        
    plotrest(ax1,'KMeans',km_labels)    
    plotrest(ax2,'FOCUS',l_focus)
    plotrest(ax3,'NAME',l_names)
    plotrest(ax4,'GENDER',l_gender)
    

def getlabel(df_,km_labels,clusters):
    
    examples = []
    
    for c in clusters:
        l = [idx for idx,label in enumerate(km_labels) if label == c]
        examples.append(l)
        print('Cluster %i: %i examples' %(c, len(l))) 
        print('%s\n%s\n%s\n' %(Counter(df_.ix[l]['GENDER']), Counter(df_.ix[l]['FOCUS']), Counter(df_.ix[l]['N'])))                                         
    if len(clusters) == 1:
        return examples[0]
    else:
        return examples

def count(df_,colname,l,cname,topN=10,pos=False):
    
    c = Counter()
    for line in df_.ix[l][colname]:
        c.update(line.split(','))
    
    if not pos:
        print('Total unique %s in Cluster %i: %i\n' %(colname, cname, len(c.keys())))

        print('Most Common: ')

        for x in c.most_common(topN):
            print(x)
        print('\n')
    else: 
        tagged = nltk.pos_tag(c.keys()) #[w for w in c.keys() if w != '']
        
        dpos = {w:t for w,t in tagged}
        
        print('Total unique %s in Cluster %i: %i\n' %(colname, cname, len(c.keys())))
        
        print('Most Common Verbs: ')
        for x in c.most_common(topN):
            #if x[0] != '':
            if dpos[x[0]][:2] == 'VB':
                print(x)
        print('\nMost Common non-Verbs: ')
        for x in c.most_common(topN):
            #if x[0] != '':
            if dpos[x[0]][:2] != 'VB':
                print(x)
        print('\n')

def overlap2d(df_,catname,welgname):
    
    c_cats = Counter()
    c_welg = Counter()

    for x in df_[catname]:
        c_cats.update(x.split(','))

    for x in df_[welgname]:
        c_welg.update(x.split(','))

    cats = sorted(c_cats.keys())
    welgs = sorted(c_welg.keys())

    c_matrix = np.zeros([len(cats),len(welgs)],dtype=int)

    for idx,row in df_.iterrows():
        cat = row[catname].split(',')
        welg = row[welgname].split(',')
        for c in cat:
            for w in welg:
                c_matrix[cats.index(c),welgs.index(w)] += 1
    
    return cats,welgs,c_matrix

def matrix2df_(cols,rows,matrix):
    _df = pd.DataFrame(index=cols,columns=rows,data=matrix)
    return _df

def topNoverlap_(df_,n=10):
    
    rows = df_.index
    cols = df_.columns
    tops = []
    
    for idx,row in df_.iterrows():
        sortedlst = sorted([(count,idx) for idx,count in enumerate(row)],reverse=True)
        topN = [(cols[idx],count) for count,idx in sortedlst[:n]]
        tops.append(topN)
        
    new_df = pd.DataFrame(index=rows,columns=range(1,n+1),data=tops)
    return new_df

def normalize(doc,onlylemma=False):
    """doc is string, i.e. Sugar is bad to consume. My sister likes to have sugar, but not my father."""
    
    stop = set(stopwords.words('english')) #high freq non indicative words
    exclude = set(string.punctuation) 
    lemma = WordNetLemmatizer()
    
    tokens = nltk.word_tokenize(doc.lower())
    normalized = [lemma.lemmatize(token) for token in tokens]
    stop_free = [w for w in normalized if w not in stop]
    punc_free = [w for w in stop_free if w not in exclude]

    if onlylemma:
        return normalized
    else:
        return punc_free

def ldatopicmodeling(raw,n_topics=1,n_w=10):
    
    raw_clean = [normalize(raw)]
    dic = corpora.Dictionary(raw_clean)
    doc_term_matrix = [dic.doc2bow(w) for w in raw_clean]
    Lda = gensim.models.ldamodel.LdaModel
    ldamodel = Lda(doc_term_matrix, num_topics=n_topics, id2word = dic, passes=20)
    
    return ldamodel.top_topics(doc_term_matrix,num_words=n_w)

# %%
df = pd.read_csv('GenderEven207.csv')
df['TOKENS'] = None
df['TOPICS'] = None
df['nVecTOPICS'] = None

for idx,row in df.iterrows():
    pp = preprocess(row['RAW'],pos=True,n_tags=['PRP','PRP$','RB','MD','WRB','NNP'],BOW=True)
    row['TOKENS'] = ','.join([w for w,t in pp])
    row['TOPICS'] = row['nVecTOPICS'] = ','.join([t for s,t in ldatopicmodeling(row['RAW'],n_topics=1,n_w=5)[0][0]]) 
    

try:
    bool(word2vec)
except NameError:
    df_w2v = pd.read_csv('data_-c_removed.csv')
    df_w2v['TOKENS'] = None

    for idx,row in df_w2v.iterrows():
        pp = normalize(row['RAW'],onlylemma=True)
        #pp = preprocess(row['RAW'],pos=False,lower=True)
        row['TOKENS'] = pp

    scentence = df_w2v['TOKENS']
    word2vec = gensim.models.word2vec.Word2Vec(scentence, min_count=1, size=200, workers=2)
    del(df_w2v)

# %%
df
# Out:
#                                                    RAW  \
# 0    Throughout my drinking career, instant gratifi...
# 1    I tried to control every aspect of my life. Wh...
# 2    Thinking about drinking – the taste and feel –...
# 3    I always thought today/this weekend/this week ...
# 4    The people around me only saw what I wanted th...
# 5    Resigned to the fact that being poor or homele...
# 6    Alcohol was great for two things, suppressing ...
# 7    I’ve started more things than I can count and ...
# 8    How great it was to have a friend that I could...
# 9    Diving headlong into whatever had caught my in...
# 10   When I was drinking, I didn’t just distance my...
# 11   I did it; it was all me. Nobody or no thing ha...
# 12   Embrace the suck. Life sucks, get a helmet. Th...
# 13   I was obsessed with everything. I obsessed ove...
# 14   I only dealt in absolutes when I drank. I was ...
# 15   Talk about being ashamed. I’d hurt just about ...
# 16   My world was black and white while I was drink...
# 17   How impulsive I was. I never had time to make ...
# 18   I didn’t plan my day, alcohol did. Everything ...
# 19   When I was drinking, I could only be best desc...
# 20   Like a kid hopped up on sugar, I can’t sit sti...
# 21   I didn’t just avoid the warning signs when I w...
# 22   When I was drinking, I thought I was pretty go...
# 23   I felt worthless. Even more troubling is that ...
# 24   Abstinence... it was a hard thing for me to ap...
# 25   It took a long time for me to sail through sto...
# 26   Accidents happen. I've known that since childh...
# 27   I used to always hurt - anxiety, depression, a...
# 28   Exploring for alternatives was what got me int...
# 29   I always thought myself to be a humble dude. I...
# ..                                                 ...
# 384  Even when I am not in a great mood, I sometime...
# 385  Reaching deep down is scary, but necessary. To...
# 386  I have been dealing with a lot of emotional ch...
# 387  One of the challenges in battling my disease i...
# 388  As I recover, I learn to be grateful for the s...
# 389  Removing myself from a situation sooths my str...
# 390   My emotions tended to be all over the place w...
# 391  I have stopped the use of drugs. I have alread...
# 392  You can find me in the garden early in the mor...
# 393  I pledge my sobriety for a day at a time. I do...
# 394   Now I realize that my bad habits/using cost m...
# 395  If I am not prepared, I will not progress. I d...
# 396  Cravings or something that will always exist. ...
# 397  There are certain people in my life that feed ...
# 398  Exploring the things that motivate my recovery...
# 399  As the saying goes, shit happens. Expect it, p...
# 400  My 4th step inventory worksheet is a problem d...
# 401  Monitoring my moods is important for me. It is...
# 402  There are many rewards of recovery. In OA and ...
# 403  Today I am not afraid to seek help. Others in ...
# 404   While using, irrational beliefs were rational...
# 405  I am capable of disputing irrational beliefs w...
# 406  While using, I had this habit of making excuse...
# 407  I imagine that I am riding an unending wave. T...
# 408  My problems became more manageable in recovery...
# 409  Lazy thinking keeps me in relapse. Everything ...
# 410  It’s been said to call a spade a spade. Bringi...
# 411   Just by being in recovery, I have a new calmn...
# 412  The cravings I experience are not imaginary, b...
# 413  When I used drugs, I was alone and I preferred...
#
#                                                   CATS  \
# 0    PROGRESS / start small,INNER MASTERY / take a ...
# 1    CONTROL,SERENITY,FREEDOM / past & let go,TRUST...
# 2    CRAVINGS / will power & tools,INNER POWER / Se...
# 3    DELUSION,CONFESSION / denial,TRUTH / self honesty
# 4    CONFIDENCE / acceptance & worth,DELUSION,VULNE...
# 5    CONFIDENCE /  hope & future,FREEDOM / past & l...
# 6    WORTHINESS / connections & sharing,VULNERABILI...
# 7    COMMITMENTS,MOTIVATION,RESPONSIBILITY,INNER PO...
# 8    EGO,PRIDE ,INFLUENCES,COMMUNITY / healthy rela...
# 9    COMMITMENTS,PROGRESS / start small,INNER POWER...
# 10   INFLUENCES,LONELINESS,GROWTH / motivation & bo...
# 11   GRATITUDE / for others,CHANGE / self love & tr...
# 12   RESILIENCE / reaction & behavior,AGONY,MINDSET...
# 13   INNER POWER / Self control & willpower,FREEDOM...
# 14   GROWTH / behavior & habits,EGO,PROGRESS / reac...
# 15   SHAME,CONFESSION / damage & hurt,WORTHINESS / ...
# 16   GROWTH / learning & mistakes,RESILIENCE / reac...
# 17   PROGRESS / future & hope,MINDSET,GROWTH / supp...
# 18   FREEDOM / past & let go,WORTHINESS / new life ...
# 19   INNER MASTERY / beliefs & awareness,URGES / to...
# 20   FREEDOM / tools & strategies,URGES / tools & t...
# 21   GROWTH / learning & mistakes,SOBRIETY / behavi...
# 22   HEALING,GROWTH / true self,INNER / SELF / harm...
# 23   WORTHINESS / connections & sharing,VULNERABILI...
# 24   SOBRIETY / costs & benefits,ABSTINENCE,INNER P...
# 25   ABSTINENCE,COMMUNITY / healthy relationships,S...
# 26   VULNERABILITY / learning and mistakes,ACCOUNTA...
# 27   AGONY,INNER MASTERY / strength,TRUTH / Admit a...
# 28   DEAD END,TRUTH / dark past,MINDSET / Future so...
# 29     AMENDS,RECONCILIATON,CONFESSION / damage & hurt
# ..                                                 ...
# 384  JOY,INNER / SELF / patterns,COMMUNITY / connec...
# 385  COURAGE,CONFIDENCE /  hope & future,COMMUNITY ...
# 386  INNER MASTERY / challenge & resilience,INNER P...
# 387  COMMUNITY / Meetings & groups,URGES / tools & ...
# 388  GRATITUDE / progress & growth,PROGRESS / rewar...
# 389                             STRESS,MOODS,REACTIONS
# 390  RESILIENCE / reaction & behavior,CONFLICT,TRIG...
# 391  WORTHINESS / new life & future,CONFIDENCE / ac...
# 392  GRATITUDE / progress & growth,HIGHER POWER / s...
# 393  SOBRIETY / maintaining & will power,PROGRESS /...
# 394         BENEFITS / COSTS,PAST,REGRET,TRUTH / Costs
# 395  PROGRESS / start small,GROWTH / behavior & hab...
# 396  MINDSET / obstacles & challenge,CRAVINGS / vul...
# 397  INFLUENCES,BABY STEPS / Help & support,COMMUNI...
# 398   DAILY WORK,OPTIMISM,GROWTH / motivation & boosts
# 399  CONTROL,SITUATIONS,MINDSET / imperfection & ac...
# 400  INNER MASTERY / tools & processes,CONFIDENCE /...
# 401  MOODS,FREEDOM / tools & strategies,MINDSET / F...
# 402  FREEDOM / tools & strategies,PROGRESS / reward...
# 403  COURAGE,CONFESSION / powerlessness,WORTHINESS ...
# 404  MINDSET,CONFIDENCE /  obstacles & challenge,CH...
# 405  CONFIDENCE / acceptance & worth,INNER POWER / ...
# 406  EXCUSES,RESPONSIBILITY,DEAD END,ACCOUNTABILITY...
# 407  MINDSET / obstacles & challenge,INNER POWER / ...
# 408  OVERWHELM,TRUTH / Admit addiction,VULNERABILIT...
# 409  GROWTH / motivation & boosts,PROGRESS / future...
# 410  DEMONS,THOUGHTS,PROGRESS / reactions & behavio...
# 411  TRIGGERS / confidence & strength,INNER POWER /...
# 412  INNER MASTERY / challenge & resilience,CRAVING...
# 413         HEALING,WORTHINESS / connections & sharing
#
#                                                WELLGOS      FOCUS       N  \
# 0    Baby Step Embracer,Finish Line Forgetter,The M...  DRUGS/ALC    Paul
# 1    Controller Coaster,Should Shover,Serenity Simu...  DRUGS/ALC    Paul
# 2    Pattern Interrupter,New Pattern Painter,Craver...  DRUGS/ALC    Paul
# 3    Delusion Detector,Sabotage SOS’r,Insanity SOS’...  DRUGS/ALC    Paul
# 4    Self Esteem Elixir,Confidence Caffeinator,Inne...  DRUGS/ALC    Paul
# 5    Excuse Exterminator,Rationalization Rinser,Gra...  DRUGS/ALC    Paul
# 6    Emotions Engineer,Feelings Fantasizer,Compassi...  DRUGS/ALC    Paul
# 7    Finish Line Forgetter,The Procrastina-shunner,...  DRUGS/ALC    Paul
# 8    Foul Weather Friender,Arrogance Arrestor,Pride...  DRUGS/ALC    Paul
# 9    Symbolic Stepper,New Pattern Painter / grit & ...  DRUGS/ALC    Paul
# 10   Isolation SOS’r,Bad Influence Butcher,WAIT AND...  DRUGS/ALC    Paul
# 11   Miracle Embracer,Ego Eclipser,Pride Polisher,A...  DRUGS/ALC    Paul
# 12   Misery Minister,Ill Feelings Illuminator,Depre...  DRUGS/ALC    Paul
# 13   Insanity SOS’r,Self awareness / habits & behav...  DRUGS/ALC    Paul
# 14   Pride Puffer,Ego Eclipser,Arrogance Arrestor,N...  DRUGS/ALC    Paul
# 15   Shame X’r,Ever Evolving Flower,Worthiness Whis...  DRUGS/ALC    Paul
# 16   Perspective Detective,Daily Daisy Spotter,Blun...  DRUGS/ALC    Paul
# 17   Values VIP’r,Soul Proprietor,Sobriety 101'r,WA...  DRUGS/ALC    Paul
# 18   Past #2,The Mindfulizer,Regret Refunder,Self C...  DRUGS/ALC    Paul
# 19   Placid Reflux,Urge Auditor,Compulsion KO’r,Sel...  DRUGS/ALC    Paul
# 20   Void Avoider,The Procrastina-shunner,Lazy Zapp...  DRUGS/ALC    Paul
# 21   Sabotage SOS’r,Little Hint Listener,Inner Soul...  DRUGS/ALC    Paul
# 22   Whole Soul Healer,Serenity Soulmater,Inner Sou...  DRUGS/ALC    Paul
# 23   Dead End Deluder,Worthiness Whisperer,Love Swe...  DRUGS/ALC    Paul
# 24   Abstainer Amazer,Demon Dethroner ,COMMITMENT k...  DRUGS/ALC   Nigel
# 25   COMMITMENT knitter / abstinence confidence,REL...  DRUGS/ALC   Nigel
# 26   RAW SOUL REVEALER / past mistakes,ADMIT / acco...  DRUGS/ALC   Nigel
# 27   Pain Abstainer,CLOSET CONFESSOR / Admit addict...  DRUGS/ALC   Nigel
# 28   Dead End Defier ,Addiction AMF’r,Lost Benefit ...  DRUGS/ALC   Nigel
# 29   Relationship Dedamager,The First Amender,CLOSE...  DRUGS/ALC   Nigel
# ..                                                 ...        ...     ...
# 384  WAIT AND SWITCH / Emotions,Soul Tuner,New Patt...    GENERAL    Shar
# 385  Deep Down Diver,Scary Stepper,Fear Flusher,Cou...  DRUGS/ALC     Jen
# 386  Challenge Ninja,Addiction AMF’r,Adversity Aven...       FOOD    Shar
# 387  Urge Auditor,Compulsion KO’r,Ill Feelings Illu...       FOOD  Ilanna
# 388  Sober Milestoner,Baby Step Embracer,WAIT AND S...       FOOD    Shar
# 389  Placid Reflux,Stress Auditor,The Wellifier ,Th...     EITHER     Jen
# 390  Reactions Auditor,Situation Unscrewer,Problem ...  DRUGS/ALC    Alys
# 391  Inner Power Allower,Negativity Nuker,THOUGHTS ...  DRUGS/ALC    Alys
# 392  Gratitude Gardener,God Grounder,Bliss Kisser,N...  DRUGS/ALC    Shar
# 393  Sobriety 101'r,Symbolic Stepper,The Momentumiz...  DRUGS/ALC    Alys
# 394  Lost Benefit Lamenter,Wellectricity Generator,...  DRUGS/ALC     Jen
# 395  WAIT AND SWITCH / Small steps,Progress Pollina...       FOOD    Shar
# 396  Reactions Auditor,Craver Saver / Braver,I-Can-...  DRUGS/ALC     Jen
# 397  Bad Influence Butcher,VULNERABILITY / listen t...       FOOD    Shar
# 398  Confidence Colonizer,The Dynamotivator,Journey...  DRUGS/ALC     Jen
# 399  Excrement Expector,Problem Primer,Self Control...    GENERAL     Jen
# 400  Problem Doctor,The Dynamotivator,COMMITMENT kn...       FOOD    Shar
# 401  Feelings Flipper,SELF HARM / Tools,I-examiner ...  DRUGS/ALC    Shar
# 402  Progress Painter,The Successcalator,Values VIP...       FOOD    Shar
# 403  Pride Puffer,The Benefisher,Sobriety SOS’r,CLO...  DRUGS/ALC     Jen
# 404  Old Belief Butcher,Missi-Un-Impossiblizer ,Can...  DRUGS/ALC    Alys
# 405  Belief Superseder,Illogical Looper,Mentality M...     EITHER     Jen
# 406  Rationalization Rinser,Excuse X’r,Responsibili...  DRUGS/ALC    Alys
# 407  Adversity Adventurer,Blunder Blesser,Troubles ...    GENERAL     Jen
# 408  Qualm Quitter,CLOSET CONFESSOR / Share & suppo...       FOOD    Shar
# 409  Lazy Zapper,The Procrastina-shunner,THOUGHTS /...  DRUGS/ALC  Ilanna
# 410  Demon Doctor,THOUGHTS / aware & examine,VULNER...       FOOD    Shar
# 411  Bad Influence Butcher,Pain Abstainer,Self Cont...  DRUGS/ALC    Alys
# 412  Ill Feelings Illuminator,Soul-ution Finder,Cra...       FOOD  Ilanna
# 413  Sobriety Soulmater,Progress Pollinator,RELATIO...  DRUGS/ALC     Jen
#
#      GENDER                                             TOKENS  \
# 0      male  took,instant,slowing,better,trades,none,learne...
# 1      male  Being,aspect,willpower,serenity,manager,go,lif...
# 2      male  lemon,cup,feel,harsh,starving,something,water,...
# 3      male  week,purchase,whatever,admit,fooling,delusion,...
# 4      male  others,hide,lubricated,thought,mask,closest,wh...
# 5      male  don’t,homeless,continue,lot,life,drink,hands,m...
# 6      male  words,others,“honest,back,feel,get,didn’t,anyo...
# 7      male  hear,finish,instant,consider,have,past,pursue,...
# 8      male  feel,complain,Looking,help,have,everyone,harm,...
# 9      male  anything,caught,interest,headlong,learned,what...
# 10     male  continue,offering,distance,who,what,anyone,dis...
# 11     male  anything,based,have,miracle,newfound,been,happ...
# 12     male  Sure,helmet,manageable,months,permanent,only,l...
# 13     male  lasted,obsessed,Today,passions,wrongs,while,mo...
# 14     male  changes,continue,others,positive,second,change...
# 15     male  others,don’t,rational,Sure,everyone,past,ways,...
# 16     male  have,gift,ways,black,look,something,learned,li...
# 17     male  bother,worst,ways,did,what’s,busy,easier,other...
# 18     male  Everything,drunk,own,plan,past,Today,today,day...
# 19     male  help,separate,urges,downright,command,somethin...
# 20     male  ways,found,something,only,life,drink,kid,gone,...
# 21     male  work,continue,don’t,avoid,warning,ways,call,li...
# 22     male  anything,don’t,aspect,come,meditation,been,oth...
# 23     male  lower,work,trust,years,another’s,sick,perfect,...
# 24     male  took,addiction,detox,compare,have,stood,fell,y...
# 25     male  changes,took,addiction,slip,look,'s,years,grou...
# 26     male  addiction,accident,years,toe,addicted,somethin...
# 27     male  Taking,took,attempt,years,used,life,felt,slapp...
# 28     male  whole,got,dependent,world,sit,media,come,found...
# 29     male  whole,feel,able,have,years,dude,something,lot,...
# ..      ...                                                ...
# 384  female  act,positive,negative,Happy,changed,get,mood,b...
# 385  female  scary,surround,have,Today,who,get,places,suppo...
# 386  female  need,facing,black,lot,only,learn,been,life,pic...
# 387  female  battling,positive,binged,dangerous,recovery,le...
# 388  female  able,feel,years,wrestle,recovery,look,what,wor...
# 389  female  head,work,annoying,Avoiding,had,stress,problem...
# 390  female  find,hurts,Family,believe,don’t,Resentments,re...
# 391  female  anything,words,stopped,achieved,own,old,ruin,n...
# 392  female  anything,feel,soil,connects,recovery,something...
# 393  female  thoughts,commit,matter,today,know,pledge,do,we...
# 394  female  habits/using,health,physical,cost,never-ending...
# 395  female  changes,coping,positive,don’t,have,recovery,de...
# 396  female  coping,others,recovery,manageable,sensation,li...
# 397  female  negativity,phone,negative,state,help,patterns,...
# 398  female  enjoy,ones,old,filling,Many,recovery,ways,is,b...
# 399  female  goes,happens,Expect,wrong,best,expect,control,...
# 400  female  work,isn’t,road,step,harm,recovery,reinforce,T...
# 401  female  moods,meals,don’t,deal,feel,recovery,hunger,al...
# 402  female  proven,others,addiction,able,help,step,recover...
# 403  female  need,recovery,Today,Asking,weakness,Others,per...
# 404  female  anything,complete,rational,have,recovery,somet...
# 405  female  positive,old,story,negative,patterns,addict,To...
# 406  female  anything,work,dead,everyone,change,accountable...
# 407  female  riding,slip,imagine,only,temptations,unending,...
# 408  female  others,recovery,honest,manageable,ways,helped,...
# 409  female  changes,Everything,support,recovery,change,Tod...
# 410  female  addiction,don’t,light,feel,phone,spade,isn’t,h...
# 411  female  partner,took,Becoming,right,second,recovery,ha...
# 412  female  find,ways,denied,denial,substance,it’s,overeat...
# 413  female  others,need,ones,don’t,story,establish,recover...
#
#                                         TOPICS
# 0                 master,step,wanted,baby,time
# 1                    go,control,thing,life,way
# 2                  like,–,salivate,man,tipping
# 3              would,stop,time,better,drinking
# 4                friend,wa,see,reason,occasion
# 5               poor,homeless,life,better,fate
# 6        feeling,suppressing,else’s,didn’t,i’m
# 7         thing,say,finish,start,disheartening
# 8               friend,wa,person,like,superior
# 9            start,done,basic,knew,intelligent
# 10              didn’t,wa,people,distance,harm
# 11                 miracle,wa,thing,sober,it’s
# 12                    misery,way,life,suck,day
# 13     obsession,obsessed,eye,everything,today
# 14                wa,second,nature,change,keep
# 15                thing,i’ve,head,ashamed,done
# 16            something,problem,wa,fail,people
# 17                      plan,wa,make,take,best
# 18            today,control,next,revolved,make
# 19                 urge,bad,wa,deep,succumbing
# 20                   still,way,i’ve,gone,can’t
# 21                warning,sign,didn’t,even,way
# 22                      soul,good,much,wa,know
# 23           life,worthy,worthless,worth,worry
# 24               abstinence,wa,thing,lost,fell
# 25                   'm,abstinence,time,'ve,'d
# 26              accident,accept,lost,n't,maybe
# 27                     wa,ever,problem,'d,took
# 28         alternative,wa,friend,whole,explore
# 29                  n't,wa,apologize,'d,became
# ..                                         ...
# 384                  act,happy,around,sad,mood
# 385              fear,support,scary,share,deep
# 386            challenge,one,room,problem,pick
# 387   withdrawal,experience,anger,recovery,one
# 388                  one,day,getting,next,time
# 389       stress,avoiding,relief,try,situation
# 390      believe,reacting,don’t,people,someone
# 391                   care,way,drug,clean,life
# 392            god,away,problem,would,centered
# 393             stay,sober,know,thought,strong
# 394      cost,account,relationship,using,trust
# 395          change,make,recovery,system,place
# 396          craving,urge,power,exist,physical
# 397               help,know,people,ask,problem
# 398      new,exploring,thing,recovery,motivate
# 399                go,shit,expect,control,best
# 400        recovery,problem,doctor,writing,4th
# 401       lonely,important,friend,feeling,make
# 402                    god,–,recovery,way,know
# 403              help,recovery,need,seek,today
# 404  belief,something,carried,attack,literally
# 405        belief,today,addict,take,irrational
# 406               nothing,wa,habit,didn’t,dead
# 407                 back,wave,get,longer,board
# 408               wa,problem,became,helped,way
# 409               want,thinking,get,day,change
# 410               thought,like,food,mind,spade
# 411            wa,impulse,kept,recovery,option
# 412                craving,ha,go,inside,become
# 413              need,recovery,friend,wa,today
#
# [414 rows x 8 columns]

# %% [markdown]
# # ONLY TOKENS

# %%
d_idx,feats = data2feats(df,col=['TOKENS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5,max_iter=500)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 4643)
# Included:  dict_keys(['TOKENS'])

# %% [markdown]
# Tokens are elements such as word and punctuation, here non-indicative tokens such have been filtered. So throwing only tokens into the cluster algorithm, if two people use similar words to describe their recovery path, they should be grouped into the same cluster.
#
# As shown in KMeans figure and below stats, in terms of language, examples with name 'Nigel' are very similar. Cluster 0 and 2 share some similarity as well.

# %%
l0,l1,l2 = getlabel(df,kmeans.labels_,clusters=[0,1,2])
count(df,'TOKENS',l0,0,topN=20,pos=True)
count(df,'TOKENS',l1,1,topN=20,pos=True)
count(df,'TOKENS',l2,2,topN=20,pos=True)
# Out:
# Cluster 0: 110 examples
# Counter({'female': 69, 'male': 41})
# Counter({'POT': 37, 'DRUGS/ALC': 36, 'FOOD': 32, 'EITHER': 3, 'GENERAL': 2})
# Counter({'Shar': 43, 'Jack': 37, 'Jen': 10, 'Alys': 8, 'Ilanna': 8, 'Paul': 3, 'Nigel': 1})
#
# Cluster 1: 86 examples
# Counter({'male': 86})
# Counter({'DRUGS/ALC': 85, 'POT': 1})
# Counter({'Nigel': 85, 'Jack': 1})
#
# Cluster 2: 216 examples
# Counter({'female': 136, 'male': 80})
# Counter({'DRUGS/ALC': 164, 'FOOD': 20, 'GENERAL': 16, 'EITHER': 16})
# Counter({'Jen': 57, 'Nigel': 48, 'Alys': 37, 'Shar': 33, 'Paul': 32, 'Ilanna': 9})
#
# Total unique TOKENS in Cluster 0: 2268
#
# Most Common Verbs:
# ('have', 114)
# ('is', 105)
# ('do', 88)
# ('am', 71)
# ('be', 63)
# ('are', 62)
# ('was', 59)
# ('get', 57)
# ('want', 48)
# ('know', 41)
# ('had', 39)
#
# Most Common non-Verbs:
# ('that', 60)
# ('life', 57)
# ('addiction', 57)
# ('one', 56)
# ('things', 50)
# ('what', 49)
# ('more', 45)
# ('recovery', 43)
# ('people', 39)
#
#
# Total unique TOKENS in Cluster 1: 2163
#
# Most Common Verbs:
# ('was', 84)
# ('had', 70)
# ('did', 56)
# ('were', 50)
# ('been', 41)
# ('lost', 41)
# ('be', 41)
# ("'m", 38)
# ('got', 38)
# ('left', 36)
#
# Most Common non-Verbs:
# ('drugs', 68)
# ('–', 64)
# ('life', 61)
# ('friends', 54)
# ('detox', 52)
# ('addiction', 48)
# ("'s", 47)
# ('more', 42)
# ('get', 37)
# ('people', 35)
#
#
# Total unique TOKENS in Cluster 2: 2646
#
# Most Common Verbs:
# ('is', 135)
# ('have', 117)
# ('was', 90)
# ('am', 88)
# ('be', 66)
# ('are', 64)
# ('do', 51)
# ('know', 37)
# ('make', 32)
#
# Most Common non-Verbs:
# ('life', 76)
# ('recovery', 63)
# ('that', 60)
# ('get', 50)
# ('what', 46)
# ('more', 44)
# ('people', 39)
# ('time', 38)
# ('way', 32)
# ('addiction', 32)
# ("'s", 31)

# %% [markdown]
# # Vectorized TOPICS

# %%
d_idx,feats = data2feats(df,col=['TOPICS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=5,max_iter=500)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 1000)
# Included:  dict_keys([])

# %% [markdown]
# Word vectors are not well trained due to small size corpus. Perhaps try pretrained vectors.

# %% [markdown]
# # TOKENS + CATS/WELLGOS

# %%
d_idx,feats = data2feats(df,col=['CATS','WELLGOS','TOKENS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=4,max_iter=300)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 5245)
# Included:  dict_keys(['WELLGOS', 'TOKENS', 'CATS'])

# %% [markdown]
# Similar to only tokens

# %% [markdown]
# # Non-Vec TOPICS

# %%
d_idx,feats = data2feats(df,col=['nVecTOPICS','GENDER'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=4,max_iter=300)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df,legloc='upper right')
# Out:
# Feats Shape:  (414, 755)
# Included:  dict_keys(['GENDER', 'nVecTOPICS'])

# %% [markdown]
# Interesting fact that within each gender, there's two major group with similarity indside but clear difference between each other. Reason unclear yet, deeper comparasion suggested.

# %%
l0,l1,l2,l3 = getlabel(df,kmeans.labels_,clusters=[0,1,2,3])
count(df,'nVecTOPICS',l0,0,topN=25)
count(df,'nVecTOPICS',l2,2,topN=20)
count(df,'nVecTOPICS',l1,1,topN=20)
count(df,'nVecTOPICS',l3,3,topN=20)
# Out:
# Cluster 0: 90 examples
# Counter({'male': 90})
# Counter({'DRUGS/ALC': 66, 'POT': 19, 'EITHER': 3, 'GENERAL': 2})
# Counter({'Nigel': 51, 'Paul': 20, 'Jack': 19})
#
# Cluster 1: 40 examples
# Counter({'female': 40})
# Counter({'DRUGS/ALC': 26, 'FOOD': 14})
# Counter({'Shar': 19, 'Jen': 12, 'Alys': 5, 'Ilanna': 4})
#
# Cluster 2: 117 examples
# Counter({'male': 117})
# Counter({'DRUGS/ALC': 92, 'POT': 19, 'GENERAL': 6})
# Counter({'Nigel': 83, 'Jack': 19, 'Paul': 15})
#
# Cluster 3: 167 examples
# Counter({'female': 167})
# Counter({'DRUGS/ALC': 102, 'FOOD': 39, 'EITHER': 16, 'GENERAL': 10})
# Counter({'Shar': 58, 'Jen': 56, 'Alys': 40, 'Ilanna': 13})
#
# Total unique nVecTOPICS in Cluster 0: 265
#
# Most Common:
# ('life', 15)
# ("n't", 14)
# ("'s", 12)
# ('–', 11)
# ("'d", 10)
# ('way', 10)
# ('trigger', 8)
# ('drug', 7)
# ('addiction', 6)
# ('thing', 5)
# ('one', 5)
# ('could', 5)
# ('make', 5)
# ("'ve", 4)
# ('get', 4)
# ('time', 4)
# ('done', 4)
# ('control', 4)
# ('like', 4)
# ('pot', 4)
# ('better', 3)
# ('light', 3)
# ('i’m', 3)
# ('ha', 3)
# ('still', 3)
#
#
# Total unique nVecTOPICS in Cluster 2: 275
#
# Most Common:
# ('wa', 117)
# ("n't", 24)
# ("'d", 20)
# ('drug', 16)
# ('–', 11)
# ('life', 11)
# ('thing', 9)
# ("'s", 9)
# ('friend', 9)
# ('would', 7)
# ('could', 6)
# ('pot', 5)
# ('never', 5)
# ('change', 5)
# ('thought', 4)
# ('going', 3)
# ('became', 3)
# ('get', 3)
# ('addiction', 3)
# ('time', 3)
#
#
# Total unique nVecTOPICS in Cluster 1: 120
#
# Most Common:
# ('recovery', 40)
# ('today', 6)
# ('wa', 5)
# ('life', 4)
# ('people', 4)
# ('god', 3)
# ('thing', 3)
# ('share', 3)
# ('one', 3)
# ('change', 3)
# ('behavior', 3)
# ('others', 2)
# ('new', 2)
# ('make', 2)
# ('addict', 2)
# ('problem', 2)
# ('always', 2)
# ('feeling', 2)
# ('focus', 2)
# ('i’m', 2)
#
#
# Total unique nVecTOPICS in Cluster 3: 429
#
# Most Common:
# ('wa', 18)
# ('food', 16)
# ('life', 12)
# ('thought', 10)
# ('change', 10)
# ('get', 9)
# ('today', 9)
# ('feeling', 9)
# ('one', 9)
# ('thing', 8)
# ('way', 8)
# ('don’t', 8)
# ('problem', 8)
# ('day', 8)
# ('people', 8)
# ('like', 8)
# ('craving', 7)
# ('take', 7)
# ('work', 7)
# ('power', 6)

# %%
df.ix[l0] #Cluster 0
# Out:
#                                                    RAW  \
# 0    Throughout my drinking career, instant gratifi...
# 1    I tried to control every aspect of my life. Wh...
# 2    Thinking about drinking – the taste and feel –...
# 3    I always thought today/this weekend/this week ...
# 5    Resigned to the fact that being poor or homele...
# 6    Alcohol was great for two things, suppressing ...
# 7    I’ve started more things than I can count and ...
# 9    Diving headlong into whatever had caught my in...
# 12   Embrace the suck. Life sucks, get a helmet. Th...
# 13   I was obsessed with everything. I obsessed ove...
# 15   Talk about being ashamed. I’d hurt just about ...
# 18   I didn’t plan my day, alcohol did. Everything ...
# 20   Like a kid hopped up on sugar, I can’t sit sti...
# 21   I didn’t just avoid the warning signs when I w...
# 23   I felt worthless. Even more troubling is that ...
# 25   It took a long time for me to sail through sto...
# 26   Accidents happen. I've known that since childh...
# 32   Baby steps didn't only take me towards recover...
# 33    Bad news is easy to refuse. I didn't want to ...
# 34   I never wanted to be a junkie; nobody does. Be...
# 36   I've always believed that a belief is meant to...
# 37   I've always focused on the greater benefit – e...
# 42   As an addict, I burned a lot of bridges – good...
# 43   Since childhood, I wanted to burn as few bridg...
# 51   Cravings, to my addicted, could only be replac...
# 53    I was a serious crutch creator. I didn't want...
# 55   Drug addiction only has two possible outcomes,...
# 64   As an addict, I did a lot of damage. I did dam...
# 65   I began growing into a deep-down reacher – for...
# 67   Two wrongs doesn't make a right. I've been tau...
# ..                                                 ...
# 150  ￼￼Even though there’s very little light in my ...
# 152  Maybe I'm not shameless. Maybe shame just fall...
# 153  Staying sober is like a son of a bitch experie...
# 155  The fact that 'stigma' is such a commonly used...
# 156  I always keep a radar that beeps at any sign o...
# 157  Like the Grim Reaper walking the streets with ...
# 161  If only I don’t see the liquor stores near my ...
# 162  I’m one of those people that's usually good at...
# 166  I’m a tough guy; I can take it. I have willpow...
# 167  When asked if I could get something done or be...
# 168  I could always rationalize any behavior I exhi...
# 169  I think it is very common. I am 25. It was wid...
# 173  I have learned that cold turkey quitting is on...
# 179  One of the hardest things I have had to deal w...
# 180  Simply not being able to control when I get th...
# 183  Very simply, “curb” means to restrain. To rest...
# 184  To minimize the craving to get high is difficu...
# 188  I remember that day. I remember a few days. I ...
# 189  I'm a very terrible craftsman. I'm much better...
# 190  Some people in today's world would rather avoi...
# 191  Sensing triggers in my life is massive. I want...
# 192  Knowing what triggers my addiction helps me st...
# 194  Much like trigger-point therapy when I went to...
# 195  Shrinking that big bullseye on your back is a ...
# 197  After I identified my triggers, each and every...
# 198  Learning how to transform my triggers into pos...
# 199  I remember having to face the truth of my pot ...
# 200  Putting the shoe on the other foot is always a...
# 204  One of my favorite silly movies is The Replace...
# 206  Urges are very similar to waves we see on the ...
#
#                                                   CATS  \
# 0    PROGRESS / start small,INNER MASTERY / take a ...
# 1    CONTROL,SERENITY,FREEDOM / past & let go,TRUST...
# 2    CRAVINGS / will power & tools,INNER POWER / Se...
# 3    DELUSION,CONFESSION / denial,TRUTH / self honesty
# 5    CONFIDENCE /  hope & future,FREEDOM / past & l...
# 6    WORTHINESS / connections & sharing,VULNERABILI...
# 7    COMMITMENTS,MOTIVATION,RESPONSIBILITY,INNER PO...
# 9    COMMITMENTS,PROGRESS / start small,INNER POWER...
# 12   RESILIENCE / reaction & behavior,AGONY,MINDSET...
# 13   INNER POWER / Self control & willpower,FREEDOM...
# 15   SHAME,CONFESSION / damage & hurt,WORTHINESS / ...
# 18   FREEDOM / past & let go,WORTHINESS / new life ...
# 20   FREEDOM / tools & strategies,URGES / tools & t...
# 21   GROWTH / learning & mistakes,SOBRIETY / behavi...
# 23   WORTHINESS / connections & sharing,VULNERABILI...
# 25   ABSTINENCE,COMMUNITY / healthy relationships,S...
# 26   VULNERABILITY / learning and mistakes,ACCOUNTA...
# 32   BABY STEPS / first steps,PROGRESS / start smal...
# 33   CONFESSION / denial,TRUTH / Admit addiction,MI...
# 34   BLAME,CONFIDENCE /  obstacles & challenge,RESP...
# 36   TRUTH / self honesty,CHANGE / beliefs,SOBRIETY...
# 37   SOBRIETY / costs & benefits,GROWTH / goals & f...
# 42   VULNERABILITY / Connection,COMMUNITY / healthy...
# 43   TRUTH / dark past,COMMUNITY / healthy relation...
# 51   CRAVINGS / vulnerability & learning,CHANGE / m...
# 53   EXCUSES,MINDSET / identify weaknesses,INNER PO...
# 55   DEAD END,ACCOUNTABILITY / damage confess,BABY ...
# 64   ACCOUNTABILITY / damage confess,ACCOUNTABILITY...
# 65   WORTHINESS / self love & acceptance,TRUTH / se...
# 67   COMMUNITY / healthy relationships,ACCOUNTABILI...
# ..                                                 ...
# 150  BABY STEPS / slow changes,GROWTH / motivation ...
# 152  CONFIDENCE / acceptance & worth,SHAME,INNER / ...
# 153  INNER / SELF / beliefs & insight,SOBRIETY / co...
# 155    LABELS / STIGMA,JUDGMENTS,SELF ESTEEM / beliefs
# 156  WARNINGS / self aware & listen,TRIGGERS / awar...
# 157  FREEDOM,WORTHINESS / new life & future,GROWTH ...
# 161  TRIGGERS / tools & techniques,CHANGE / action ...
# 162  INNER POWER,GRATITUDE / progress & growth,BABY...
# 166  "WILL POWER\n",CRAVINGS / vulnerability & lear...
# 167  MINDSET / obstacles & challenge,RESPONSIBILITY...
# 168  EXCUSES,INNER POWER / Vulnerability,CONFESSION...
# 169  LABELS / STIGMA,CONFESSION / admit,TRUTH / dar...
# 173  MINDSET / no matter what,ABSTINENCE,INNER MAST...
# 179  INNER POWER / Self control & willpower,INNER M...
# 180  CRAVINGS / vulnerability & learning,MINDSET / ...
# 183  INNER POWER / Self control & willpower,WARNING...
# 184  MINDSET / no matter what,ABSTINENCE,WARNINGS /...
# 188  CONFESSION / damage & hurt,VULNERABILITY / lea...
# 189  CONFESSION / damage & hurt,HEALING,WORTHINESS ...
# 190  MINDSET / will power,INNER MASTERY / self cont...
# 191  INNER MASTERY / self control,CONFIDENCE / acti...
# 192  TRIGGERS / awareness,MINDSET / identify weakne...
# 194  TRIGGERS / confidence & strength,INNER / SELF ...
# 195  INNER / SELF / balance,MINDSET / obstacles & c...
# 197  TRIGGERS / confidence & strength,WARNINGS / Av...
# 198  INNER MASTERY / tools & processes,TRIGGERS / c...
# 199  CONFIDENCE /  hope & future,TRUTH / dark past,...
# 200  MINDSET / Perceptions,INNER / SELF / beliefs &...
# 204  TRUTH / self honesty,VULNERABILITY / learning ...
# 206  INNER / SELF / balance,FREEDOM / peace & harmo...
#
#                                                WELLGOS      FOCUS      N  \
# 0    Baby Step Embracer,Finish Line Forgetter,The M...  DRUGS/ALC   Paul
# 1    Controller Coaster,Should Shover,Serenity Simu...  DRUGS/ALC   Paul
# 2    Pattern Interrupter,New Pattern Painter,Craver...  DRUGS/ALC   Paul
# 3    Delusion Detector,Sabotage SOS’r,Insanity SOS’...  DRUGS/ALC   Paul
# 5    Excuse Exterminator,Rationalization Rinser,Gra...  DRUGS/ALC   Paul
# 6    Emotions Engineer,Feelings Fantasizer,Compassi...  DRUGS/ALC   Paul
# 7    Finish Line Forgetter,The Procrastina-shunner,...  DRUGS/ALC   Paul
# 9    Symbolic Stepper,New Pattern Painter / grit & ...  DRUGS/ALC   Paul
# 12   Misery Minister,Ill Feelings Illuminator,Depre...  DRUGS/ALC   Paul
# 13   Insanity SOS’r,Self awareness / habits & behav...  DRUGS/ALC   Paul
# 15   Shame X’r,Ever Evolving Flower,Worthiness Whis...  DRUGS/ALC   Paul
# 18   Past #2,The Mindfulizer,Regret Refunder,Self C...  DRUGS/ALC   Paul
# 20   Void Avoider,The Procrastina-shunner,Lazy Zapp...  DRUGS/ALC   Paul
# 21   Sabotage SOS’r,Little Hint Listener,Inner Soul...  DRUGS/ALC   Paul
# 23   Dead End Deluder,Worthiness Whisperer,Love Swe...  DRUGS/ALC   Paul
# 25   COMMITMENT knitter / abstinence confidence,REL...  DRUGS/ALC  Nigel
# 26   RAW SOUL REVEALER / past mistakes,ADMIT / acco...  DRUGS/ALC  Nigel
# 32   Baby Step Embracer,Progress Painter,WAIT AND S...  DRUGS/ALC  Nigel
# 33   Denial Denyer,CLOSET CONFESSOR / Admit addicti...  DRUGS/ALC  Nigel
# 34   Blame Changer,Victim Vanquisher,Responsibility...  DRUGS/ALC  Nigel
# 36   Belief Superseder,CLOSET CONFESSOR / Face trut...  DRUGS/ALC  Nigel
# 37   Insanity SOS’r,Delusion Detector,Lost Benefit ...  DRUGS/ALC  Nigel
# 42   Relationship Redeemer,Bad Influence Butcher,RE...  DRUGS/ALC  Nigel
# 43   Relationship Redeemer,VULNERABILITY / connecti...  DRUGS/ALC  Nigel
# 51   Craver Saver / Braver,Hope Harvester,I-Examine...  DRUGS/ALC  Nigel
# 53   Excuse Exterminator,Rationalization Rinser,Rai...  DRUGS/ALC  Nigel
# 55   Dead End Deluder,Grave Trigger,Just One Justif...  DRUGS/ALC  Nigel
# 64   Relationship Dedamager,Damage Doctor,CLOSET CO...  DRUGS/ALC  Nigel
# 65   Deep Down Diver,Inner Eye Opener,VULNERABILITY...  DRUGS/ALC  Nigel
# 67   Double Wronger,Values VIP’r,Dire Extinguisher,...  DRUGS/ALC  Nigel
# ..                                                 ...        ...    ...
# 150  Moonlight Motivator,WAIT AND SWITCH / Small st...  DRUGS/ALC  Nigel
# 152  Shamenesia,COMMITMENT knitter / celebrate,Self...  DRUGS/ALC  Nigel
# 153  Sobriety SOB’r,Challenge Ninja,Inner Motor Mot...  DRUGS/ALC  Nigel
# 155  Stigma Stigmatizer,Attitude Alchemizer,Mentali...  DRUGS/ALC  Nigel
# 156  Danger Ranger,SELF HARM / Tools,Self Awareness...  DRUGS/ALC  Nigel
# 157  Grave Trigger,Fear FYI’r,Inner Motor Motivator...  DRUGS/ALC  Nigel
# 161  Insanity SOS’r,Trigger SOS’r,Trigger Trespasse...    GENERAL   Paul
# 162  Little Win Welcomer,Journey Jazzer,Symbolic St...    GENERAL   Paul
# 166  Little Hint Listener,Worthiness Whisperer,Gut ...     EITHER   Paul
# 167  Responsibility Rebooter,The Procrastina-shunne...     EITHER   Paul
# 168  Rationalization Rinser,I-examiner - motivation...     EITHER   Paul
# 169  CLOSET CONFESSOR / Admit addiction,The Destigm...        POT   Jack
# 173  Cold Turkey Taster,Killer Kickstarter,COMMITME...        POT   Jack
# 179  Urge X’r,Inner Power Allower,Inner Winner,SELF...        POT   Jack
# 180  Craver Saver / Braver,SELF HARM ALARMER / avoi...        POT   Jack
# 183  Cravings 101'r,Self Control 101'r,SELF HARM AL...        POT   Jack
# 184  SELF HARM ALARMER / avoid triggers,Craver Save...        POT   Jack
# 188  Relationship Dedamager,CLOSET CONFESSOR / Face...        POT   Jack
# 189  Damage Doctor,Relationship Redeemer,RAW SOUL R...        POT   Jack
# 190  Trigger X’r,COMMITMENT knitter / above all els...        POT   Jack
# 191  Triggers 101'r,Self Control 101'r,COMMITMENT k...        POT   Jack
# 192  Trigger Auditor,New Pattern Painter / confiden...        POT   Jack
# 194  Compulsion KO’r,Temperance Tester,Trigger Tres...        POT   Jack
# 195  Trigger Auditor,I-examiner - reactions & behav...        POT   Jack
# 197  Trigger Trespasser,The Successcalator,Problem ...        POT   Jack
# 198  Trigger Transformer,THOUGHTS / positivity,Brav...        POT   Jack
# 199  Bitter Truth Taster,CLOSET CONFESSOR / Share &...        POT   Jack
# 200  RAW SOUL REVEALER / past mistakes,Deep Down Di...        POT   Jack
# 204  Blunder Blesser,SELF HARM / Self honesty & adm...        POT   Jack
# 206  Emotions Elixir,Inner I-Opener,WAIT AND SWITCH...        POT   Jack
#
#     GENDER                                             TOKENS  \
# 0     male  took,instant,slowing,better,trades,none,learne...
# 1     male  Being,aspect,willpower,serenity,manager,go,lif...
# 2     male  lemon,cup,feel,harsh,starving,something,water,...
# 3     male  week,purchase,whatever,admit,fooling,delusion,...
# 5     male  don’t,homeless,continue,lot,life,drink,hands,m...
# 6     male  words,others,“honest,back,feel,get,didn’t,anyo...
# 7     male  hear,finish,instant,consider,have,past,pursue,...
# 9     male  anything,caught,interest,headlong,learned,what...
# 12    male  Sure,helmet,manageable,months,permanent,only,l...
# 13    male  lasted,obsessed,Today,passions,wrongs,while,mo...
# 15    male  others,don’t,rational,Sure,everyone,past,ways,...
# 18    male  Everything,drunk,own,plan,past,Today,today,day...
# 20    male  ways,found,something,only,life,drink,kid,gone,...
# 21    male  work,continue,don’t,avoid,warning,ways,call,li...
# 23    male  lower,work,trust,years,another’s,sick,perfect,...
# 25    male  changes,took,addiction,slip,look,'s,years,grou...
# 26    male  addiction,accident,years,toe,addicted,somethin...
# 32    male  society,took,addiction,right,able,old,bringing...
# 33    male  changes,stopped,accepted,JUNKIE,go,wanting,ref...
# 34    male  anything,weight,therapy,left,negative,years,bl...
# 36    male  anything,took,addiction,right,'s,pile,outstret...
# 37    male  disappear,addiction,detox,–,cure,access,years,...
# 42    male  work,took,thought,ones,drug-addicted,left,deto...
# 43    male  fellow,addiction,left,motives,set,became,life,...
# 51    male  took,addiction,accepted,replaced,years,conside...
# 53    male  addiction,state,became,life,seek,wanted,more,f...
# 55    male  bit,took,addiction,right,detox,'s,years,Drug,c...
# 64    male  took,others,able,detox,help,addict,repairing,b...
# 65    male  others,addiction,able,help,helped,became,life,...
# 67    male  battling,right,addiction,Doing,left,–,hardest,...
# ..     ...                                                ...
# 150   male           there’s,keep,light,motivated,little,life
# 152   male  's,something,life,back,like,everything,has,doi...
# 153   male  Staying,dual,story,meanings,sob,has,sober,bitc...
# 155   male  junkies,society,stigmatizers,'s,ingrained,loca...
# 156   male  addiction,'s,past,dangerous,use,endows,anyone,...
# 157   male  bit,streets,trigger,destination,worthless.”,'s...
# 161   male  route,stores,don’t,problem,bypass,known,go,wal...
# 162   male  anything,took,enjoy,right,bunch,appreciate,ste...
# 166   male  whisperer,gut,get,use,Codswallop,begging,matte...
# 167   male  anything,took,don’t,mindset,finishing,start,so...
# 168   male  find,excuses,something,use,what’s,behavior,was...
# 169   male  anything,public,everyone,found,joke,addicted,m...
# 173   male  bit,week,dad,lowest,tampered,addicted,months,g...
# 179   male  anything,had,deal,addiction,right,start,urges,...
# 180   male  addiction,positive,able,help,road,body,addicte...
# 183   male  anything,negativity,continue,addiction,need,de...
# 184   male  stopped,trigger,stimulation,locking,help,helpe...
# 188   male  inexcusable,bit,addiction,past,brief,change,co...
# 189   male  anything,meeting,addiction,years,repair,repair...
# 190   male  hear,addiction,season,wife,smoke,life,looking,...
# 191   male  words,refuse,others,addiction,watch,vaults,loo...
# 192   male  addiction,trigger,bothers,help,years,tick,go,w...
# 194   male  trigger,addiction,feel,therapy,smoking,worst,c...
# 195   male  anything,delicate,positive,feel,negative,addic...
# 197   male  anything,work,Being,addiction,problem,Transcen...
# 198   male  members,addiction,years,helped,beast,wife,lear...
# 199   male  arrogance-,addiction,scary,numerous,have,past,...
# 200   male  bare,others,believe,addiction,spending,second,...
# 204   male  anything,willingness,ask,need,close,urges,Repl...
# 206   male  others,addiction,after-,feel,need,gate,minutes...
#
#                                         TOPICS  \
# 0                 master,step,wanted,baby,time
# 1                    go,control,thing,life,way
# 2                  like,–,salivate,man,tipping
# 3              would,stop,time,better,drinking
# 5               poor,homeless,life,better,fate
# 6        feeling,suppressing,else’s,didn’t,i’m
# 7         thing,say,finish,start,disheartening
# 9            start,done,basic,knew,intelligent
# 12                    misery,way,life,suck,day
# 13     obsession,obsessed,eye,everything,today
# 15                thing,i’ve,head,ashamed,done
# 18            today,control,next,revolved,make
# 20                   still,way,i’ve,gone,can’t
# 21                warning,sign,didn’t,even,way
# 23           life,worthy,worthless,worth,worry
# 25                   'm,abstinence,time,'ve,'d
# 26              accident,accept,lost,n't,maybe
# 32                 step,towards,small,way,take
# 33                   news,n't,bad,refused,life
# 34                    blame,life,'d,nobody,'ve
# 36                   belief,'m,people,back,n't
# 37                  –,benefit,focus,'d,focused
# 42                      bridge,–,one,'d,friend
# 43                 bridge,friend,life,'d,could
# 51          craving,thing,maybe,addiction,drug
# 53                    crutch,drug,use,make,'ll
# 55                       's,'d,could,corner,go
# 64                  damage,done,rehab,help,'ve
# 65                     –,reach,could,life,drug
# 67                      –,wrong,right,n't,drug
# ..                                         ...
# 150             light,enough,it’s,keep,there’s
# 152                  shame,maybe,way,result,ha
# 153                 like,ha,sober,meaning,also
# 155               's,stigma,group,think,entire
# 156              danger,knowledge,radar,–,keep
# 157                   –,time,'re,grave,trigger
# 161          stop,liquor,store,trigger,without
# 162          little,win,good,appreciate,enough
# 166                 i’m,go,listen,better,ready
# 167                       try,tell,i’d,get,way
# 168         excuse,rationalize,i’m,make,trying
# 169             still,addicted,'s,one,everyone
# 173                        n't,'s,ca,still,pot
# 179                    one,urge,resist,make,ha
# 180            craving,get,leave,place,failure
# 183          n't,addiction,pot,expect,restrain
# 184           craving,would,even,difficult,n't
# 188            addiction,pot,remember,done,way
# 189            explain,thing,caused,damage,n't
# 190          n't,trigger,show,addiction,nudity
# 191              trigger,get,control,show,give
# 192          want,addiction,comfort,'s,trigger
# 194             addiction,trigger,like,'s,feel
# 195                  emotion,n't,back,life,pot
# 197            could,way,transcend,trigger,one
# 198  learned,transform,trigger,became,positive
# 199                    n't,life,people,past,ca
# 200                could,others,see,would,life
# 204                afraid,name,say,person,urge
# 206                    think,urge,move,soon,'s
#
#                                     nVecTOPICS
# 0                 master,step,wanted,baby,time
# 1                    go,control,thing,life,way
# 2                  like,–,salivate,man,tipping
# 3              would,stop,time,better,drinking
# 5               poor,homeless,life,better,fate
# 6        feeling,suppressing,else’s,didn’t,i’m
# 7         thing,say,finish,start,disheartening
# 9            start,done,basic,knew,intelligent
# 12                    misery,way,life,suck,day
# 13     obsession,obsessed,eye,everything,today
# 15                thing,i’ve,head,ashamed,done
# 18            today,control,next,revolved,make
# 20                   still,way,i’ve,gone,can’t
# 21                warning,sign,didn’t,even,way
# 23           life,worthy,worthless,worth,worry
# 25                   'm,abstinence,time,'ve,'d
# 26              accident,accept,lost,n't,maybe
# 32                 step,towards,small,way,take
# 33                   news,n't,bad,refused,life
# 34                    blame,life,'d,nobody,'ve
# 36                   belief,'m,people,back,n't
# 37                  –,benefit,focus,'d,focused
# 42                      bridge,–,one,'d,friend
# 43                 bridge,friend,life,'d,could
# 51          craving,thing,maybe,addiction,drug
# 53                    crutch,drug,use,make,'ll
# 55                       's,'d,could,corner,go
# 64                  damage,done,rehab,help,'ve
# 65                     –,reach,could,life,drug
# 67                      –,wrong,right,n't,drug
# ..                                         ...
# 150             light,enough,it’s,keep,there’s
# 152                  shame,maybe,way,result,ha
# 153                 like,ha,sober,meaning,also
# 155               's,stigma,group,think,entire
# 156              danger,knowledge,radar,–,keep
# 157                   –,time,'re,grave,trigger
# 161          stop,liquor,store,trigger,without
# 162          little,win,good,appreciate,enough
# 166                 i’m,go,listen,better,ready
# 167                       try,tell,i’d,get,way
# 168         excuse,rationalize,i’m,make,trying
# 169             still,addicted,'s,one,everyone
# 173                        n't,'s,ca,still,pot
# 179                    one,urge,resist,make,ha
# 180            craving,get,leave,place,failure
# 183          n't,addiction,pot,expect,restrain
# 184           craving,would,even,difficult,n't
# 188            addiction,pot,remember,done,way
# 189            explain,thing,caused,damage,n't
# 190          n't,trigger,show,addiction,nudity
# 191              trigger,get,control,show,give
# 192          want,addiction,comfort,'s,trigger
# 194             addiction,trigger,like,'s,feel
# 195                  emotion,n't,back,life,pot
# 197            could,way,transcend,trigger,one
# 198  learned,transform,trigger,became,positive
# 199                    n't,life,people,past,ca
# 200                could,others,see,would,life
# 204                afraid,name,say,person,urge
# 206                    think,urge,move,soon,'s
#
# [90 rows x 9 columns]

# %%
df.ix[l2] #Cluster2
# Out:
#                                                    RAW  \
# 4    The people around me only saw what I wanted th...
# 8    How great it was to have a friend that I could...
# 10   When I was drinking, I didn’t just distance my...
# 11   I did it; it was all me. Nobody or no thing ha...
# 14   I only dealt in absolutes when I drank. I was ...
# 16   My world was black and white while I was drink...
# 17   How impulsive I was. I never had time to make ...
# 19   When I was drinking, I could only be best desc...
# 22   When I was drinking, I thought I was pretty go...
# 24   Abstinence... it was a hard thing for me to ap...
# 27   I used to always hurt - anxiety, depression, a...
# 28   Exploring for alternatives was what got me int...
# 29   I always thought myself to be a humble dude. I...
# 30   Anger has never been one of my issues. I was a...
# 31   It certainly wasn't autopilot that drove me to...
# 35   I've always been what a polite person would ca...
# 38   The bipolar coaster was one hell of a ride. It...
# 39   The truth is something that an addict likes to...
# 40    I lived in the dark for a long time. With onl...
# 41   My brain functioned alright as a young teen. I...
# 44   It takes a special type of person to give peop...
# 45   When I got into drugs, their initial appeal wa...
# 46    As a young lad, I embraced change in all the ...
# 47   I was born with a clean slate – everyone is. T...
# 48   Cold turkey's a term named after the goosebump...
# 49   I rode the controller coaster all the way to t...
# 50   I might say... I've been a bit stingy with mon...
# 52   Life throws everyone curve balls, sometimes. I...
# 54   I was addicted for quite a few years. During t...
# 56   I was never one to detect my own delusions, bu...
# ..                                                 ...
# 125  I was never in a rush to get anywhere as a kid...
# 128  I hailed myself as the anxiety exiler – I'd so...
# 142  No matter what situation me and my addiction b...
# 151  There aren't a lot of things in my life that I...
# 154  An honest junkie – as I was to my few closest ...
# 158  Everything about life was hard when I was drin...
# 159  Planning for the next day, week, month, and th...
# 160  I thought I was free to do whatever I wanted. ...
# 163  I was in my early 20s when a dear friend said ...
# 164  I’ll only do something for someone if I get so...
# 165  When it came to people, I was great at pointin...
# 170  One of the hardest things that I ever had to d...
# 171  In order to change, I had to have a reason to ...
# 172  Today, I'm going to make a clean break. I'm no...
# 174  I've seen many types of compulsions in my life...
# 175  NOT avoiding conflict became very important to...
# 176  A girl. A look. A glance. A thought. One insta...
# 177  Taking a moment to explore my thoughts and fee...
# 178  I love economics. I really do. Cost-benefit an...
# 181  Dealing with craving cramps as a pot addict is...
# 182  Ever seen a caffeine or even nicotine addict i...
# 185  I have read about some options to help you red...
# 186  Witnessing one of my own cravings was and is a...
# 187  Throughout the years of my pot addiction, I ha...
# 193  Losing the trigger that makes me turn to pot a...
# 196   Once I identified my specific pot triggers (t...
# 201  Up and down. Hot and cold. On and off. That's ...
# 202  The advantage of having a pot addiction (there...
# 203  When I was a kid, my mom had a quote she alway...
# 205  I hate resisting urges. I love to drink Sprite...
#
#                                                   CATS  \
# 4    CONFIDENCE / acceptance & worth,DELUSION,VULNE...
# 8    EGO,PRIDE ,INFLUENCES,COMMUNITY / healthy rela...
# 10   INFLUENCES,LONELINESS,GROWTH / motivation & bo...
# 11   GRATITUDE / for others,CHANGE / self love & tr...
# 14   GROWTH / behavior & habits,EGO,PROGRESS / reac...
# 16   GROWTH / learning & mistakes,RESILIENCE / reac...
# 17   PROGRESS / future & hope,MINDSET,GROWTH / supp...
# 19   INNER MASTERY / beliefs & awareness,URGES / to...
# 22   HEALING,GROWTH / true self,INNER / SELF / harm...
# 24   SOBRIETY / costs & benefits,ABSTINENCE,INNER P...
# 27   AGONY,INNER MASTERY / strength,TRUTH / Admit a...
# 28   DEAD END,TRUTH / dark past,MINDSET / Future so...
# 29     AMENDS,RECONCILIATON,CONFESSION / damage & hurt
# 30   ANGER,FREEDOM / tools & strategies,SOBRIETY / ...
# 31   DEAD END,CHANGE / motivations,TRUTH / Admit ad...
# 35   GROWTH / behavior & habits,INNER POWER / Tools...
# 38   MINDSET / Clear headed,GROWTH / willing to cha...
# 39   BITTERNESS,TRUTH / self honesty,VULNERABILITY ...
# 40   TRUTH / Costs,CHANGE / motivations,GROWTH / le...
# 41   MINDSET / Clear headed,PROGRESS / future & hop...
# 44   GROWTH / willing to change,TRUTH / self honest...
# 45   CONFIDENCE /  obstacles & challenge,SOBRIETY /...
# 46   COMMUNITY / healthy relationships,GROWTH / wil...
# 47   FREEDOM / past & let go,MINDSET / Future sobri...
# 48   RESILIENCE / discomfort,SOBRIETY / costs & ben...
# 49   CONTROL,MINDSET / Clear headed,SOBRIETY / cele...
# 50   SOBRIETY / costs & benefits,TRUTH / dark past,...
# 52   COMMUNITY / healthy relationships,EGO,VULNERAB...
# 54   ACCOUNTABILITY / damage confess,CONFESSION / a...
# 56   CONFESSION / denial,TRUTH / self honesty,DELUSION
# ..                                                 ...
# 125  COMMITMENTS,MINDSET / Future sobriety,BABY STE...
# 128         FREEDOM / peace & harmony,EMOTIONS,ANXIETY
# 142                               BLAME,EXCUSES,DENIAL
# 151                              DELUSION,DENIAL,SHAME
# 154  LABELS / STIGMA,VULNERABILITY / Show true self...
# 158  WORTHINESS / help,MINDSET / obstacles & challe...
# 159  FREEDOM / past & let go,SERENITY,SOBRIETY / be...
# 160  FREEDOM / peace & harmony,WORTHINESS / new lif...
# 163  FREEDOM / future & growth,GROWTH,CHANGE / beli...
# 164  GIVING / GENEROSITY,WORTHINESS / connections &...
# 165  MOTIVATION,CONFESSION / denial,MINDSET / Clear...
# 170  CHANGE / thoughts,BABY STEPS / focus on today,...
# 171  CHANGE / motivations,FREEDOM / past & let go,C...
# 172  BABY STEPS / focus on today,WARNINGS / Avoid t...
# 174  URGES / tools & techniques,FREEDOM,CONTROL,SOB...
# 175  CONFLICT,VULNERABILITY / Show true self,EMOTIO...
# 176  VULNERABILITY / to support my sobriety,CRAVING...
# 177  HEALING,CHANGE / beliefs,CONFESSION / damage &...
# 178  TRUTH / Costs,VULNERABILITY / Connection,INNER...
# 181  MINDSET / identify weaknesses,WARNINGS / self ...
# 182  AGONY,MINDSET / Future sobriety,RESILIENCE / d...
# 185  PROGRESS / future & hope,COMMUNITY / healthy r...
# 186  VULNERABILITY / to support my sobriety,CONFIDE...
# 187  CHANGE / self love & true self,INNER / SELF / ...
# 193  INNER / SELF / patterns,TRIGGERS / confidence ...
# 196  MINDSET / Clear headed,TRIGGERS / tools & tech...
# 201  URGES / moods & emotions,MINDSET / obstacles &...
# 202  URGES / moods & emotions,VULNERABILITY / to su...
# 203  OPTIMISM,SELF ESTEEM / beliefs,MINDSET / Perce...
# 205  CHANGE / motivations,DELUSION,URGES / tools & ...
#
#                                                WELLGOS      FOCUS      N  \
# 4    Self Esteem Elixir,Confidence Caffeinator,Inne...  DRUGS/ALC   Paul
# 8    Foul Weather Friender,Arrogance Arrestor,Pride...  DRUGS/ALC   Paul
# 10   Isolation SOS’r,Bad Influence Butcher,WAIT AND...  DRUGS/ALC   Paul
# 11   Miracle Embracer,Ego Eclipser,Pride Polisher,A...  DRUGS/ALC   Paul
# 14   Pride Puffer,Ego Eclipser,Arrogance Arrestor,N...  DRUGS/ALC   Paul
# 16   Perspective Detective,Daily Daisy Spotter,Blun...  DRUGS/ALC   Paul
# 17   Values VIP’r,Soul Proprietor,Sobriety 101'r,WA...  DRUGS/ALC   Paul
# 19   Placid Reflux,Urge Auditor,Compulsion KO’r,Sel...  DRUGS/ALC   Paul
# 22   Whole Soul Healer,Serenity Soulmater,Inner Sou...  DRUGS/ALC   Paul
# 24   Abstainer Amazer,Demon Dethroner ,COMMITMENT k...  DRUGS/ALC  Nigel
# 27   Pain Abstainer,CLOSET CONFESSOR / Admit addict...  DRUGS/ALC  Nigel
# 28   Dead End Defier ,Addiction AMF’r,Lost Benefit ...  DRUGS/ALC  Nigel
# 29   Relationship Dedamager,The First Amender,CLOSE...  DRUGS/ALC  Nigel
# 30   Lost Benefit Lamenter,Relationship Dedamager,V...  DRUGS/ALC  Nigel
# 31   Autopilot Auto X’r,Dead End Deluder,Addiction ...  DRUGS/ALC  Nigel
# 35   Bad Habit Butcher,Self awareness / habits & be...  DRUGS/ALC  Nigel
# 38   Bipolar Coaster,Rainbow Hunter,Inner Freedom F...  DRUGS/ALC  Nigel
# 39   Bitter Truth Taster,CLOSET CONFESSOR / Face tr...  DRUGS/ALC  Nigel
# 40   Black Hole Blesser,Killer Kickstarter,Addictio...  DRUGS/ALC  Nigel
# 41   Lost Benefit Lamenter,Brain Unchainer,NEW LIFE...  DRUGS/ALC  Nigel
# 44   Pride Puffer,VULNERABILITY / Radical self hone...  DRUGS/ALC  Nigel
# 45   Brick Wall Bulldozer,Block Climber,RELATIONSHI...  DRUGS/ALC  Nigel
# 46   Lost Benefit Lamenter,VULNERABILITY / support ...  DRUGS/ALC  Nigel
# 47   Bliss Kisser,NEW LIFE / POSSIBILITIES,Memory R...  DRUGS/ALC  Nigel
# 48   Cold Turkey Taster,Braverade,WAIT AND SWITCH /...  DRUGS/ALC  Nigel
# 49   Controller Coaster,Delusion Detector,WAIT AND ...  DRUGS/ALC  Nigel
# 50   Lack Hacker,Black Hole Blesser,Dead End Defier...  DRUGS/ALC  Nigel
# 52   Ego X’r,Relationship Dedamager,RELATIONSHIPS /...  DRUGS/ALC  Nigel
# 54   Damage Doctor,ADMIT / accountability,CLOSET CO...  DRUGS/ALC  Nigel
# 56   Delusion Detector,VULNERABILITY / listen to ot...  DRUGS/ALC  Nigel
# ..                                                 ...        ...    ...
# 125  Lost Benefit Lamenter,WAIT AND SWITCH / Small ...  DRUGS/ALC  Nigel
# 128  Anxiety Exiler,Emotions Auditor,Inner Freedom ...  DRUGS/ALC  Nigel
# 142              The Deblamer,Excuse X’r,Denial Denyer  DRUGS/ALC  Nigel
# 151  The Deshamer,Ego Excuser,Excuse Nuker,Delusion...  DRUGS/ALC  Nigel
# 154  The Destigmatizer,Self awareness / confidence ...  DRUGS/ALC  Nigel
# 158  Hardship Hacker,Craver Saver / Braver,Worthy S...    GENERAL   Paul
# 159  Past #2,Finish Line Forgetter,The Mindfulizer,...    GENERAL   Paul
# 160  I-Examiner,THOUGHTS / aware & examine,Spiritua...    GENERAL   Paul
# 163  Old Belief Butcher,I-Examiner,THOUGHTS / aware...    GENERAL   Paul
# 164  Kindness Knitter,Compassion Weaver,Inner Sun S...    GENERAL   Paul
# 165  Old Belief Butcher,I-examiner - motivations,Bi...    GENERAL   Paul
# 170  Baby Step Embracer,Inner Winner,THOUGHTS / awa...        POT   Jack
# 171  I-examiner - motivations,NEW PATTERN PAINTER /...        POT   Jack
# 172  New Pattern Painter,Trigger Trespasser,SELF HA...        POT   Jack
# 174      Mighty Motor Cranker,Compulsion KO’r,Urge X’r        POT   Jack
# 175  RAW SOUL REVEALER / emotions & urges,Conflict ...        POT   Jack
# 176  Trigger SOS’r,SELF HARM ALARMER / avoid trigge...        POT   Jack
# 177  Relationship Redeemer,Damage Detective,CLOSET ...        POT   Jack
# 178  RAW SOUL REVEALER / costs,Lost Benefit Lamente...        POT   Jack
# 181  Cravings 101'r,Autopilot Auto X’r,SELF HARM / ...        POT   Jack
# 182  Craver Saver / Braver,Torment Terminator,Pain ...        POT   Jack
# 185  Craver Saver / Braver,Whole Soul Healer,VULNER...        POT   Jack
# 186  Memory Rinser,Hope Harvester,VULNERABILITY / s...        POT   Jack
# 187  Inner Motor Motivator,New Pattern Painter / gr...        POT   Jack
# 193  Trigger X’r,Adversity Ninja,Challenge Ninja,Ne...        POT   Jack
# 196  Trigger Auditor,I-Examiner,Self awareness / ha...        POT   Jack
# 201  Challenge Ninja,Temperance Tester,Moody MF’r,B...        POT   Jack
# 202  Urge Purger,WAIT AND SWITCH / Progress,Self aw...        POT   Jack
# 203  I-Can-ographer,THOUGHTS / positivity,Attitude ...        POT   Jack
# 205  Urge Purger,Delusion Detector,Torment Terminat...        POT   Jack
#
#     GENDER                                             TOKENS  \
# 4     male  others,hide,lubricated,thought,mask,closest,wh...
# 8     male  feel,complain,Looking,help,have,everyone,harm,...
# 10    male  continue,offering,distance,who,what,anyone,dis...
# 11    male  anything,based,have,miracle,newfound,been,happ...
# 14    male  changes,continue,others,positive,second,change...
# 16    male  have,gift,ways,black,look,something,learned,li...
# 17    male  bother,worst,ways,did,what’s,busy,easier,other...
# 19    male  help,separate,urges,downright,command,somethin...
# 22    male  anything,don’t,aspect,come,meditation,been,oth...
# 24    male  took,addiction,detox,compare,have,stood,fell,y...
# 27    male  Taking,took,attempt,years,used,life,felt,slapp...
# 28    male  whole,got,dependent,world,sit,media,come,found...
# 29    male  whole,feel,able,have,years,dude,something,lot,...
# 30    male  heroin,positive,took,addiction,detox,smoking,l...
# 31    male  addiction,problem,'s,followed,years,have,hit,v...
# 35    male  Everything,public,positive,living,streets,sixt...
# 38    male  unstable,vehicle,terrifying,addiction,Amazing,...
# 39    male  nugget,addiction,told,hide,couldno,wore,have,a...
# 40    male  week,trashed,act,stressful,drug-addicted,detox...
# 41    male  others,addiction,wore,years,reboot,sucked,life...
# 44    male  anything,need,negative,have,addict,change,hit,...
# 45    male  brick,stopped,heroin,anxieties,switched,addict...
# 46    male  dwindle,whole,took,rooting,able,cheers,left,re...
# 47    male  rigorous,able,Looking,left,everyone,addict,sca...
# 48    male  bit,deal,valuable,named,'s,help,jumping,meds,u...
# 49    male  complete,addiction,detox,reached,bay,life,cras...
# 50    male  addiction,able,benefit,improved,gas,life,girl,...
# 52    male  addiction,controlled,detox,year,build,have,eve...
# 54    male  vehicle,Everything,addiction,years,step,blame,...
# 56    male  user,took,Delusions,able,harsh,years,have,reco...
# ..     ...                                                ...
# 125   male  addiction,none,experience,life,kid,gauged,damn...
# 128   male  took,addiction,exiled,rigorous,caught,anxiety,...
# 142   male  matter,cracks,addiction,avoid,upon,there,–,sit...
# 151   male  anything,have,come,addicted,lot,deflected,life...
# 154   male  believe,able,'s,help,have,step,split,associate...
# 158   male  Everything,island,advice,facing,Everybody,only...
# 159   male  week,right,year,happened,today,day,full,next,m...
# 160   male  managing,thinking,released,life,been,free,thou...
# 163   male  old,have,change,ways,wasn’t,been,beliefs,frien...
# 164   male  anything,matter,Sure,express,worked,something,...
# 165   male  able,old,comments,based,response,beliefs,perso...
# 170   male  addiction,feel,able,acknowledgment,have,step,c...
# 171   male  Everything,others,companionship,motivate,negat...
# 172   male  work,access,help,have,Today,tempt,something,st...
# 174   male  addiction,step,controlling,life,day,fed,pot,st...
# 175   male  addiction,able,step,wife,became,life,struggled...
# 176   male  anything,estimation,took,addiction,others,lock...
# 177   male  others,addiction,wife,felt,life,say,pot,certai...
# 178   male  marvelous,thought,companionship,addiction,watc...
# 181   male  user,slip,reverted,disengaged,cramps,have,addi...
# 182   male  anything,had,cruel,feel,addiction,able,past,ha...
# 185   male  partner,believe,help,helped,reduced,go,tried,l...
# 186   male  draw,overcome,wife,felt,explain,wanted,pot,cer...
# 187   male  find,addiction,watch,able,years,patterns,happe...
# 193   male  dies,work,addiction,watch,help,have,written,ca...
# 196   male  addiction,able,step,helped,none,track,write,sa...
# 201   male  anything,stopped,addiction,right,depressing,sm...
# 202   male  addiction,search,feel,help,step,controlling,pe...
# 203   male  addiction,believe,chances,positive,have,urges,...
# 205   male  addiction,able,feel,helped,wife,became,life,La...
#
#                                     TOPICS  \
# 4            friend,wa,see,reason,occasion
# 8           friend,wa,person,like,superior
# 10          didn’t,wa,people,distance,harm
# 11             miracle,wa,thing,sober,it’s
# 14            wa,second,nature,change,keep
# 16        something,problem,wa,fail,people
# 17                  plan,wa,make,take,best
# 19             urge,bad,wa,deep,succumbing
# 22                  soul,good,much,wa,know
# 24           abstinence,wa,thing,lost,fell
# 27                 wa,ever,problem,'d,took
# 28     alternative,wa,friend,whole,explore
# 29              n't,wa,apologize,'d,became
# 30               anger,wa,would,never,calm
# 31                wa,autopilot,day,go,drug
# 35              behaviour,close,'d,wa,lost
# 38         coaster,bipolar,happy,wa,friend
# 39            wa,truth,bitter,could,addict
# 40   wa,thing,girlfriend,trashed,apartment
# 41                wa,brain,reboot,–,spiral
# 44             wa,accept,person,type,wrong
# 45                 wa,friend,'d,made,could
# 46    wa,change,soon,experimenting,cheered
# 47                  wa,slate,–,could,clean
# 48                 wa,'s,cold,turkey,going
# 49          wa,control,coaster,enough,drop
# 50              wa,'d,money,benefit,though
# 52                 wa,ball,lean,curve,drug
# 54             wa,'d,damage,everything,n't
# 56            delusion,wa,detect,wrong,'ve
# ..                                     ...
# 125                  wa,–,time,going,clock
# 128            anxiety,wa,exiled,'d,exiler
# 142      wa,addicted,situation,crack,blame
# 151           wa,time,thing,long,deceitful
# 154              stigma,–,'d,wa,associated
# 158              wa,hardship,hand,i’m,okay
# 159               wa,today,norm,drink,make
# 160            wa,life,thought,free,action
# 163                said,wa,change,set,come
# 164           something,give,wa,get,return
# 165           root,cause,knowing,belief,wa
# 170             would,wa,step,change,first
# 171      wa,motivation,reason,would,change
# 172                   'm,going,pot,wa,room
# 174          control,compulsion,wa,n't,bad
# 175    conflict,emotion,wa,bottle,avoiding
# 176               wa,could,thought,one,pot
# 177                 wa,n't,thing,know,wife
# 178                   wa,n't,able,use,life
# 181             wa,would,pot,n't,seemingly
# 182          wa,overcome,even,nicotine,bad
# 185         craving,wa,wanted,would,reduce
# 186             memory,craving,wa,n't,time
# 187         wa,watching,crutch,least,began
# 193        addiction,trigger,work,thing,wa
# 196           trigger,wa,n't,wish,tracking
# 201             day,want,wa,moment,comfort
# 202         wa,n't,pot,chemical,absolutely
# 203          attitude,urge,wa,percent,lose
# 205                    pot,easy,'s,wa,urge
#
#                                 nVecTOPICS
# 4            friend,wa,see,reason,occasion
# 8           friend,wa,person,like,superior
# 10          didn’t,wa,people,distance,harm
# 11             miracle,wa,thing,sober,it’s
# 14            wa,second,nature,change,keep
# 16        something,problem,wa,fail,people
# 17                  plan,wa,make,take,best
# 19             urge,bad,wa,deep,succumbing
# 22                  soul,good,much,wa,know
# 24           abstinence,wa,thing,lost,fell
# 27                 wa,ever,problem,'d,took
# 28     alternative,wa,friend,whole,explore
# 29              n't,wa,apologize,'d,became
# 30               anger,wa,would,never,calm
# 31                wa,autopilot,day,go,drug
# 35              behaviour,close,'d,wa,lost
# 38         coaster,bipolar,happy,wa,friend
# 39            wa,truth,bitter,could,addict
# 40   wa,thing,girlfriend,trashed,apartment
# 41                wa,brain,reboot,–,spiral
# 44             wa,accept,person,type,wrong
# 45                 wa,friend,'d,made,could
# 46    wa,change,soon,experimenting,cheered
# 47                  wa,slate,–,could,clean
# 48                 wa,'s,cold,turkey,going
# 49          wa,control,coaster,enough,drop
# 50              wa,'d,money,benefit,though
# 52                 wa,ball,lean,curve,drug
# 54             wa,'d,damage,everything,n't
# 56            delusion,wa,detect,wrong,'ve
# ..                                     ...
# 125                  wa,–,time,going,clock
# 128            anxiety,wa,exiled,'d,exiler
# 142      wa,addicted,situation,crack,blame
# 151           wa,time,thing,long,deceitful
# 154              stigma,–,'d,wa,associated
# 158              wa,hardship,hand,i’m,okay
# 159               wa,today,norm,drink,make
# 160            wa,life,thought,free,action
# 163                said,wa,change,set,come
# 164           something,give,wa,get,return
# 165           root,cause,knowing,belief,wa
# 170             would,wa,step,change,first
# 171      wa,motivation,reason,would,change
# 172                   'm,going,pot,wa,room
# 174          control,compulsion,wa,n't,bad
# 175    conflict,emotion,wa,bottle,avoiding
# 176               wa,could,thought,one,pot
# 177                 wa,n't,thing,know,wife
# 178                   wa,n't,able,use,life
# 181             wa,would,pot,n't,seemingly
# 182          wa,overcome,even,nicotine,bad
# 185         craving,wa,wanted,would,reduce
# 186             memory,craving,wa,n't,time
# 187         wa,watching,crutch,least,began
# 193        addiction,trigger,work,thing,wa
# 196           trigger,wa,n't,wish,tracking
# 201             day,want,wa,moment,comfort
# 202         wa,n't,pot,chemical,absolutely
# 203          attitude,urge,wa,percent,lose
# 205                    pot,easy,'s,wa,urge
#
# [117 rows x 9 columns]

# %% [markdown]
# # DRUGS/ALC vs FOOD

# %%
df_drug = df[df['FOCUS'].str.contains("DRUGS/ALC")]
df_food = df[df['FOCUS'].str.contains("FOOD")]
df_df = df.loc[(df['FOCUS'] == 'DRUGS/ALC') | (df['FOCUS'] == 'FOOD')]
df_df.index = range(len(df_df))

d_idx,feats = data2feats(df_df,col=['CATS','WELLGOS','GENDER','FOCUS'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=3)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df_df)
# Out:
# Feats Shape:  (339, 581)
# Included:  dict_keys(['WELLGOS', 'CATS', 'GENDER', 'FOCUS'])

# %%
d_idx,feats = data2feats(df_df,col=['nVecTOPICS','GENDER'])

print('Feats Shape: ', feats.shape)
print('Included: ', d_idx.keys())

pca = PCA(n_components=2)
feats_2d = pca.fit_transform(feats)

kmeans = KMeans(n_clusters=4)
kmeans.fit(feats)

plotclusters(feats_2d,kmeans.labels_,df_df)
# Out:
# Feats Shape:  (339, 669)
# Included:  dict_keys(['GENDER', 'nVecTOPICS'])

# %%
l0,l1,l2,l3 = getlabel(df_df,kmeans.labels_,clusters=[0,1,2,3])
count(df_df,'nVecTOPICS',l0,0,topN=25)
count(df_df,'nVecTOPICS',l2,2,topN=20)
count(df_df,'nVecTOPICS',l1,1,topN=20)
count(df_df,'nVecTOPICS',l3,3,topN=20)
# Out:
# Cluster 0: 66 examples
# Counter({'male': 66})
# Counter({'DRUGS/ALC': 66})
# Counter({'Nigel': 51, 'Paul': 15})
#
# Cluster 1: 40 examples
# Counter({'female': 40})
# Counter({'DRUGS/ALC': 26, 'FOOD': 14})
# Counter({'Shar': 19, 'Jen': 12, 'Alys': 5, 'Ilanna': 4})
#
# Cluster 2: 92 examples
# Counter({'male': 92})
# Counter({'DRUGS/ALC': 92})
# Counter({'Nigel': 83, 'Paul': 9})
#
# Cluster 3: 141 examples
# Counter({'female': 141})
# Counter({'DRUGS/ALC': 102, 'FOOD': 39})
# Counter({'Shar': 53, 'Jen': 39, 'Alys': 37, 'Ilanna': 12})
#
# Total unique nVecTOPICS in Cluster 0: 218
#
# Most Common:
# ('life', 12)
# ('–', 11)
# ("'d", 10)
# ('drug', 7)
# ('way', 7)
# ("'s", 7)
# ("n't", 7)
# ('thing', 4)
# ("'ve", 4)
# ('time', 4)
# ('light', 3)
# ('could', 3)
# ('done', 3)
# ('everything', 3)
# ('control', 3)
# ('make', 3)
# ('friend', 3)
# ('maybe', 3)
# ('feeling', 3)
# ('like', 3)
# ('blame', 3)
# ('step', 2)
# ('depression', 2)
# ('there’s', 2)
# ('bridge', 2)
#
#
# Total unique nVecTOPICS in Cluster 2: 226
#
# Most Common:
# ('wa', 92)
# ("'d", 20)
# ("n't", 17)
# ('drug', 16)
# ('–', 11)
# ('life', 9)
# ('friend', 9)
# ("'s", 8)
# ('thing', 7)
# ('could', 5)
# ('never', 5)
# ('became', 3)
# ('would', 3)
# ('people', 3)
# ('going', 2)
# ('miracle', 2)
# ('lazy', 2)
# ('excuse', 2)
# ('get', 2)
# ('person', 2)
#
#
# Total unique nVecTOPICS in Cluster 1: 120
#
# Most Common:
# ('recovery', 40)
# ('today', 6)
# ('wa', 5)
# ('life', 4)
# ('people', 4)
# ('god', 3)
# ('thing', 3)
# ('share', 3)
# ('one', 3)
# ('change', 3)
# ('behavior', 3)
# ('others', 2)
# ('new', 2)
# ('make', 2)
# ('addict', 2)
# ('problem', 2)
# ('always', 2)
# ('feeling', 2)
# ('focus', 2)
# ('i’m', 2)
#
#
# Total unique nVecTOPICS in Cluster 3: 370
#
# Most Common:
# ('wa', 17)
# ('food', 16)
# ('life', 11)
# ('feeling', 9)
# ('one', 9)
# ('way', 8)
# ('today', 8)
# ('thought', 8)
# ('change', 8)
# ('people', 8)
# ('get', 7)
# ('craving', 7)
# ('don’t', 7)
# ('problem', 7)
# ('day', 7)
# ('like', 7)
# ('thing', 6)
# ('use', 6)
# ('god', 6)
# ('drug', 6)

# %% [markdown]
# # WELLGOS Comparasion DRUGS/ALC vs FOOD

# %%
l0,l1,l2 = getlabel(df_df,kmeans.labels_,clusters=[0,1,2])
count(df_df,'WELLGOS',l0,0,topN=10)
count(df_df,'WELLGOS',l1,1,topN=10)
count(df_df,'WELLGOS',l2,2,topN=10)
# Out:
# Cluster 0: 128 examples
# Counter({'female': 128})
# Counter({'DRUGS/ALC': 128})
# Counter({'Jen': 51, 'Alys': 42, 'Shar': 22, 'Ilanna': 13})
#
# Cluster 1: 53 examples
# Counter({'female': 53})
# Counter({'FOOD': 53})
# Counter({'Shar': 50, 'Ilanna': 3})
#
# Cluster 2: 158 examples
# Counter({'male': 158})
# Counter({'DRUGS/ALC': 158})
# Counter({'Nigel': 134, 'Paul': 24})
#
# Total unique WELLGOS in Cluster 0: 268
#
# Most Common:
# ('RELATIONSHIPS / Build connections & community', 9)
# ('Reactions Auditor', 8)
# ('NEW LIFE / POSSIBILITIES', 8)
# ('ADMIT / accountability', 8)
# ('Killer Kickstarter', 7)
# ('Inner Power Allower', 7)
# ("Self Control 101'r", 7)
# ('Symbolic Stepper', 7)
# ('Bitter Truth Taster', 7)
# ('Progress Pollinator', 6)
#
#
# Total unique WELLGOS in Cluster 1: 151
#
# Most Common:
# ('Ill Feelings Illuminator', 5)
# ('SELF HARM / Tools', 5)
# ('VULNERABILITY / reach out for help', 5)
# ('SELF HARM ALARMER / avoid triggers', 5)
# ('Deep Down Diver', 4)
# ('New Pattern Painter / confidence & awareness', 4)
# ('Self awareness / habits & behavior', 4)
# ('RELATIONSHIPS / Healthy & supportive', 3)
# ('Qualm Quitter', 3)
# ('Addiction AMF’r', 3)
#
#
# Total unique WELLGOS in Cluster 2: 284
#
# Most Common:
# ('Lost Benefit Lamenter', 11)
# ('Damage Doctor', 8)
# ('Denial Denyer', 8)
# ('Delusion Detector', 8)
# ('Inner Soul X-Rayer', 8)
# ('CLOSET CONFESSOR / Face truths', 8)
# ('RELATIONSHIPS / Healthy & supportive', 7)
# ('Inner Freedom Forager', 7)
# ('Relationship Redeemer', 7)
# ('WAIT AND SWITCH / Small steps', 7)

# %% [markdown]
# # CATS Comparasion DRUGS/ALC vs FOOD

# %%
l0,l1,l2 = getlabel(df_df,kmeans.labels_,clusters=[0,1,2])
count(df_df,'CATS',l0,0,topN=10)
count(df_df,'CATS',l1,1,topN=10)
count(df_df,'CATS',l2,2,topN=10)
# Out:
# Cluster 0: 128 examples
# Counter({'female': 128})
# Counter({'DRUGS/ALC': 128})
# Counter({'Jen': 51, 'Alys': 42, 'Shar': 22, 'Ilanna': 13})
#
# Cluster 1: 53 examples
# Counter({'female': 53})
# Counter({'FOOD': 53})
# Counter({'Shar': 50, 'Ilanna': 3})
#
# Cluster 2: 158 examples
# Counter({'male': 158})
# Counter({'DRUGS/ALC': 158})
# Counter({'Nigel': 134, 'Paul': 24})
#
# Total unique CATS in Cluster 0: 163
#
# Most Common:
# ('COMMUNITY / listen to guidance', 8)
# ('ACCOUNTABILITY / Own up', 8)
# ('CONFIDENCE /  hope & future', 8)
# ('FREEDOM / future & growth', 7)
# ('INFLUENCES', 7)
# ('GROWTH / motivation & boosts', 7)
# ('FREEDOM / past & let go', 6)
# ('INNER POWER / Vulnerability', 6)
# ('VULNERABILITY / learning and mistakes', 6)
# ('WORTHINESS / new life & future', 6)
#
#
# Total unique CATS in Cluster 1: 97
#
# Most Common:
# ('CONFESSION / admit', 5)
# ('INNER MASTERY / challenge & resilience', 5)
# ('VULNERABILITY / Show true self', 5)
# ('TRUTH / Admit addiction', 4)
# ('GOD / reach out', 4)
# ('DEMONS', 4)
# ('SOBRIETY / celebrate & progress', 4)
# ('PROGRESS / reactions & behavior', 3)
# ('TRIGGERS / tools & techniques', 3)
# ('WARNINGS / self aware & listen', 3)
#
#
# Total unique CATS in Cluster 2: 154
#
# Most Common:
# ('SOBRIETY / costs & benefits', 12)
# ('MINDSET / Clear headed', 11)
# ('GROWTH / willing to change', 11)
# ('TRUTH / self honesty', 11)
# ('ACCOUNTABILITY / damage confess', 10)
# ('CHANGE / mental confidence', 10)
# ('COMMUNITY / healthy relationships', 10)
# ('INNER / SELF / harmony & inner peace', 10)
# ('TRUTH / dark past', 8)
# ('DEAD END', 8)
